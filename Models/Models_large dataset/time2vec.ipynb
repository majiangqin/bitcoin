# %% [markdown]
# First finds optimal hyperparameters using Optuna
#
# Then validates model performance using 5-fold cross validation
#
# Finally trains one model on the entire dataset to make future predictions

# %%
import optuna
from dataclasses import asdict, dataclass
from functools import partial
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from typing import List, Dict, Tuple
import time
import random
import torch.optim.lr_scheduler as lr_scheduler
import warnings

warnings.filterwarnings('ignore')


@dataclass
class ModelConfig:
    """Configuration for LSTM model"""
    time2vec_dim: int = 20
    hidden_dim: int = 128
    batch_size: int = 128
    learning_rate: float = 0.00005
    num_epochs: int = 100
    max_encoder_length: int = 288
    max_prediction_length: int = 144
    clip_grad_norm: float = 1.0
    warmup_epochs: int = 3
    patience: int = 10
    min_delta: float = 1e-4
    dropout: float = 0.1


class EarlyStopping:
    def __init__(self, patience: int = 7, min_delta: float = 1e-4, verbose: bool = True):
        self.patience = patience
        self.min_delta = min_delta
        self.verbose = verbose
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.val_loss_min = float('inf')

    def __call__(self, val_loss: float, model: nn.Module) -> bool:
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0
        return self.early_stop


class Time2Vec(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(Time2Vec, self).__init__()
        self.w0 = nn.parameter.Parameter(torch.randn(input_dim, 1))
        self.b0 = nn.parameter.Parameter(torch.randn(1))
        self.w = nn.parameter.Parameter(torch.randn(input_dim, output_dim - 1))
        self.b = nn.parameter.Parameter(torch.randn(output_dim - 1))
        self.f = torch.sin

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        v1 = torch.matmul(x, self.w0) + self.b0
        v2 = self.f(torch.matmul(x, self.w) + self.b)
        return torch.cat([v1, v2], -1)


class BitcoinFeeModel(nn.Module):
    def __init__(self, hist_input_dim: int, future_input_dim: int, config: ModelConfig):
        super(BitcoinFeeModel, self).__init__()
        self.time2vec = Time2Vec(1, config.time2vec_dim)
        self.lstm = nn.LSTM(
            hist_input_dim + config.time2vec_dim,
            config.hidden_dim,
            batch_first=True,
            dropout=config.dropout
        )
        self.fc_combine = nn.Linear(config.hidden_dim + future_input_dim, config.hidden_dim)
        self.fc_out = nn.Linear(config.hidden_dim, 1)
        self.num_predictions = config.max_prediction_length

    def forward(self, time_feature: torch.Tensor, x_hist: torch.Tensor,
                x_future: torch.Tensor) -> torch.Tensor:
        batch_size, seq_len, _ = x_hist.shape
        time_encoded = self.time2vec(time_feature).expand(batch_size, seq_len, -1)
        x_hist_time = torch.cat([x_hist, time_encoded], dim=-1)

        _, (h_n, _) = self.lstm(x_hist_time)
        h_n = h_n.squeeze(0)

        outputs = []
        for i in range(self.num_predictions):
            combined = torch.cat((h_n, x_future[:, i, :]), dim=1)
            hidden = self.fc_combine(combined)
            out = self.fc_out(hidden)
            outputs.append(out)

        return torch.cat(outputs, dim=1)


class Time2VecDataset(Dataset):
    def __init__(self, data: pd.DataFrame, historical_features: List[str],
                 future_known_features: List[str], target: str, config: ModelConfig):
        self.data = data
        self.historical_features = historical_features
        self.future_known_features = future_known_features
        self.target = target
        self.config = config

    def __len__(self) -> int:
        return len(self.data) - self.config.max_encoder_length - self.config.max_prediction_length + 1

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
        encoder_start = idx
        encoder_end = idx + self.config.max_encoder_length
        decoder_end = encoder_end + self.config.max_prediction_length

        historical_data = self.data.iloc[encoder_start:encoder_end][self.historical_features]
        future_known_data = self.data.iloc[encoder_end:decoder_end][self.future_known_features]
        target_values = self.data.iloc[encoder_end:decoder_end][self.target]

        time_feature = torch.arange(0, self.config.max_encoder_length, dtype=torch.float32).unsqueeze(1)
        x_hist = torch.tensor(historical_data.values, dtype=torch.float32)
        x_future = torch.tensor(future_known_data.values, dtype=torch.float32)
        y = torch.tensor(target_values.values, dtype=torch.float32)

        return time_feature, x_hist, x_future, y


@dataclass
class ModelMetrics:
    mae: float
    rmse: float
    r2: float
    mape: float
    theil_u: float
    directional_accuracy: float


class BitcoinFeePredictor:


    def __init__(self, config: ModelConfig = ModelConfig()):
        self.config = config
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        self.historical_features = [
            'tx_count', 'mempool_size_mb', 'max_fee_rate', 'avg_fee_rate',
            'median_fee_rate', 'fee_rate_10th', 'fee_rate_90th', 'fee_rate_std',
            'mempool_min_fee', 'total_fee', 'mempool_usage', 'transaction_count',
            'block_weight', 'block_interval', 'hist_low_fee_ratio',
            'hist_med_fee_ratio', 'hist_high_fee_ratio', 'hist_fee_diversity',
            'hash_rate', 'bitcoin_price_usd'
        ]

        self.known_future_features = ['block_height', 'difficulty', 'block_version']
        self.target = 'block_median_fee_rate'


    def prepare_data(self, df: pd.DataFrame, scaler=None) -> Tuple[pd.DataFrame, RobustScaler]:
        """Prepare and scale data"""
        all_features = self.historical_features + self.known_future_features

        if scaler is None:
            scaler = RobustScaler()
            df[all_features] = scaler.fit_transform(df[all_features])
        else:
            df[all_features] = scaler.transform(df[all_features])
            
        return df, scaler


    def create_validation_dataloader(self, train_data: pd.DataFrame) -> DataLoader:
        """Create validation dataloader from last 20% of training data"""
        val_size = int(len(train_data) * 0.2)
        val_data = train_data.iloc[-val_size:]
        val_dataset = Time2VecDataset(val_data, self.historical_features,
                                  self.known_future_features, self.target, self.config)
        return DataLoader(val_dataset, batch_size=self.config.batch_size,
                      shuffle=False, drop_last=True)


    def train_model(self, train_data: pd.DataFrame) -> BitcoinFeeModel:
        """Train model with validation and early stopping"""
        train_size = int(len(train_data) * 0.8)
        train_subset = train_data.iloc[:train_size]

        train_dataset = Time2VecDataset(train_subset, self.historical_features,
                                    self.known_future_features, self.target, self.config)
        train_loader = DataLoader(train_dataset, batch_size=self.config.batch_size,
                              shuffle=True, drop_last=True)
        val_loader = self.create_validation_dataloader(train_data)

        model = BitcoinFeeModel(len(self.historical_features),
                            len(self.known_future_features), self.config).to(self.device)

        criterion = nn.HuberLoss()
        optimizer = optim.AdamW(model.parameters(), lr=self.config.learning_rate,
                            weight_decay=0.01, betas=(0.9, 0.999))

        scheduler = lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, T_0=10, T_mult=2, eta_min=1e-6
        )

        warmup_scheduler = lr_scheduler.LinearLR(
            optimizer,
            start_factor=0.1,
            end_factor=1.0,
            total_iters=self.config.warmup_epochs
         ) if self.config.warmup_epochs > 0 else None

        early_stopping = EarlyStopping(
        patience=self.config.patience,
        min_delta=self.config.min_delta
        )

        best_model_state = None
        best_val_loss = float('inf')

        for epoch in range(self.config.num_epochs):
            model.train()
            running_loss = 0.0

            for time_feature, x_hist, x_future_known, y in train_loader:
                time_feature = time_feature.to(self.device)
                x_hist = x_hist.to(self.device)
                x_future_known = x_future_known.to(self.device)
                y = y.to(self.device)

                outputs = model(time_feature, x_hist, x_future_known)
                loss = criterion(outputs, y)

                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), self.config.clip_grad_norm)
                optimizer.step()
                running_loss += loss.item()

            avg_train_loss = running_loss / len(train_loader)

        # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for time_feature, x_hist, x_future_known, y in val_loader:
                    time_feature = time_feature.to(self.device)
                    x_hist = x_hist.to(self.device)
                    x_future_known = x_future_known.to(self.device)
                    y = y.to(self.device)

                    outputs = model(time_feature, x_hist, x_future_known)
                    loss = criterion(outputs, y)
                    val_loss += loss.item()

                avg_val_loss = val_loss / len(val_loader)

            # Update learning rate
            if epoch < self.config.warmup_epochs and warmup_scheduler:
                warmup_scheduler.step()
            else:
                 scheduler.step()

            current_lr = optimizer.param_groups[0]['lr']
            print(f"Epoch {epoch + 1}/{self.config.num_epochs}, "
              f"Train Loss: {avg_train_loss:.4f}, "
              f"Val Loss: {avg_val_loss:.4f}, "
              f"LR: {current_lr:.6f}")

            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model_state = model.state_dict().copy()

            if early_stopping(avg_val_loss, model):
                print("Early stopping triggered")
                break

        if best_model_state is not None:
            model.load_state_dict(best_model_state)

        return model

    def predict(self, model: BitcoinFeeModel, data: pd.DataFrame) -> np.ndarray:
        """Make predictions"""
        model.eval()
        hist_data = data.tail(self.config.max_encoder_length)[self.historical_features].values

        future_known_data = np.zeros((self.config.max_prediction_length, len(self.known_future_features)))
        last_block_height = data['block_height'].iloc[-1]
        last_difficulty = data['difficulty'].iloc[-1]
        last_block_version = data['block_version'].iloc[-1]

        for i in range(self.config.max_prediction_length):
            future_known_data[i] = [last_block_height + i + 1, last_difficulty, last_block_version]

        time_feature = torch.arange(0, self.config.max_encoder_length, dtype=torch.float32).unsqueeze(1).to(self.device)
        x_hist = torch.tensor(hist_data, dtype=torch.float32).unsqueeze(0).to(self.device)
        x_future_known = torch.tensor(future_known_data, dtype=torch.float32).unsqueeze(0).to(self.device)

        with torch.no_grad():
            predictions = model(time_feature, x_hist, x_future_known).cpu().numpy().flatten()

        return predictions



    def calculate_metrics(self, y_true: np.ndarray, y_pred: np.ndarray) -> ModelMetrics:
        """Calculate evaluation metrics"""
        def mean_absolute_percentage_error(y_true, y_pred):
            return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

        def directional_accuracy(y_true, y_pred):
            return np.mean((np.diff(y_true) * np.diff(y_pred)) > 0) * 100

        def theil_u(y_true, y_pred):
            y_true_pct = (y_true[1:] - y_true[:-1]) / y_true[:-1]
            y_pred_pct = (y_pred[1:] - y_true[:-1]) / y_true[:-1]
            numerator = np.sqrt(np.mean((y_true_pct - y_pred_pct) ** 2))
            denominator = np.sqrt(np.mean(y_true_pct ** 2)) + np.sqrt(np.mean(y_pred_pct ** 2))
            return numerator / denominator

        return ModelMetrics(
            mae=mean_absolute_error(y_true, y_pred),
            rmse=np.sqrt(mean_squared_error(y_true, y_pred)),
            r2=r2_score(y_true, y_pred),
            mape=mean_absolute_percentage_error(y_true, y_pred),
            theil_u=theil_u(y_true, y_pred),
            directional_accuracy=directional_accuracy(y_true, y_pred)
        )
    
    def plot_predictions(self, y_true: np.ndarray, y_pred: np.ndarray,
                    title: str = "Actual vs Predicted Bitcoin Fee Rates") -> None:
        """Plot actual vs predicted values with metrics"""
        plt.figure(figsize=(15, 8))
    
        # Plot actual and predicted values
        x_axis = np.arange(len(y_true))
        plt.plot(x_axis, y_true, label='Actual', color='blue', alpha=0.6, linewidth=2)
        plt.plot(x_axis, y_pred, label='Predicted', color='red', alpha=0.6, linewidth=2)
    
        # Calculate and display metrics
        metrics = self.calculate_metrics(y_true, y_pred)
        metrics_text = (f'MAE: {metrics.mae:.2f}\n'
                   f'RMSE: {metrics.rmse:.2f}\n'
                   f'R²: {metrics.r2:.2f}\n'
                   f'MAPE: {metrics.mape:.2f}%\n'
                   f'Directional Accuracy: {metrics.directional_accuracy:.2f}%')
    
        plt.text(0.02, 0.98, metrics_text,
             transform=plt.gca().transAxes,
             verticalalignment='top',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
        plt.title(title)
        plt.xlabel('Block Number')
        plt.ylabel('Fee Rate (sat/vB)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()

    def cross_validate(self, df: pd.DataFrame, n_splits: int = 5) -> Tuple[List[ModelMetrics], np.ndarray, np.ndarray]:
        """Perform time series cross-validation with combined plotting"""
        n_samples = len(df)
        metrics_list = []
        all_y_true = []
        all_y_pred = []
    
    # Create figure for combined plot
        plt.figure(figsize=(15, 8))
    
        for fold_idx in range(n_splits):
            train_end = n_samples - (n_splits - fold_idx) * self.config.max_prediction_length
            test_start = train_end
            test_end = test_start + self.config.max_prediction_length
        
        # Split and prepare data
            train_data = df.iloc[:train_end].copy()
            test_data = df.iloc[test_start:test_end].copy()
        
            train_data, scaler = self.prepare_data(train_data)
            test_data, _ = self.prepare_data(test_data, scaler)
        
        # Train model
            model = self.train_model(train_data)
        
        # Make predictions
            predictions = self.predict(model, train_data)
        
        # Get actual values
            y_true = test_data[self.target].values
        
        # Store results
            metrics = self.calculate_metrics(y_true, predictions)
            metrics_list.append(metrics)
        
        # Accumulate predictions for combined plot
            start_idx = fold_idx * len(predictions)
            all_y_true.extend(y_true)
            all_y_pred.extend(predictions)
    
    # Convert to numpy arrays for plotting
        all_y_true = np.array(all_y_true)
        all_y_pred = np.array(all_y_pred)
    
    # Create combined plot
        plt.figure(figsize=(15, 12))
        x_axis = np.arange(1,len(all_y_true)+1)
    
    # Plot actual values in blue
        plt.plot(x_axis, all_y_true, label='Actual')
    
    # Plot predicted values in orange
        plt.plot(x_axis, all_y_pred, label='Predicted')

    # Customize plot
        plt.title('Time2vec: Actual vs Predicted Bitcoin Fee Rates (All Folds)', fontsize=20)
        plt.xlabel('Block Number',fontsize=20)
        plt.ylabel('Fee Rate',fontsize=20)
        plt.xticks(fontsize=16)
        plt.yticks(fontsize=16)
        plt.legend(fontsize=16)
        plt.grid(True, alpha=0.3)
        plt.savefig('time2vec.png',dpi=600)
        plt.show()
        
        
    # Calculate and format metrics for display
        mae_values = [m.mae for m in metrics_list]
        rmse_values = [m.rmse for m in metrics_list]
        theil_u_values = [m.theil_u for m in metrics_list]
        r2_values = [m.r2 for m in metrics_list]
        da_values = [m.directional_accuracy for m in metrics_list]
    

    # Print metrics to console
        print("\nCross-Validation Results:")
        print(f"Mean Absolute Error (CV): {np.mean(mae_values):.4f} (±{np.std(mae_values):.4f})")
        print(f"Root Mean Squared Error (CV): {np.mean(rmse_values):.4f} (±{np.std(rmse_values):.4f})")
        print(f"Theil's U Statistic (CV): {np.mean(theil_u_values):.4f} (±{np.std(theil_u_values):.4f})")
        print(f"R² Score (CV): {np.mean(r2_values):.4f} (±{np.std(r2_values):.4f})")
        print(f"Directional Accuracy (CV): {np.mean(da_values):.2f}% (±{np.std(da_values):.2f}%)")
    
        return metrics_list, all_y_true, all_y_pred


class ModelTuner:
    def __init__(self, df, n_trials=50):
        self.df = df
        self.n_trials = n_trials
        self.best_params = None
        self.best_score = float('inf')

    def objective(self, trial):
        """Optuna objective function for hyperparameter optimization"""
        try:
            # Define hyperparameter search space
            config = ModelConfig(
                # Time2Vec parameters
                time2vec_dim=trial.suggest_int('time2vec_dim', 16, 32),

                # Model architecture
                hidden_dim=trial.suggest_int('hidden_dim', 32, 256, step=32),

                # Training parameters
                batch_size=trial.suggest_categorical('batch_size', [32, 64, 128, 256]),
                learning_rate=trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True),

                # Regularization
                dropout=trial.suggest_float('dropout', 0.1, 0.5),
                clip_grad_norm=trial.suggest_float('clip_grad_norm', 0.1, 5.0),

                # Training schedule
                warmup_epochs=trial.suggest_int('warmup_epochs', 1, 10),
                patience=trial.suggest_int('patience', 5, 15),

                # Keep other parameters fixed
                num_epochs=100,
                max_encoder_length=288,
                max_prediction_length=144,
                min_delta=1e-4
            )

            # Initialize predictor with trial config
            predictor = BitcoinFeePredictor(config)

            # Split data before scaling
            n_samples = len(self.df)
            train_end = n_samples - config.max_prediction_length
            train_data = self.df.iloc[:train_end].copy()
            test_data = self.df.iloc[train_end:].copy()

            # Fit scaler only on training data
            train_data, scaler = predictor.prepare_data(train_data)
            test_data, _ = predictor.prepare_data(test_data, scaler)  # Use same scaler

            # Train model
            model = predictor.train_model(train_data)

            # Make predictions
            predictions = predictor.predict(model, train_data)

            # Get actual values
            y_true = test_data[predictor.target].values

            # Calculate metrics
            metrics = predictor.calculate_metrics(y_true, predictions)

            # Use RMSE as the optimization metric
            return metrics.rmse

        except Exception as e:
            print(f"Trial failed with error: {str(e)}")
            return float('inf')

    def find_best_params(self):
        """Run hyperparameter optimization"""
        try:
            study = optuna.create_study(
                direction='minimize',
                pruner=optuna.pruners.MedianPruner(
                    n_startup_trials=5,
                    n_warmup_steps=5,
                    interval_steps=3
                )
            )

            study.sampler = optuna.samplers.TPESampler(
                n_startup_trials=10,
                multivariate=True,
                constant_liar=True
            )

            study.optimize(self.objective, n_trials=self.n_trials, show_progress_bar=True)

            print("\nOptimization Results:")
            print(f"Number of completed trials: {len(study.trials)}")
            print("\nBest trial:")
            trial = study.best_trial

            print(f"Value (RMSE): {trial.value:.4f}")
            print("\nBest hyperparameters:")
            for key, value in trial.params.items():
                print(f"    {key}: {value}")

            self.best_params = trial.params
            self.best_score = trial.value

            return study

        except Exception as e:
            print(f"Error in hyperparameter optimization: {str(e)}")
            raise


def main_with_tuning_and_cv():
    try:
        # Set seeds
        random.seed(42)
        np.random.seed(42)
        torch.manual_seed(42)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(42)
            torch.cuda.manual_seed_all(42)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False

        # Load data
        print("Loading data...")
        df = pd.read_csv('../../Data/Data_larger dataset/train_set.csv')
        df['block_time'] = pd.to_datetime(df['block_time'])
        df = df.sort_values('block_time')
        
        # Set block_time as index
        df.set_index('block_time', inplace=True)

        # Step 1: Hyperparameter Optimization
        print("\nStarting hyperparameter optimization...")
        tuner = ModelTuner(df, n_trials=30)  # Increased trials
        study = tuner.find_best_params()

        # Create config with best parameters
        best_config = ModelConfig(**study.best_params)
        
        # Step 2: Cross Validation with Best Parameters
        print("\nPerforming cross-validation with best parameters...")
        predictor = BitcoinFeePredictor(best_config)
        metrics_list, all_y_true, all_y_pred = predictor.cross_validate(df, n_splits=5)
        
        mae_values = [m.mae for m in metrics_list]
        rmse_values = [m.rmse for m in metrics_list]
        r2_values = [m.r2 for m in metrics_list]
        

        # Step 3: Train Final Model on Full Dataset for Future Predictions
        print("\nTraining final model on full dataset...")
        df_prepared, scaler = predictor.prepare_data(df)
        model = predictor.train_model(df_prepared)
        
        # Generate predictions for next 144 blocks
        predictions = predictor.predict(model, df_prepared)

        # Create timestamps for predictions
        last_time = df.index[-1]  # Now this will be a timestamp
        prediction_times = pd.date_range(
            start=last_time,  # Use the last timestamp
            periods=145,      # Include the last timestamp
            freq='10T'
        )[1:]  # Exclude the first timestamp which is the last actual data point

        # Create results DataFrame with proper timestamps
        results_df = pd.DataFrame({
            'timestamp': prediction_times,
            'predicted_fee_rate': predictions[:144]
        })

        # Plot final results with proper time axis
        plt.figure(figsize=(15, 8))
        
        # Plot historical data
        historical_data = df['block_median_fee_rate'].iloc[-144:]
        plt.plot(historical_data.index, historical_data.values,
                 label='Historical', color='gray', alpha=0.5)
        
        # Plot predictions
        plt.plot(results_df['timestamp'], results_df['predicted_fee_rate'],
                 label='Predicted', color='blue', marker='o', markersize=4)
        
        plt.title('Bitcoin Fee Rate Predictions - Next 144 Blocks')
        plt.xlabel('Time')
        plt.ylabel('Fee Rate (sat/vB)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.gcf().autofmt_xdate()
        plt.tight_layout()
        plt.show()

        # Save results
        results_df.to_csv('time2vec_predictions.csv')
        best_params_df = pd.DataFrame([study.best_params])
        best_params_df.to_csv('time2vec_best_params.csv', index=False)

        # Save cross-validation results with more detailed metrics
        cv_results = pd.DataFrame({
            'fold': range(1, len(metrics_list) + 1),
            'mae': [m.mae for m in metrics_list],
            'rmse': [m.rmse for m in metrics_list],
            'r2': [m.r2 for m in metrics_list],
            'mape': [m.mape for m in metrics_list],
            'theil_u': [m.theil_u for m in metrics_list],
            'directional_accuracy': [m.directional_accuracy for m in metrics_list]
        })
        cv_results.to_csv('time2vec_cross_validation_results.csv', index=False)

        print("\nResults saved:")
        print("- Predictions: 'time2vec_predictions.csv'")
        print("- Best parameters: 'time2vec_best_params.csv'")
        print("- Cross-validation results: 'cross_validation_results.csv'")

        return study, results_df, cv_results

    except Exception as e:
        print(f"Error in main process: {str(e)}")
        raise

if __name__ == "__main__":
    study, predictions, cv_results = main_with_tuning_and_cv()
# Out:
# [I 2025-01-06 23:43:56,290] A new study created in memory with name: no-name-64588cc6-1e0f-48f5-88bf-2ba2b8fc714c
# Loading data...
#
# Starting hyperparameter optimization...
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 1/100, Train Loss: 5.7432, Val Loss: 7.9046, LR: 0.000004
# Epoch 2/100, Train Loss: 5.6751, Val Loss: 7.8150, LR: 0.000007
# Epoch 3/100, Train Loss: 5.5571, Val Loss: 7.6640, LR: 0.000009
# Epoch 4/100, Train Loss: 5.3582, Val Loss: 7.4468, LR: 0.000012
# Epoch 5/100, Train Loss: 5.1064, Val Loss: 7.1545, LR: 0.000015
# Epoch 6/100, Train Loss: 4.7696, Val Loss: 6.7732, LR: 0.000014
# Epoch 7/100, Train Loss: 4.3997, Val Loss: 6.3534, LR: 0.000013
# Epoch 8/100, Train Loss: 4.0343, Val Loss: 5.9059, LR: 0.000012
# Epoch 9/100, Train Loss: 3.7061, Val Loss: 5.4713, LR: 0.000010
# Epoch 10/100, Train Loss: 3.4564, Val Loss: 5.0864, LR: 0.000008
# Epoch 11/100, Train Loss: 3.2912, Val Loss: 4.7736, LR: 0.000006
# Epoch 12/100, Train Loss: 3.1801, Val Loss: 4.5527, LR: 0.000004
# Epoch 13/100, Train Loss: 3.1183, Val Loss: 4.4173, LR: 0.000002
# Epoch 14/100, Train Loss: 3.0884, Val Loss: 4.3414, LR: 0.000001
# Epoch 15/100, Train Loss: 3.0679, Val Loss: 4.2998, LR: 0.000015
# Epoch 16/100, Train Loss: 3.0172, Val Loss: 3.9111, LR: 0.000015
# Epoch 17/100, Train Loss: 2.9538, Val Loss: 3.6607, LR: 0.000014
# Epoch 18/100, Train Loss: 2.9211, Val Loss: 3.5099, LR: 0.000014
# Epoch 19/100, Train Loss: 2.8892, Val Loss: 3.3676, LR: 0.000013
# Epoch 20/100, Train Loss: 2.8332, Val Loss: 3.2179, LR: 0.000013
# Epoch 21/100, Train Loss: 2.7652, Val Loss: 3.1113, LR: 0.000012
# Epoch 22/100, Train Loss: 2.7110, Val Loss: 3.0039, LR: 0.000011
# Epoch 23/100, Train Loss: 2.6576, Val Loss: 2.9605, LR: 0.000010
# Epoch 24/100, Train Loss: 2.6011, Val Loss: 2.8628, LR: 0.000009
# Epoch 25/100, Train Loss: 2.5414, Val Loss: 2.8066, LR: 0.000008
# Epoch 26/100, Train Loss: 2.4890, Val Loss: 2.7385, LR: 0.000007
# Epoch 27/100, Train Loss: 2.4534, Val Loss: 2.6857, LR: 0.000006
# Epoch 28/100, Train Loss: 2.4219, Val Loss: 2.6467, LR: 0.000005
# Epoch 29/100, Train Loss: 2.4008, Val Loss: 2.6126, LR: 0.000004
# Epoch 30/100, Train Loss: 2.3820, Val Loss: 2.6004, LR: 0.000003
# Epoch 31/100, Train Loss: 2.3707, Val Loss: 2.5824, LR: 0.000002
# Epoch 32/100, Train Loss: 2.3591, Val Loss: 2.5710, LR: 0.000002
# Epoch 33/100, Train Loss: 2.3500, Val Loss: 2.5635, LR: 0.000001
# Epoch 34/100, Train Loss: 2.3481, Val Loss: 2.5599, LR: 0.000001
# Epoch 35/100, Train Loss: 2.3444, Val Loss: 2.5547, LR: 0.000015
# Epoch 36/100, Train Loss: 2.3206, Val Loss: 2.4958, LR: 0.000015
# Epoch 37/100, Train Loss: 2.2821, Val Loss: 2.4665, LR: 0.000015
# Epoch 38/100, Train Loss: 2.2513, Val Loss: 2.4780, LR: 0.000015
# EarlyStopping counter: 1 out of 9
# Epoch 39/100, Train Loss: 2.2229, Val Loss: 2.4805, LR: 0.000014
# EarlyStopping counter: 2 out of 9
# Epoch 40/100, Train Loss: 2.1928, Val Loss: 2.4860, LR: 0.000014
# EarlyStopping counter: 3 out of 9
# Epoch 41/100, Train Loss: 2.1741, Val Loss: 2.5045, LR: 0.000014
# EarlyStopping counter: 4 out of 9
# Epoch 42/100, Train Loss: 2.1584, Val Loss: 2.5156, LR: 0.000014
# EarlyStopping counter: 5 out of 9
# Epoch 43/100, Train Loss: 2.1415, Val Loss: 2.5280, LR: 0.000013
# EarlyStopping counter: 6 out of 9
# Epoch 44/100, Train Loss: 2.1271, Val Loss: 2.5572, LR: 0.000013
# EarlyStopping counter: 7 out of 9
# Epoch 45/100, Train Loss: 2.1153, Val Loss: 2.5726, LR: 0.000013
# EarlyStopping counter: 8 out of 9
# Epoch 46/100, Train Loss: 2.1077, Val Loss: 2.5990, LR: 0.000012
# EarlyStopping counter: 9 out of 9
# Early stopping triggered
# [I 2025-01-07 00:17:03,882] Trial 0 finished with value: 2.401102453868018 and parameters: {'time2vec_dim': 30, 'hidden_dim': 128, 'batch_size': 128, 'learning_rate': 1.4707187453368439e-05, 'dropout': 0.2744003027920934, 'clip_grad_norm': 4.778604963722088, 'warmup_epochs': 5, 'patience': 9}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.7607, Val Loss: 7.9198, LR: 0.000006
# Epoch 2/100, Train Loss: 5.6302, Val Loss: 7.7622, LR: 0.000009
# Epoch 3/100, Train Loss: 5.4306, Val Loss: 7.5156, LR: 0.000012
# Epoch 4/100, Train Loss: 5.1194, Val Loss: 7.1519, LR: 0.000016
# Epoch 5/100, Train Loss: 4.6852, Val Loss: 6.6137, LR: 0.000019
# Epoch 6/100, Train Loss: 4.0970, Val Loss: 5.8012, LR: 0.000022
# Epoch 7/100, Train Loss: 3.4494, Val Loss: 4.6227, LR: 0.000025
# Epoch 8/100, Train Loss: 2.9970, Val Loss: 3.4576, LR: 0.000028
# Epoch 9/100, Train Loss: 2.8588, Val Loss: 3.3214, LR: 0.000028
# Epoch 10/100, Train Loss: 2.7707, Val Loss: 3.0895, LR: 0.000026
# Epoch 11/100, Train Loss: 2.6595, Val Loss: 2.9147, LR: 0.000023
# Epoch 12/100, Train Loss: 2.5482, Val Loss: 2.7524, LR: 0.000019
# Epoch 13/100, Train Loss: 2.4409, Val Loss: 2.6115, LR: 0.000015
# Epoch 14/100, Train Loss: 2.3597, Val Loss: 2.4495, LR: 0.000010
# Epoch 15/100, Train Loss: 2.3105, Val Loss: 2.3782, LR: 0.000007
# Epoch 16/100, Train Loss: 2.2764, Val Loss: 2.3616, LR: 0.000004
# Epoch 17/100, Train Loss: 2.2620, Val Loss: 2.3542, LR: 0.000002
# Epoch 18/100, Train Loss: 2.2527, Val Loss: 2.3582, LR: 0.000028
# EarlyStopping counter: 1 out of 7
# Epoch 19/100, Train Loss: 2.2170, Val Loss: 2.3651, LR: 0.000028
# EarlyStopping counter: 2 out of 7
# Epoch 20/100, Train Loss: 2.1661, Val Loss: 2.4858, LR: 0.000028
# EarlyStopping counter: 3 out of 7
# Epoch 21/100, Train Loss: 2.1219, Val Loss: 2.5240, LR: 0.000027
# EarlyStopping counter: 4 out of 7
# Epoch 22/100, Train Loss: 2.0771, Val Loss: 2.5463, LR: 0.000026
# EarlyStopping counter: 5 out of 7
# Epoch 23/100, Train Loss: 2.0415, Val Loss: 2.5766, LR: 0.000024
# EarlyStopping counter: 6 out of 7
# Epoch 24/100, Train Loss: 2.0172, Val Loss: 2.6160, LR: 0.000023
# EarlyStopping counter: 7 out of 7
# Early stopping triggered
# [I 2025-01-07 00:36:10,360] Trial 1 finished with value: 4.855482054959774 and parameters: {'time2vec_dim': 19, 'hidden_dim': 160, 'batch_size': 128, 'learning_rate': 2.8321934872347574e-05, 'dropout': 0.20524817351108365, 'clip_grad_norm': 0.22602483443097757, 'warmup_epochs': 8, 'patience': 7}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.6673, Val Loss: 7.8952, LR: 0.000005
# Epoch 2/100, Train Loss: 5.6529, Val Loss: 7.8786, LR: 0.000007
# Epoch 3/100, Train Loss: 5.6312, Val Loss: 7.8535, LR: 0.000009
# Epoch 4/100, Train Loss: 5.6007, Val Loss: 7.8194, LR: 0.000011
# Epoch 5/100, Train Loss: 5.5532, Val Loss: 7.7753, LR: 0.000014
# Epoch 6/100, Train Loss: 5.5045, Val Loss: 7.7193, LR: 0.000016
# Epoch 7/100, Train Loss: 5.4355, Val Loss: 7.6489, LR: 0.000018
# Epoch 8/100, Train Loss: 5.3613, Val Loss: 7.5616, LR: 0.000020
# Epoch 9/100, Train Loss: 5.2536, Val Loss: 7.4565, LR: 0.000023
# Epoch 10/100, Train Loss: 5.1342, Val Loss: 7.3329, LR: 0.000022
# Epoch 11/100, Train Loss: 5.0032, Val Loss: 7.2017, LR: 0.000021
# Epoch 12/100, Train Loss: 4.8704, Val Loss: 7.0771, LR: 0.000018
# Epoch 13/100, Train Loss: 4.7629, Val Loss: 6.9715, LR: 0.000015
# Epoch 14/100, Train Loss: 4.6571, Val Loss: 6.8791, LR: 0.000012
# Epoch 15/100, Train Loss: 4.5788, Val Loss: 6.8110, LR: 0.000008
# Epoch 16/100, Train Loss: 4.5221, Val Loss: 6.7660, LR: 0.000005
# Epoch 17/100, Train Loss: 4.4863, Val Loss: 6.7384, LR: 0.000003
# Epoch 18/100, Train Loss: 4.4635, Val Loss: 6.7234, LR: 0.000002
# Epoch 19/100, Train Loss: 4.4549, Val Loss: 6.7161, LR: 0.000023
# Epoch 20/100, Train Loss: 4.4001, Val Loss: 6.6052, LR: 0.000022
# Epoch 21/100, Train Loss: 4.3026, Val Loss: 6.4850, LR: 0.000022
# Epoch 22/100, Train Loss: 4.1871, Val Loss: 6.3461, LR: 0.000021
# Epoch 23/100, Train Loss: 4.0670, Val Loss: 6.1831, LR: 0.000021
# Epoch 24/100, Train Loss: 3.9358, Val Loss: 6.0185, LR: 0.000019
# Epoch 25/100, Train Loss: 3.8154, Val Loss: 5.8692, LR: 0.000018
# Epoch 26/100, Train Loss: 3.7172, Val Loss: 5.7327, LR: 0.000017
# Epoch 27/100, Train Loss: 3.6330, Val Loss: 5.6034, LR: 0.000015
# Epoch 28/100, Train Loss: 3.5573, Val Loss: 5.4809, LR: 0.000014
# Epoch 29/100, Train Loss: 3.4950, Val Loss: 5.3687, LR: 0.000012
# Epoch 30/100, Train Loss: 3.4408, Val Loss: 5.2702, LR: 0.000010
# Epoch 31/100, Train Loss: 3.3971, Val Loss: 5.1870, LR: 0.000008
# Epoch 32/100, Train Loss: 3.3514, Val Loss: 5.1186, LR: 0.000007
# Epoch 33/100, Train Loss: 3.3245, Val Loss: 5.0638, LR: 0.000005
# Epoch 34/100, Train Loss: 3.3060, Val Loss: 5.0214, LR: 0.000004
# Epoch 35/100, Train Loss: 3.2964, Val Loss: 4.9894, LR: 0.000003
# Epoch 36/100, Train Loss: 3.2863, Val Loss: 4.9664, LR: 0.000002
# Epoch 37/100, Train Loss: 3.2715, Val Loss: 4.9501, LR: 0.000002
# Epoch 38/100, Train Loss: 3.2656, Val Loss: 4.9389, LR: 0.000001
# Epoch 39/100, Train Loss: 3.2597, Val Loss: 4.9307, LR: 0.000023
# Epoch 40/100, Train Loss: 3.2236, Val Loss: 4.7628, LR: 0.000023
# Epoch 41/100, Train Loss: 3.1669, Val Loss: 4.5805, LR: 0.000022
# Epoch 42/100, Train Loss: 3.1120, Val Loss: 4.3730, LR: 0.000022
# Epoch 43/100, Train Loss: 3.0509, Val Loss: 4.1436, LR: 0.000022
# Epoch 44/100, Train Loss: 3.0162, Val Loss: 3.9172, LR: 0.000022
# Epoch 45/100, Train Loss: 2.9820, Val Loss: 3.7308, LR: 0.000021
# Epoch 46/100, Train Loss: 2.9592, Val Loss: 3.6296, LR: 0.000021
# Epoch 47/100, Train Loss: 2.9478, Val Loss: 3.6048, LR: 0.000021
# Epoch 48/100, Train Loss: 2.9372, Val Loss: 3.6138, LR: 0.000020
# EarlyStopping counter: 1 out of 9
# Epoch 49/100, Train Loss: 2.9221, Val Loss: 3.5913, LR: 0.000019
# Epoch 50/100, Train Loss: 2.9173, Val Loss: 3.5620, LR: 0.000019
# Epoch 51/100, Train Loss: 2.8955, Val Loss: 3.5882, LR: 0.000018
# EarlyStopping counter: 1 out of 9
# Epoch 52/100, Train Loss: 2.8784, Val Loss: 3.5645, LR: 0.000017
# EarlyStopping counter: 2 out of 9
# Epoch 53/100, Train Loss: 2.8513, Val Loss: 3.5114, LR: 0.000017
# Epoch 54/100, Train Loss: 2.8303, Val Loss: 3.4506, LR: 0.000016
# Epoch 55/100, Train Loss: 2.8079, Val Loss: 3.4244, LR: 0.000015
# Epoch 56/100, Train Loss: 2.7953, Val Loss: 3.3960, LR: 0.000014
# Epoch 57/100, Train Loss: 2.7831, Val Loss: 3.3740, LR: 0.000014
# Epoch 58/100, Train Loss: 2.7676, Val Loss: 3.3549, LR: 0.000013
# Epoch 59/100, Train Loss: 2.7457, Val Loss: 3.3243, LR: 0.000012
# Epoch 60/100, Train Loss: 2.7297, Val Loss: 3.3026, LR: 0.000011
# Epoch 61/100, Train Loss: 2.7178, Val Loss: 3.2915, LR: 0.000010
# Epoch 62/100, Train Loss: 2.7058, Val Loss: 3.2788, LR: 0.000009
# Epoch 63/100, Train Loss: 2.6971, Val Loss: 3.2644, LR: 0.000008
# Epoch 64/100, Train Loss: 2.6941, Val Loss: 3.2554, LR: 0.000008
# Epoch 65/100, Train Loss: 2.6875, Val Loss: 3.2511, LR: 0.000007
# Epoch 66/100, Train Loss: 2.6823, Val Loss: 3.2474, LR: 0.000006
# Epoch 67/100, Train Loss: 2.6788, Val Loss: 3.2351, LR: 0.000005
# Epoch 68/100, Train Loss: 2.6778, Val Loss: 3.2295, LR: 0.000005
# Epoch 69/100, Train Loss: 2.6747, Val Loss: 3.2240, LR: 0.000004
# Epoch 70/100, Train Loss: 2.6701, Val Loss: 3.2209, LR: 0.000004
# Epoch 71/100, Train Loss: 2.6671, Val Loss: 3.2172, LR: 0.000003
# Epoch 72/100, Train Loss: 2.6647, Val Loss: 3.2158, LR: 0.000003
# Epoch 73/100, Train Loss: 2.6628, Val Loss: 3.2122, LR: 0.000002
# Epoch 74/100, Train Loss: 2.6608, Val Loss: 3.2079, LR: 0.000002
# Epoch 75/100, Train Loss: 2.6626, Val Loss: 3.2062, LR: 0.000002
# Epoch 76/100, Train Loss: 2.6625, Val Loss: 3.2032, LR: 0.000001
# Epoch 77/100, Train Loss: 2.6609, Val Loss: 3.2015, LR: 0.000001
# Epoch 78/100, Train Loss: 2.6609, Val Loss: 3.1986, LR: 0.000001
# Epoch 79/100, Train Loss: 2.6617, Val Loss: 3.1987, LR: 0.000023
# EarlyStopping counter: 1 out of 9
# Epoch 80/100, Train Loss: 2.6536, Val Loss: 3.1730, LR: 0.000023
# Epoch 81/100, Train Loss: 2.6427, Val Loss: 3.1642, LR: 0.000023
# Epoch 82/100, Train Loss: 2.6281, Val Loss: 3.0887, LR: 0.000023
# Epoch 83/100, Train Loss: 2.6009, Val Loss: 3.0001, LR: 0.000022
# Epoch 84/100, Train Loss: 2.5817, Val Loss: 2.9897, LR: 0.000022
# Epoch 85/100, Train Loss: 2.5638, Val Loss: 2.9455, LR: 0.000022
# Epoch 86/100, Train Loss: 2.5410, Val Loss: 2.8847, LR: 0.000022
# Epoch 87/100, Train Loss: 2.5145, Val Loss: 2.8184, LR: 0.000022
# Epoch 88/100, Train Loss: 2.4836, Val Loss: 2.7638, LR: 0.000022
# Epoch 89/100, Train Loss: 2.4535, Val Loss: 2.6676, LR: 0.000022
# Epoch 90/100, Train Loss: 2.4271, Val Loss: 2.6267, LR: 0.000022
# Epoch 91/100, Train Loss: 2.3965, Val Loss: 2.5586, LR: 0.000021
# Epoch 92/100, Train Loss: 2.3741, Val Loss: 2.5196, LR: 0.000021
# Epoch 93/100, Train Loss: 2.3534, Val Loss: 2.4814, LR: 0.000021
# Epoch 94/100, Train Loss: 2.3344, Val Loss: 2.4819, LR: 0.000021
# EarlyStopping counter: 1 out of 9
# Epoch 95/100, Train Loss: 2.3015, Val Loss: 2.4490, LR: 0.000021
# Epoch 96/100, Train Loss: 2.2807, Val Loss: 2.4671, LR: 0.000020
# EarlyStopping counter: 1 out of 9
# Epoch 97/100, Train Loss: 2.2696, Val Loss: 2.4308, LR: 0.000020
# Epoch 98/100, Train Loss: 2.2524, Val Loss: 2.4250, LR: 0.000020
# Epoch 99/100, Train Loss: 2.2388, Val Loss: 2.4241, LR: 0.000019
# Epoch 100/100, Train Loss: 2.2301, Val Loss: 2.4317, LR: 0.000019
# EarlyStopping counter: 1 out of 9
# [I 2025-01-07 01:14:53,586] Trial 2 finished with value: 6.662006605692569 and parameters: {'time2vec_dim': 17, 'hidden_dim': 64, 'batch_size': 256, 'learning_rate': 2.2626206438291175e-05, 'dropout': 0.10382410942453212, 'clip_grad_norm': 1.6298519610841067, 'warmup_epochs': 9, 'patience': 9}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.9197, Val Loss: 7.9992, LR: 0.000031
# Epoch 2/100, Train Loss: 5.3678, Val Loss: 7.0605, LR: 0.000054
# Epoch 3/100, Train Loss: 3.9805, Val Loss: 4.7069, LR: 0.000077
# Epoch 4/100, Train Loss: 3.0018, Val Loss: 3.5606, LR: 0.000075
# Epoch 5/100, Train Loss: 2.9067, Val Loss: 3.2546, LR: 0.000070
# Epoch 6/100, Train Loss: 2.7814, Val Loss: 3.0164, LR: 0.000061
# Epoch 7/100, Train Loss: 2.6272, Val Loss: 2.7254, LR: 0.000051
# Epoch 8/100, Train Loss: 2.4809, Val Loss: 2.5280, LR: 0.000039
# Epoch 9/100, Train Loss: 2.3879, Val Loss: 2.3839, LR: 0.000027
# Epoch 10/100, Train Loss: 2.3326, Val Loss: 2.3319, LR: 0.000017
# Epoch 11/100, Train Loss: 2.3004, Val Loss: 2.3071, LR: 0.000008
# Epoch 12/100, Train Loss: 2.2830, Val Loss: 2.3121, LR: 0.000003
# EarlyStopping counter: 1 out of 14
# Epoch 13/100, Train Loss: 2.2727, Val Loss: 2.2905, LR: 0.000077
# Epoch 14/100, Train Loss: 2.2794, Val Loss: 2.2517, LR: 0.000077
# Epoch 15/100, Train Loss: 2.1993, Val Loss: 2.2834, LR: 0.000075
# EarlyStopping counter: 1 out of 14
# Epoch 16/100, Train Loss: 2.1498, Val Loss: 2.4985, LR: 0.000073
# EarlyStopping counter: 2 out of 14
# Epoch 17/100, Train Loss: 2.1113, Val Loss: 2.5112, LR: 0.000070
# EarlyStopping counter: 3 out of 14
# Epoch 18/100, Train Loss: 2.0844, Val Loss: 2.6204, LR: 0.000066
# EarlyStopping counter: 4 out of 14
# Epoch 19/100, Train Loss: 2.0546, Val Loss: 2.6261, LR: 0.000061
# EarlyStopping counter: 5 out of 14
# Epoch 20/100, Train Loss: 2.0467, Val Loss: 2.5660, LR: 0.000056
# EarlyStopping counter: 6 out of 14
# Epoch 21/100, Train Loss: 2.0177, Val Loss: 2.4466, LR: 0.000051
# EarlyStopping counter: 7 out of 14
# Epoch 22/100, Train Loss: 1.9907, Val Loss: 2.4159, LR: 0.000045
# EarlyStopping counter: 8 out of 14
# Epoch 23/100, Train Loss: 1.9758, Val Loss: 2.5733, LR: 0.000039
# EarlyStopping counter: 9 out of 14
# Epoch 24/100, Train Loss: 1.9598, Val Loss: 2.5650, LR: 0.000033
# EarlyStopping counter: 10 out of 14
# Epoch 25/100, Train Loss: 1.9586, Val Loss: 2.4787, LR: 0.000027
# EarlyStopping counter: 11 out of 14
# Epoch 26/100, Train Loss: 1.9455, Val Loss: 2.5288, LR: 0.000022
# EarlyStopping counter: 12 out of 14
# Epoch 27/100, Train Loss: 1.9409, Val Loss: 2.5112, LR: 0.000017
# EarlyStopping counter: 13 out of 14
# Epoch 28/100, Train Loss: 1.9369, Val Loss: 2.5473, LR: 0.000012
# EarlyStopping counter: 14 out of 14
# Early stopping triggered
# [I 2025-01-07 01:39:44,532] Trial 3 finished with value: 4.364496409056728 and parameters: {'time2vec_dim': 24, 'hidden_dim': 256, 'batch_size': 256, 'learning_rate': 7.698740017359627e-05, 'dropout': 0.26266677048939824, 'clip_grad_norm': 2.190611260778518, 'warmup_epochs': 3, 'patience': 14}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 6.0196, Val Loss: 8.0303, LR: 0.000024
# Epoch 2/100, Train Loss: 5.6111, Val Loss: 7.4164, LR: 0.000042
# Epoch 3/100, Train Loss: 4.5098, Val Loss: 5.6038, LR: 0.000060
# Epoch 4/100, Train Loss: 3.1112, Val Loss: 3.3713, LR: 0.000059
# Epoch 5/100, Train Loss: 2.7504, Val Loss: 2.9491, LR: 0.000055
# Epoch 6/100, Train Loss: 2.4920, Val Loss: 2.5019, LR: 0.000048
# Epoch 7/100, Train Loss: 2.3430, Val Loss: 2.2967, LR: 0.000040
# Epoch 8/100, Train Loss: 2.2706, Val Loss: 2.3256, LR: 0.000031
# EarlyStopping counter: 1 out of 6
# Epoch 9/100, Train Loss: 2.2292, Val Loss: 2.3256, LR: 0.000022
# EarlyStopping counter: 2 out of 6
# Epoch 10/100, Train Loss: 2.2031, Val Loss: 2.3404, LR: 0.000013
# EarlyStopping counter: 3 out of 6
# Epoch 11/100, Train Loss: 2.1874, Val Loss: 2.3598, LR: 0.000007
# EarlyStopping counter: 4 out of 6
# Epoch 12/100, Train Loss: 2.1788, Val Loss: 2.3646, LR: 0.000002
# EarlyStopping counter: 5 out of 6
# Epoch 13/100, Train Loss: 2.1751, Val Loss: 2.3692, LR: 0.000060
# EarlyStopping counter: 6 out of 6
# Early stopping triggered
# [I 2025-01-07 01:48:01,338] Trial 4 finished with value: 4.004570484786037 and parameters: {'time2vec_dim': 30, 'hidden_dim': 32, 'batch_size': 32, 'learning_rate': 6.041607305846e-05, 'dropout': 0.43117418379101147, 'clip_grad_norm': 4.529379799205323, 'warmup_epochs': 3, 'patience': 6}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.7600, Val Loss: 7.7341, LR: 0.000128
# Epoch 2/100, Train Loss: 4.0104, Val Loss: 3.5578, LR: 0.000124
# Epoch 3/100, Train Loss: 2.9232, Val Loss: 3.3042, LR: 0.000115
# Epoch 4/100, Train Loss: 2.7381, Val Loss: 3.1337, LR: 0.000101
# Epoch 5/100, Train Loss: 2.5905, Val Loss: 2.7738, LR: 0.000084
# Epoch 6/100, Train Loss: 2.4597, Val Loss: 2.7021, LR: 0.000064
# Epoch 7/100, Train Loss: 2.4040, Val Loss: 2.6826, LR: 0.000045
# Epoch 8/100, Train Loss: 2.3713, Val Loss: 2.6922, LR: 0.000027
# EarlyStopping counter: 1 out of 15
# Epoch 9/100, Train Loss: 2.3499, Val Loss: 2.7020, LR: 0.000013
# EarlyStopping counter: 2 out of 15
# Epoch 10/100, Train Loss: 2.3401, Val Loss: 2.7129, LR: 0.000004
# EarlyStopping counter: 3 out of 15
# Epoch 11/100, Train Loss: 2.3347, Val Loss: 2.7093, LR: 0.000128
# EarlyStopping counter: 4 out of 15
# Epoch 12/100, Train Loss: 2.3199, Val Loss: 2.6039, LR: 0.000127
# Epoch 13/100, Train Loss: 2.2635, Val Loss: 2.4908, LR: 0.000124
# Epoch 14/100, Train Loss: 2.2167, Val Loss: 2.4794, LR: 0.000121
# Epoch 15/100, Train Loss: 2.1666, Val Loss: 2.4403, LR: 0.000115
# Epoch 16/100, Train Loss: 2.1296, Val Loss: 2.3457, LR: 0.000109
# Epoch 17/100, Train Loss: 2.0830, Val Loss: 2.3705, LR: 0.000101
# EarlyStopping counter: 1 out of 15
# Epoch 18/100, Train Loss: 2.0539, Val Loss: 2.3881, LR: 0.000093
# EarlyStopping counter: 2 out of 15
# Epoch 19/100, Train Loss: 2.0284, Val Loss: 2.3418, LR: 0.000084
# Epoch 20/100, Train Loss: 2.0096, Val Loss: 2.4641, LR: 0.000074
# EarlyStopping counter: 1 out of 15
# Epoch 21/100, Train Loss: 1.9913, Val Loss: 2.4757, LR: 0.000064
# EarlyStopping counter: 2 out of 15
# Epoch 22/100, Train Loss: 1.9670, Val Loss: 2.4898, LR: 0.000054
# EarlyStopping counter: 3 out of 15
# Epoch 23/100, Train Loss: 1.9544, Val Loss: 2.5548, LR: 0.000045
# EarlyStopping counter: 4 out of 15
# Epoch 24/100, Train Loss: 1.9448, Val Loss: 2.5004, LR: 0.000036
# EarlyStopping counter: 5 out of 15
# Epoch 25/100, Train Loss: 1.9359, Val Loss: 2.4865, LR: 0.000027
# EarlyStopping counter: 6 out of 15
# Epoch 26/100, Train Loss: 1.9278, Val Loss: 2.5136, LR: 0.000020
# EarlyStopping counter: 7 out of 15
# Epoch 27/100, Train Loss: 1.9235, Val Loss: 2.5129, LR: 0.000013
# EarlyStopping counter: 8 out of 15
# Epoch 28/100, Train Loss: 1.9189, Val Loss: 2.5278, LR: 0.000008
# EarlyStopping counter: 9 out of 15
# Epoch 29/100, Train Loss: 1.9168, Val Loss: 2.5066, LR: 0.000004
# EarlyStopping counter: 10 out of 15
# Epoch 30/100, Train Loss: 1.9154, Val Loss: 2.5170, LR: 0.000002
# EarlyStopping counter: 11 out of 15
# Epoch 31/100, Train Loss: 1.9143, Val Loss: 2.5226, LR: 0.000128
# EarlyStopping counter: 12 out of 15
# Epoch 32/100, Train Loss: 1.9195, Val Loss: 2.5743, LR: 0.000127
# EarlyStopping counter: 13 out of 15
# Epoch 33/100, Train Loss: 1.9117, Val Loss: 2.5957, LR: 0.000127
# EarlyStopping counter: 14 out of 15
# Epoch 34/100, Train Loss: 1.9016, Val Loss: 2.6548, LR: 0.000126
# EarlyStopping counter: 15 out of 15
# Early stopping triggered
# [I 2025-01-07 02:07:20,312] Trial 5 finished with value: 7.452126093291118 and parameters: {'time2vec_dim': 25, 'hidden_dim': 64, 'batch_size': 64, 'learning_rate': 0.00012752432901206136, 'dropout': 0.43723776532593284, 'clip_grad_norm': 2.9101573602111657, 'warmup_epochs': 1, 'patience': 15}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.9741, Val Loss: 8.0769, LR: 0.000009
# Epoch 2/100, Train Loss: 5.9169, Val Loss: 8.0075, LR: 0.000014
# Epoch 3/100, Train Loss: 5.8292, Val Loss: 7.8999, LR: 0.000019
# Epoch 4/100, Train Loss: 5.6712, Val Loss: 7.6653, LR: 0.000024
# Epoch 5/100, Train Loss: 5.3330, Val Loss: 7.2318, LR: 0.000029
# Epoch 6/100, Train Loss: 4.7955, Val Loss: 6.5896, LR: 0.000034
# Epoch 7/100, Train Loss: 4.1262, Val Loss: 5.7345, LR: 0.000033
# Epoch 8/100, Train Loss: 3.5057, Val Loss: 4.7605, LR: 0.000031
# Epoch 9/100, Train Loss: 3.1011, Val Loss: 3.8813, LR: 0.000027
# Epoch 10/100, Train Loss: 2.9831, Val Loss: 3.5738, LR: 0.000023
# Epoch 11/100, Train Loss: 2.9576, Val Loss: 3.5722, LR: 0.000018
# Epoch 12/100, Train Loss: 2.9446, Val Loss: 3.5308, LR: 0.000012
# Epoch 13/100, Train Loss: 2.9291, Val Loss: 3.5006, LR: 0.000008
# Epoch 14/100, Train Loss: 2.9208, Val Loss: 3.5069, LR: 0.000004
# EarlyStopping counter: 1 out of 15
# Epoch 15/100, Train Loss: 2.9149, Val Loss: 3.5022, LR: 0.000002
# EarlyStopping counter: 2 out of 15
# Epoch 16/100, Train Loss: 2.9138, Val Loss: 3.5008, LR: 0.000034
# EarlyStopping counter: 3 out of 15
# Epoch 17/100, Train Loss: 2.8990, Val Loss: 3.4645, LR: 0.000034
# Epoch 18/100, Train Loss: 2.8564, Val Loss: 3.3986, LR: 0.000033
# Epoch 19/100, Train Loss: 2.7672, Val Loss: 3.0963, LR: 0.000032
# Epoch 20/100, Train Loss: 2.6618, Val Loss: 2.7843, LR: 0.000031
# Epoch 21/100, Train Loss: 2.5842, Val Loss: 2.6790, LR: 0.000029
# Epoch 22/100, Train Loss: 2.5362, Val Loss: 2.6749, LR: 0.000027
# Epoch 23/100, Train Loss: 2.5047, Val Loss: 2.7062, LR: 0.000025
# EarlyStopping counter: 1 out of 15
# Epoch 24/100, Train Loss: 2.4905, Val Loss: 2.6737, LR: 0.000023
# Epoch 25/100, Train Loss: 2.4750, Val Loss: 2.5870, LR: 0.000020
# Epoch 26/100, Train Loss: 2.4539, Val Loss: 2.5787, LR: 0.000018
# Epoch 27/100, Train Loss: 2.4338, Val Loss: 2.5968, LR: 0.000015
# EarlyStopping counter: 1 out of 15
# Epoch 28/100, Train Loss: 2.4211, Val Loss: 2.5718, LR: 0.000012
# Epoch 29/100, Train Loss: 2.4125, Val Loss: 2.5534, LR: 0.000010
# Epoch 30/100, Train Loss: 2.4006, Val Loss: 2.5567, LR: 0.000008
# EarlyStopping counter: 1 out of 15
# Epoch 31/100, Train Loss: 2.3949, Val Loss: 2.5161, LR: 0.000006
# Epoch 32/100, Train Loss: 2.3924, Val Loss: 2.5340, LR: 0.000004
# EarlyStopping counter: 1 out of 15
# Epoch 33/100, Train Loss: 2.3903, Val Loss: 2.5375, LR: 0.000003
# EarlyStopping counter: 2 out of 15
# Epoch 34/100, Train Loss: 2.3845, Val Loss: 2.5335, LR: 0.000002
# EarlyStopping counter: 3 out of 15
# Epoch 35/100, Train Loss: 2.3821, Val Loss: 2.5219, LR: 0.000001
# EarlyStopping counter: 4 out of 15
# Epoch 36/100, Train Loss: 2.3783, Val Loss: 2.5296, LR: 0.000034
# EarlyStopping counter: 5 out of 15
# Epoch 37/100, Train Loss: 2.3566, Val Loss: 2.4663, LR: 0.000034
# Epoch 38/100, Train Loss: 2.3078, Val Loss: 2.4224, LR: 0.000034
# Epoch 39/100, Train Loss: 2.2866, Val Loss: 2.4211, LR: 0.000034
# Epoch 40/100, Train Loss: 2.2731, Val Loss: 2.4176, LR: 0.000033
# Epoch 41/100, Train Loss: 2.2630, Val Loss: 2.3704, LR: 0.000033
# Epoch 42/100, Train Loss: 2.2526, Val Loss: 2.3916, LR: 0.000032
# EarlyStopping counter: 1 out of 15
# Epoch 43/100, Train Loss: 2.2421, Val Loss: 2.4102, LR: 0.000032
# EarlyStopping counter: 2 out of 15
# Epoch 44/100, Train Loss: 2.2309, Val Loss: 2.4252, LR: 0.000031
# EarlyStopping counter: 3 out of 15
# Epoch 45/100, Train Loss: 2.2199, Val Loss: 2.3850, LR: 0.000030
# EarlyStopping counter: 4 out of 15
# Epoch 46/100, Train Loss: 2.2101, Val Loss: 2.4071, LR: 0.000029
# EarlyStopping counter: 5 out of 15
# Epoch 47/100, Train Loss: 2.2028, Val Loss: 2.3750, LR: 0.000028
# EarlyStopping counter: 6 out of 15
# Epoch 48/100, Train Loss: 2.1942, Val Loss: 2.3750, LR: 0.000027
# EarlyStopping counter: 7 out of 15
# Epoch 49/100, Train Loss: 2.1780, Val Loss: 2.4016, LR: 0.000026
# EarlyStopping counter: 8 out of 15
# Epoch 50/100, Train Loss: 2.1770, Val Loss: 2.4473, LR: 0.000025
# EarlyStopping counter: 9 out of 15
# Epoch 51/100, Train Loss: 2.1663, Val Loss: 2.3833, LR: 0.000024
# EarlyStopping counter: 10 out of 15
# Epoch 52/100, Train Loss: 2.1586, Val Loss: 2.3957, LR: 0.000023
# EarlyStopping counter: 11 out of 15
# Epoch 53/100, Train Loss: 2.1474, Val Loss: 2.4031, LR: 0.000021
# EarlyStopping counter: 12 out of 15
# Epoch 54/100, Train Loss: 2.1392, Val Loss: 2.3968, LR: 0.000020
# EarlyStopping counter: 13 out of 15
# Epoch 55/100, Train Loss: 2.1319, Val Loss: 2.4108, LR: 0.000019
# EarlyStopping counter: 14 out of 15
# Epoch 56/100, Train Loss: 2.1209, Val Loss: 2.4170, LR: 0.000018
# EarlyStopping counter: 15 out of 15
# Early stopping triggered
# [I 2025-01-07 02:41:22,292] Trial 6 finished with value: 2.653771587724596 and parameters: {'time2vec_dim': 27, 'hidden_dim': 96, 'batch_size': 128, 'learning_rate': 3.413248313200955e-05, 'dropout': 0.2240717283036307, 'clip_grad_norm': 2.8683053463677064, 'warmup_epochs': 6, 'patience': 15}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.9855, Val Loss: 8.2010, LR: 0.000013
# Epoch 2/100, Train Loss: 5.9113, Val Loss: 8.1162, LR: 0.000020
# Epoch 3/100, Train Loss: 5.7538, Val Loss: 7.8783, LR: 0.000027
# Epoch 4/100, Train Loss: 5.2796, Val Loss: 7.2634, LR: 0.000034
# Epoch 5/100, Train Loss: 4.4514, Val Loss: 6.1979, LR: 0.000041
# Epoch 6/100, Train Loss: 3.6354, Val Loss: 5.1152, LR: 0.000049
# Epoch 7/100, Train Loss: 3.1567, Val Loss: 4.1312, LR: 0.000056
# Epoch 8/100, Train Loss: 2.9885, Val Loss: 3.6594, LR: 0.000055
# Epoch 9/100, Train Loss: 2.8625, Val Loss: 3.5740, LR: 0.000051
# Epoch 10/100, Train Loss: 2.7852, Val Loss: 3.4547, LR: 0.000045
# Epoch 11/100, Train Loss: 2.7119, Val Loss: 3.3058, LR: 0.000037
# Epoch 12/100, Train Loss: 2.6278, Val Loss: 3.1120, LR: 0.000028
# Epoch 13/100, Train Loss: 2.5646, Val Loss: 3.0685, LR: 0.000020
# Epoch 14/100, Train Loss: 2.5211, Val Loss: 2.9904, LR: 0.000012
# Epoch 15/100, Train Loss: 2.4843, Val Loss: 2.9596, LR: 0.000006
# Epoch 16/100, Train Loss: 2.4674, Val Loss: 2.9331, LR: 0.000002
# Epoch 17/100, Train Loss: 2.4582, Val Loss: 2.9298, LR: 0.000056
# Epoch 18/100, Train Loss: 2.4172, Val Loss: 2.9094, LR: 0.000056
# Epoch 19/100, Train Loss: 2.3490, Val Loss: 2.8487, LR: 0.000055
# Epoch 20/100, Train Loss: 2.3070, Val Loss: 2.9114, LR: 0.000053
# EarlyStopping counter: 1 out of 8
# Epoch 21/100, Train Loss: 2.2669, Val Loss: 2.9439, LR: 0.000051
# EarlyStopping counter: 2 out of 8
# Epoch 22/100, Train Loss: 2.2235, Val Loss: 2.9854, LR: 0.000048
# EarlyStopping counter: 3 out of 8
# Epoch 23/100, Train Loss: 2.1964, Val Loss: 3.0060, LR: 0.000045
# EarlyStopping counter: 4 out of 8
# Epoch 24/100, Train Loss: 2.1797, Val Loss: 3.0013, LR: 0.000041
# EarlyStopping counter: 5 out of 8
# Epoch 25/100, Train Loss: 2.1657, Val Loss: 3.0474, LR: 0.000037
# EarlyStopping counter: 6 out of 8
# Epoch 26/100, Train Loss: 2.1554, Val Loss: 2.9584, LR: 0.000033
# EarlyStopping counter: 7 out of 8
# Epoch 27/100, Train Loss: 2.1433, Val Loss: 2.9720, LR: 0.000028
# EarlyStopping counter: 8 out of 8
# Early stopping triggered
# [I 2025-01-07 02:58:22,634] Trial 7 finished with value: 17.73750169276139 and parameters: {'time2vec_dim': 18, 'hidden_dim': 32, 'batch_size': 32, 'learning_rate': 5.584252208262511e-05, 'dropout': 0.4672781251255367, 'clip_grad_norm': 1.6228260187876205, 'warmup_epochs': 7, 'patience': 8}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.2176, Val Loss: 6.8419, LR: 0.000351
# Epoch 2/100, Train Loss: 3.0828, Val Loss: 2.8995, LR: 0.000343
# Epoch 3/100, Train Loss: 2.5763, Val Loss: 2.4697, LR: 0.000318
# Epoch 4/100, Train Loss: 2.3707, Val Loss: 2.5219, LR: 0.000279
# EarlyStopping counter: 1 out of 8
# Epoch 5/100, Train Loss: 2.2261, Val Loss: 2.4922, LR: 0.000230
# EarlyStopping counter: 2 out of 8
# Epoch 6/100, Train Loss: 2.1477, Val Loss: 2.4354, LR: 0.000176
# Epoch 7/100, Train Loss: 2.0987, Val Loss: 2.4428, LR: 0.000122
# EarlyStopping counter: 1 out of 8
# Epoch 8/100, Train Loss: 2.0668, Val Loss: 2.4370, LR: 0.000073
# EarlyStopping counter: 2 out of 8
# Epoch 9/100, Train Loss: 2.0411, Val Loss: 2.5006, LR: 0.000034
# EarlyStopping counter: 3 out of 8
# Epoch 10/100, Train Loss: 2.0249, Val Loss: 2.4794, LR: 0.000010
# EarlyStopping counter: 4 out of 8
# Epoch 11/100, Train Loss: 2.0163, Val Loss: 2.5098, LR: 0.000351
# EarlyStopping counter: 5 out of 8
# Epoch 12/100, Train Loss: 2.0320, Val Loss: 2.5997, LR: 0.000349
# EarlyStopping counter: 6 out of 8
# Epoch 13/100, Train Loss: 1.9929, Val Loss: 2.5717, LR: 0.000343
# EarlyStopping counter: 7 out of 8
# Epoch 14/100, Train Loss: 1.9673, Val Loss: 2.4341, LR: 0.000332
# Epoch 15/100, Train Loss: 1.9157, Val Loss: 2.4778, LR: 0.000318
# EarlyStopping counter: 1 out of 8
# Epoch 16/100, Train Loss: 1.8945, Val Loss: 2.4545, LR: 0.000300
# EarlyStopping counter: 2 out of 8
# Epoch 17/100, Train Loss: 1.8745, Val Loss: 2.4590, LR: 0.000279
# EarlyStopping counter: 3 out of 8
# Epoch 18/100, Train Loss: 1.8459, Val Loss: 2.5054, LR: 0.000256
# EarlyStopping counter: 4 out of 8
# Epoch 19/100, Train Loss: 1.8361, Val Loss: 2.5013, LR: 0.000230
# EarlyStopping counter: 5 out of 8
# Epoch 20/100, Train Loss: 1.8200, Val Loss: 2.6547, LR: 0.000204
# EarlyStopping counter: 6 out of 8
# Epoch 21/100, Train Loss: 1.8089, Val Loss: 2.6128, LR: 0.000176
# EarlyStopping counter: 7 out of 8
# Epoch 22/100, Train Loss: 1.8027, Val Loss: 2.5931, LR: 0.000149
# EarlyStopping counter: 8 out of 8
# Early stopping triggered
# [I 2025-01-07 03:12:28,389] Trial 8 finished with value: 10.78912201979374 and parameters: {'time2vec_dim': 18, 'hidden_dim': 96, 'batch_size': 64, 'learning_rate': 0.0003512548402019235, 'dropout': 0.17040881481161263, 'clip_grad_norm': 2.0865937364347187, 'warmup_epochs': 1, 'patience': 8}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.7471, Val Loss: 7.8330, LR: 0.000018
# Epoch 2/100, Train Loss: 5.5708, Val Loss: 7.5850, LR: 0.000028
# Epoch 3/100, Train Loss: 5.2238, Val Loss: 7.1373, LR: 0.000039
# Epoch 4/100, Train Loss: 4.6373, Val Loss: 6.3931, LR: 0.000049
# Epoch 5/100, Train Loss: 3.8739, Val Loss: 5.2779, LR: 0.000059
# Epoch 6/100, Train Loss: 3.1889, Val Loss: 3.7646, LR: 0.000069
# Epoch 7/100, Train Loss: 2.9693, Val Loss: 3.5025, LR: 0.000080
# Epoch 8/100, Train Loss: 2.9186, Val Loss: 3.4153, LR: 0.000078
# Epoch 9/100, Train Loss: 2.8269, Val Loss: 3.1209, LR: 0.000072
# Epoch 10/100, Train Loss: 2.6826, Val Loss: 2.8125, LR: 0.000063
# Epoch 11/100, Train Loss: 2.5268, Val Loss: 2.5580, LR: 0.000052
# Epoch 12/100, Train Loss: 2.4541, Val Loss: 2.6461, LR: 0.000040
# EarlyStopping counter: 1 out of 10
# Epoch 13/100, Train Loss: 2.4104, Val Loss: 2.7045, LR: 0.000028
# EarlyStopping counter: 2 out of 10
# Epoch 14/100, Train Loss: 2.3786, Val Loss: 2.6725, LR: 0.000017
# EarlyStopping counter: 3 out of 10
# Epoch 15/100, Train Loss: 2.3589, Val Loss: 2.6551, LR: 0.000009
# EarlyStopping counter: 4 out of 10
# Epoch 16/100, Train Loss: 2.3495, Val Loss: 2.6764, LR: 0.000003
# EarlyStopping counter: 5 out of 10
# Epoch 17/100, Train Loss: 2.3433, Val Loss: 2.6679, LR: 0.000080
# EarlyStopping counter: 6 out of 10
# Epoch 18/100, Train Loss: 2.3139, Val Loss: 2.5805, LR: 0.000079
# EarlyStopping counter: 7 out of 10
# Epoch 19/100, Train Loss: 2.2660, Val Loss: 2.6632, LR: 0.000078
# EarlyStopping counter: 8 out of 10
# Epoch 20/100, Train Loss: 2.2238, Val Loss: 2.6339, LR: 0.000075
# EarlyStopping counter: 9 out of 10
# Epoch 21/100, Train Loss: 2.1925, Val Loss: 2.6252, LR: 0.000072
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# [I 2025-01-07 03:24:59,315] Trial 9 finished with value: 4.769851307017105 and parameters: {'time2vec_dim': 31, 'hidden_dim': 160, 'batch_size': 256, 'learning_rate': 7.961813838745206e-05, 'dropout': 0.23340913672105523, 'clip_grad_norm': 3.74590650700203, 'warmup_epochs': 7, 'patience': 10}. Best is trial 0 with value: 2.401102453868018.
# Epoch 1/100, Train Loss: 5.8600, Val Loss: 7.9981, LR: 0.000012
# Epoch 2/100, Train Loss: 5.7300, Val Loss: 7.7779, LR: 0.000021
# Epoch 3/100, Train Loss: 5.3971, Val Loss: 7.3480, LR: 0.000021
# Epoch 4/100, Train Loss: 4.9332, Val Loss: 6.8817, LR: 0.000019
# Epoch 5/100, Train Loss: 4.4741, Val Loss: 6.3884, LR: 0.000017
# Epoch 6/100, Train Loss: 4.0367, Val Loss: 5.8489, LR: 0.000014
# Epoch 7/100, Train Loss: 3.6550, Val Loss: 5.3259, LR: 0.000011
# Epoch 8/100, Train Loss: 3.3952, Val Loss: 4.9115, LR: 0.000008
# Epoch 9/100, Train Loss: 3.2339, Val Loss: 4.6202, LR: 0.000005
# Epoch 10/100, Train Loss: 3.1464, Val Loss: 4.4272, LR: 0.000003
# Epoch 11/100, Train Loss: 3.0929, Val Loss: 4.3217, LR: 0.000001
# Epoch 12/100, Train Loss: 3.0766, Val Loss: 4.2728, LR: 0.000021
# Epoch 13/100, Train Loss: 3.0075, Val Loss: 3.7483, LR: 0.000021
# Epoch 14/100, Train Loss: 2.9537, Val Loss: 3.5477, LR: 0.000021
# Epoch 15/100, Train Loss: 2.9244, Val Loss: 3.4645, LR: 0.000020
# Epoch 16/100, Train Loss: 2.8633, Val Loss: 3.3818, LR: 0.000019
# Epoch 17/100, Train Loss: 2.7946, Val Loss: 3.2530, LR: 0.000018
# Epoch 18/100, Train Loss: 2.7231, Val Loss: 3.1549, LR: 0.000017
# Epoch 19/100, Train Loss: 2.6210, Val Loss: 2.9934, LR: 0.000016
# Epoch 20/100, Train Loss: 2.5007, Val Loss: 2.7036, LR: 0.000014
# Epoch 21/100, Train Loss: 2.3977, Val Loss: 2.5810, LR: 0.000013
# Epoch 22/100, Train Loss: 2.3392, Val Loss: 2.4466, LR: 0.000011
# Epoch 23/100, Train Loss: 2.2947, Val Loss: 2.4795, LR: 0.000010
# EarlyStopping counter: 1 out of 10
# Epoch 24/100, Train Loss: 2.2654, Val Loss: 2.5161, LR: 0.000008
# EarlyStopping counter: 2 out of 10
# Epoch 25/100, Train Loss: 2.2429, Val Loss: 2.4968, LR: 0.000007
# EarlyStopping counter: 3 out of 10
# Epoch 26/100, Train Loss: 2.2286, Val Loss: 2.5122, LR: 0.000005
# EarlyStopping counter: 4 out of 10
# Epoch 27/100, Train Loss: 2.2164, Val Loss: 2.4989, LR: 0.000004
# EarlyStopping counter: 5 out of 10
# Epoch 28/100, Train Loss: 2.2115, Val Loss: 2.4988, LR: 0.000003
# EarlyStopping counter: 6 out of 10
# Epoch 29/100, Train Loss: 2.2047, Val Loss: 2.5048, LR: 0.000002
# EarlyStopping counter: 7 out of 10
# Epoch 30/100, Train Loss: 2.2018, Val Loss: 2.5091, LR: 0.000001
# EarlyStopping counter: 8 out of 10
# Epoch 31/100, Train Loss: 2.1982, Val Loss: 2.5121, LR: 0.000001
# EarlyStopping counter: 9 out of 10
# Epoch 32/100, Train Loss: 2.1964, Val Loss: 2.5089, LR: 0.000021
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# [I 2025-01-07 03:47:22,833] Trial 10 finished with value: 2.0647142990640073 and parameters: {'time2vec_dim': 30, 'hidden_dim': 128, 'batch_size': 128, 'learning_rate': 2.1204563099530582e-05, 'dropout': 0.2526894373148839, 'clip_grad_norm': 4.5381490956788895, 'warmup_epochs': 2, 'patience': 10}. Best is trial 10 with value: 2.0647142990640073.
# Epoch 1/100, Train Loss: 5.7388, Val Loss: 7.9067, LR: 0.000008
# Epoch 2/100, Train Loss: 5.6890, Val Loss: 7.8356, LR: 0.000014
# Epoch 3/100, Train Loss: 5.5895, Val Loss: 7.7135, LR: 0.000019
# Epoch 4/100, Train Loss: 5.4329, Val Loss: 7.5372, LR: 0.000025
# Epoch 5/100, Train Loss: 5.2138, Val Loss: 7.2992, LR: 0.000024
# Epoch 6/100, Train Loss: 4.9632, Val Loss: 7.0482, LR: 0.000022
# Epoch 7/100, Train Loss: 4.7111, Val Loss: 6.7823, LR: 0.000020
# Epoch 8/100, Train Loss: 4.4607, Val Loss: 6.5363, LR: 0.000017
# Epoch 9/100, Train Loss: 4.2587, Val Loss: 6.3354, LR: 0.000013
# Epoch 10/100, Train Loss: 4.1137, Val Loss: 6.1779, LR: 0.000009
# Epoch 11/100, Train Loss: 4.0058, Val Loss: 6.0664, LR: 0.000006
# Epoch 12/100, Train Loss: 3.9394, Val Loss: 5.9968, LR: 0.000003
# Epoch 13/100, Train Loss: 3.8928, Val Loss: 5.9590, LR: 0.000002
# Epoch 14/100, Train Loss: 3.8740, Val Loss: 5.9409, LR: 0.000025
# Epoch 15/100, Train Loss: 3.7708, Val Loss: 5.6493, LR: 0.000025
# Epoch 16/100, Train Loss: 3.5712, Val Loss: 5.3241, LR: 0.000024
# Epoch 17/100, Train Loss: 3.3946, Val Loss: 4.9547, LR: 0.000023
# Epoch 18/100, Train Loss: 3.2346, Val Loss: 4.6173, LR: 0.000022
# Epoch 19/100, Train Loss: 3.1305, Val Loss: 4.3611, LR: 0.000021
# Epoch 20/100, Train Loss: 3.0717, Val Loss: 4.1710, LR: 0.000020
# Epoch 21/100, Train Loss: 3.0372, Val Loss: 4.0267, LR: 0.000018
# Epoch 22/100, Train Loss: 3.0170, Val Loss: 3.9211, LR: 0.000017
# Epoch 23/100, Train Loss: 3.0052, Val Loss: 3.8420, LR: 0.000015
# Epoch 24/100, Train Loss: 2.9910, Val Loss: 3.7788, LR: 0.000013
# Epoch 25/100, Train Loss: 2.9895, Val Loss: 3.7283, LR: 0.000011
# Epoch 26/100, Train Loss: 2.9805, Val Loss: 3.6906, LR: 0.000009
# Epoch 27/100, Train Loss: 2.9754, Val Loss: 3.6658, LR: 0.000007
# Epoch 28/100, Train Loss: 2.9679, Val Loss: 3.6454, LR: 0.000006
# Epoch 29/100, Train Loss: 2.9610, Val Loss: 3.6304, LR: 0.000004
# Epoch 30/100, Train Loss: 2.9556, Val Loss: 3.6214, LR: 0.000003
# Epoch 31/100, Train Loss: 2.9521, Val Loss: 3.6138, LR: 0.000002
# Epoch 32/100, Train Loss: 2.9532, Val Loss: 3.6095, LR: 0.000002
# Epoch 33/100, Train Loss: 2.9505, Val Loss: 3.6058, LR: 0.000001
# Epoch 34/100, Train Loss: 2.9483, Val Loss: 3.6035, LR: 0.000025
# Epoch 35/100, Train Loss: 2.9383, Val Loss: 3.5914, LR: 0.000025
# Epoch 36/100, Train Loss: 2.8867, Val Loss: 3.5017, LR: 0.000025
# Epoch 37/100, Train Loss: 2.8440, Val Loss: 3.4180, LR: 0.000024
# Epoch 38/100, Train Loss: 2.7976, Val Loss: 3.3252, LR: 0.000024
# Epoch 39/100, Train Loss: 2.7440, Val Loss: 3.1968, LR: 0.000024
# Epoch 40/100, Train Loss: 2.6893, Val Loss: 3.1153, LR: 0.000023
# Epoch 41/100, Train Loss: 2.6399, Val Loss: 3.0135, LR: 0.000023
# Epoch 42/100, Train Loss: 2.6052, Val Loss: 2.9049, LR: 0.000022
# Epoch 43/100, Train Loss: 2.5727, Val Loss: 2.8610, LR: 0.000022
# Epoch 44/100, Train Loss: 2.5488, Val Loss: 2.8285, LR: 0.000021
# Epoch 45/100, Train Loss: 2.5240, Val Loss: 2.7639, LR: 0.000021
# Epoch 46/100, Train Loss: 2.5060, Val Loss: 2.7505, LR: 0.000020
# Epoch 47/100, Train Loss: 2.4850, Val Loss: 2.7399, LR: 0.000019
# Epoch 48/100, Train Loss: 2.4681, Val Loss: 2.7454, LR: 0.000018
# EarlyStopping counter: 1 out of 9
# Epoch 49/100, Train Loss: 2.4564, Val Loss: 2.6893, LR: 0.000017
# Epoch 50/100, Train Loss: 2.4399, Val Loss: 2.6688, LR: 0.000017
# Epoch 51/100, Train Loss: 2.4263, Val Loss: 2.6741, LR: 0.000016
# EarlyStopping counter: 1 out of 9
# Epoch 52/100, Train Loss: 2.4152, Val Loss: 2.6704, LR: 0.000015
# EarlyStopping counter: 2 out of 9
# Epoch 53/100, Train Loss: 2.4010, Val Loss: 2.6644, LR: 0.000014
# Epoch 54/100, Train Loss: 2.3901, Val Loss: 2.6430, LR: 0.000013
# Epoch 55/100, Train Loss: 2.3800, Val Loss: 2.6574, LR: 0.000012
# EarlyStopping counter: 1 out of 9
# Epoch 56/100, Train Loss: 2.3708, Val Loss: 2.6515, LR: 0.000011
# EarlyStopping counter: 2 out of 9
# Epoch 57/100, Train Loss: 2.3602, Val Loss: 2.6457, LR: 0.000010
# EarlyStopping counter: 3 out of 9
# Epoch 58/100, Train Loss: 2.3513, Val Loss: 2.6469, LR: 0.000009
# EarlyStopping counter: 4 out of 9
# Epoch 59/100, Train Loss: 2.3468, Val Loss: 2.6436, LR: 0.000008
# EarlyStopping counter: 5 out of 9
# Epoch 60/100, Train Loss: 2.3402, Val Loss: 2.6460, LR: 0.000007
# EarlyStopping counter: 6 out of 9
# Epoch 61/100, Train Loss: 2.3312, Val Loss: 2.6424, LR: 0.000007
# Epoch 62/100, Train Loss: 2.3309, Val Loss: 2.6437, LR: 0.000006
# EarlyStopping counter: 1 out of 9
# Epoch 63/100, Train Loss: 2.3261, Val Loss: 2.6473, LR: 0.000005
# EarlyStopping counter: 2 out of 9
# Epoch 64/100, Train Loss: 2.3224, Val Loss: 2.6477, LR: 0.000004
# EarlyStopping counter: 3 out of 9
# Epoch 65/100, Train Loss: 2.3196, Val Loss: 2.6449, LR: 0.000004
# EarlyStopping counter: 4 out of 9
# Epoch 66/100, Train Loss: 2.3163, Val Loss: 2.6438, LR: 0.000003
# EarlyStopping counter: 5 out of 9
# Epoch 67/100, Train Loss: 2.3165, Val Loss: 2.6412, LR: 0.000003
# Epoch 68/100, Train Loss: 2.3160, Val Loss: 2.6428, LR: 0.000002
# EarlyStopping counter: 1 out of 9
# Epoch 69/100, Train Loss: 2.3143, Val Loss: 2.6414, LR: 0.000002
# EarlyStopping counter: 2 out of 9
# Epoch 70/100, Train Loss: 2.3131, Val Loss: 2.6440, LR: 0.000002
# EarlyStopping counter: 3 out of 9
# Epoch 71/100, Train Loss: 2.3125, Val Loss: 2.6417, LR: 0.000001
# EarlyStopping counter: 4 out of 9
# Epoch 72/100, Train Loss: 2.3117, Val Loss: 2.6400, LR: 0.000001
# Epoch 73/100, Train Loss: 2.3118, Val Loss: 2.6400, LR: 0.000001
# EarlyStopping counter: 1 out of 9
# Epoch 74/100, Train Loss: 2.3100, Val Loss: 2.6403, LR: 0.000025
# EarlyStopping counter: 2 out of 9
# Epoch 75/100, Train Loss: 2.3044, Val Loss: 2.6566, LR: 0.000025
# EarlyStopping counter: 3 out of 9
# Epoch 76/100, Train Loss: 2.2902, Val Loss: 2.6210, LR: 0.000025
# Epoch 77/100, Train Loss: 2.2777, Val Loss: 2.6293, LR: 0.000025
# EarlyStopping counter: 1 out of 9
# Epoch 78/100, Train Loss: 2.2676, Val Loss: 2.6033, LR: 0.000025
# Epoch 79/100, Train Loss: 2.2550, Val Loss: 2.6223, LR: 0.000025
# EarlyStopping counter: 1 out of 9
# Epoch 80/100, Train Loss: 2.2442, Val Loss: 2.6094, LR: 0.000024
# EarlyStopping counter: 2 out of 9
# Epoch 81/100, Train Loss: 2.2396, Val Loss: 2.6268, LR: 0.000024
# EarlyStopping counter: 3 out of 9
# Epoch 82/100, Train Loss: 2.2250, Val Loss: 2.6153, LR: 0.000024
# EarlyStopping counter: 4 out of 9
# Epoch 83/100, Train Loss: 2.2151, Val Loss: 2.6245, LR: 0.000024
# EarlyStopping counter: 5 out of 9
# Epoch 84/100, Train Loss: 2.2047, Val Loss: 2.6336, LR: 0.000024
# EarlyStopping counter: 6 out of 9
# Epoch 85/100, Train Loss: 2.1895, Val Loss: 2.6176, LR: 0.000024
# EarlyStopping counter: 7 out of 9
# Epoch 86/100, Train Loss: 2.1781, Val Loss: 2.6281, LR: 0.000023
# EarlyStopping counter: 8 out of 9
# Epoch 87/100, Train Loss: 2.1717, Val Loss: 2.6247, LR: 0.000023
# EarlyStopping counter: 9 out of 9
# Early stopping triggered
# [I 2025-01-07 04:28:22,016] Trial 11 finished with value: 2.9588903408153784 and parameters: {'time2vec_dim': 24, 'hidden_dim': 64, 'batch_size': 128, 'learning_rate': 2.4758151409814634e-05, 'dropout': 0.256945414511525, 'clip_grad_norm': 4.206122367939422, 'warmup_epochs': 4, 'patience': 9}. Best is trial 10 with value: 2.0647142990640073.
# Epoch 1/100, Train Loss: 5.9984, Val Loss: 8.0700, LR: 0.000011
# Epoch 2/100, Train Loss: 5.8501, Val Loss: 7.8539, LR: 0.000020
# Epoch 3/100, Train Loss: 5.4240, Val Loss: 7.2054, LR: 0.000020
# Epoch 4/100, Train Loss: 4.7406, Val Loss: 6.5107, LR: 0.000019
# Epoch 5/100, Train Loss: 4.1467, Val Loss: 5.8910, LR: 0.000016
# Epoch 6/100, Train Loss: 3.7078, Val Loss: 5.3228, LR: 0.000014
# Epoch 7/100, Train Loss: 3.3963, Val Loss: 4.8333, LR: 0.000011
# Epoch 8/100, Train Loss: 3.2009, Val Loss: 4.4151, LR: 0.000008
# Epoch 9/100, Train Loss: 3.0778, Val Loss: 4.1133, LR: 0.000005
# Epoch 10/100, Train Loss: 3.0240, Val Loss: 3.9412, LR: 0.000003
# Epoch 11/100, Train Loss: 3.0000, Val Loss: 3.8611, LR: 0.000001
# Epoch 12/100, Train Loss: 2.9865, Val Loss: 3.8240, LR: 0.000020
# Epoch 13/100, Train Loss: 2.9656, Val Loss: 3.5140, LR: 0.000020
# Epoch 14/100, Train Loss: 2.9427, Val Loss: 3.4460, LR: 0.000020
# Epoch 15/100, Train Loss: 2.9005, Val Loss: 3.3863, LR: 0.000019
# Epoch 16/100, Train Loss: 2.8366, Val Loss: 3.2833, LR: 0.000019
# Epoch 17/100, Train Loss: 2.7763, Val Loss: 3.1777, LR: 0.000018
# Epoch 18/100, Train Loss: 2.7188, Val Loss: 3.0621, LR: 0.000016
# Epoch 19/100, Train Loss: 2.6669, Val Loss: 2.9925, LR: 0.000015
# Epoch 20/100, Train Loss: 2.6143, Val Loss: 2.9199, LR: 0.000014
# Epoch 21/100, Train Loss: 2.5692, Val Loss: 2.8354, LR: 0.000012
# Epoch 22/100, Train Loss: 2.5327, Val Loss: 2.8371, LR: 0.000011
# EarlyStopping counter: 1 out of 8
# Epoch 23/100, Train Loss: 2.5061, Val Loss: 2.8072, LR: 0.000009
# Epoch 24/100, Train Loss: 2.4850, Val Loss: 2.8019, LR: 0.000008
# Epoch 25/100, Train Loss: 2.4663, Val Loss: 2.7774, LR: 0.000006
# Epoch 26/100, Train Loss: 2.4514, Val Loss: 2.7539, LR: 0.000005
# Epoch 27/100, Train Loss: 2.4408, Val Loss: 2.7507, LR: 0.000004
# Epoch 28/100, Train Loss: 2.4338, Val Loss: 2.7349, LR: 0.000003
# Epoch 29/100, Train Loss: 2.4296, Val Loss: 2.7303, LR: 0.000002
# Epoch 30/100, Train Loss: 2.4249, Val Loss: 2.7163, LR: 0.000001
# Epoch 31/100, Train Loss: 2.4239, Val Loss: 2.7199, LR: 0.000001
# EarlyStopping counter: 1 out of 8
# Epoch 32/100, Train Loss: 2.4216, Val Loss: 2.7198, LR: 0.000020
# EarlyStopping counter: 2 out of 8
# Epoch 33/100, Train Loss: 2.4089, Val Loss: 2.6809, LR: 0.000020
# Epoch 34/100, Train Loss: 2.3882, Val Loss: 2.6628, LR: 0.000020
# Epoch 35/100, Train Loss: 2.3649, Val Loss: 2.6112, LR: 0.000020
# Epoch 36/100, Train Loss: 2.3450, Val Loss: 2.6251, LR: 0.000020
# EarlyStopping counter: 1 out of 8
# Epoch 37/100, Train Loss: 2.3213, Val Loss: 2.5625, LR: 0.000020
# Epoch 38/100, Train Loss: 2.3028, Val Loss: 2.6169, LR: 0.000019
# EarlyStopping counter: 1 out of 8
# Epoch 39/100, Train Loss: 2.2874, Val Loss: 2.5688, LR: 0.000019
# EarlyStopping counter: 2 out of 8
# Epoch 40/100, Train Loss: 2.2684, Val Loss: 2.6335, LR: 0.000019
# EarlyStopping counter: 3 out of 8
# Epoch 41/100, Train Loss: 2.2503, Val Loss: 2.6386, LR: 0.000018
# EarlyStopping counter: 4 out of 8
# Epoch 42/100, Train Loss: 2.2386, Val Loss: 2.5684, LR: 0.000018
# EarlyStopping counter: 5 out of 8
# Epoch 43/100, Train Loss: 2.2251, Val Loss: 2.6059, LR: 0.000017
# EarlyStopping counter: 6 out of 8
# Epoch 44/100, Train Loss: 2.2133, Val Loss: 2.5885, LR: 0.000016
# EarlyStopping counter: 7 out of 8
# Epoch 45/100, Train Loss: 2.2007, Val Loss: 2.6073, LR: 0.000016
# EarlyStopping counter: 8 out of 8
# Early stopping triggered
# [I 2025-01-07 05:04:45,572] Trial 12 finished with value: 5.3832496106812044 and parameters: {'time2vec_dim': 30, 'hidden_dim': 160, 'batch_size': 128, 'learning_rate': 2.0478518974730774e-05, 'dropout': 0.2528552105258274, 'clip_grad_norm': 4.9697030472081005, 'warmup_epochs': 2, 'patience': 8}. Best is trial 10 with value: 2.0647142990640073.
# Epoch 1/100, Train Loss: 5.7404, Val Loss: 7.9126, LR: 0.000003
# Epoch 2/100, Train Loss: 5.7168, Val Loss: 7.8722, LR: 0.000005
# Epoch 3/100, Train Loss: 5.6586, Val Loss: 7.8056, LR: 0.000007
# Epoch 4/100, Train Loss: 5.5853, Val Loss: 7.7172, LR: 0.000009
# Epoch 5/100, Train Loss: 5.4812, Val Loss: 7.6026, LR: 0.000010
# Epoch 6/100, Train Loss: 5.3549, Val Loss: 7.4704, LR: 0.000010
# Epoch 7/100, Train Loss: 5.2181, Val Loss: 7.3372, LR: 0.000009
# Epoch 8/100, Train Loss: 5.0664, Val Loss: 7.1908, LR: 0.000008
# Epoch 9/100, Train Loss: 4.9071, Val Loss: 7.0172, LR: 0.000007
# Epoch 10/100, Train Loss: 4.7263, Val Loss: 6.8355, LR: 0.000006
# Epoch 11/100, Train Loss: 4.5625, Val Loss: 6.6849, LR: 0.000004
# Epoch 12/100, Train Loss: 4.4385, Val Loss: 6.5749, LR: 0.000003
# Epoch 13/100, Train Loss: 4.3552, Val Loss: 6.5008, LR: 0.000002
# Epoch 14/100, Train Loss: 4.2967, Val Loss: 6.4541, LR: 0.000001
# Epoch 15/100, Train Loss: 4.2750, Val Loss: 6.4244, LR: 0.000010
# Epoch 16/100, Train Loss: 4.1462, Val Loss: 6.1657, LR: 0.000010
# Epoch 17/100, Train Loss: 3.9337, Val Loss: 5.8791, LR: 0.000010
# Epoch 18/100, Train Loss: 3.7145, Val Loss: 5.5648, LR: 0.000010
# Epoch 19/100, Train Loss: 3.5188, Val Loss: 5.2365, LR: 0.000009
# Epoch 20/100, Train Loss: 3.3459, Val Loss: 4.9006, LR: 0.000009
# Epoch 21/100, Train Loss: 3.2015, Val Loss: 4.5610, LR: 0.000008
# Epoch 22/100, Train Loss: 3.0864, Val Loss: 4.2551, LR: 0.000008
# Epoch 23/100, Train Loss: 3.0211, Val Loss: 4.0348, LR: 0.000007
# Epoch 24/100, Train Loss: 2.9823, Val Loss: 3.8885, LR: 0.000006
# Epoch 25/100, Train Loss: 2.9593, Val Loss: 3.7922, LR: 0.000006
# Epoch 26/100, Train Loss: 2.9490, Val Loss: 3.7264, LR: 0.000005
# Epoch 27/100, Train Loss: 2.9379, Val Loss: 3.6770, LR: 0.000004
# Epoch 28/100, Train Loss: 2.9302, Val Loss: 3.6484, LR: 0.000004
# Epoch 29/100, Train Loss: 2.9240, Val Loss: 3.6231, LR: 0.000003
# Epoch 30/100, Train Loss: 2.9150, Val Loss: 3.6082, LR: 0.000002
# Epoch 31/100, Train Loss: 2.9101, Val Loss: 3.5951, LR: 0.000002
# Epoch 32/100, Train Loss: 2.9052, Val Loss: 3.5850, LR: 0.000002
# Epoch 33/100, Train Loss: 2.9018, Val Loss: 3.5764, LR: 0.000001
# ...
# EarlyStopping counter: 9 out of 10
# Epoch 45/100, Train Loss: 2.0671, Val Loss: 2.2683, LR: 0.000016
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Epoch 1/100, Train Loss: 6.1411, Val Loss: 7.8544, LR: 0.000012
# Epoch 2/100, Train Loss: 5.9790, Val Loss: 7.5532, LR: 0.000021
# Epoch 3/100, Train Loss: 5.4624, Val Loss: 6.8318, LR: 0.000021
# Epoch 4/100, Train Loss: 4.7692, Val Loss: 6.1704, LR: 0.000019
# Epoch 5/100, Train Loss: 4.1886, Val Loss: 5.5465, LR: 0.000017
# Epoch 6/100, Train Loss: 3.7393, Val Loss: 4.9445, LR: 0.000014
# Epoch 7/100, Train Loss: 3.4095, Val Loss: 4.3955, LR: 0.000011
# Epoch 8/100, Train Loss: 3.2007, Val Loss: 3.9535, LR: 0.000008
# Epoch 9/100, Train Loss: 3.0869, Val Loss: 3.6801, LR: 0.000005
# Epoch 10/100, Train Loss: 3.0424, Val Loss: 3.5395, LR: 0.000003
# Epoch 11/100, Train Loss: 3.0182, Val Loss: 3.4719, LR: 0.000001
# Epoch 12/100, Train Loss: 3.0159, Val Loss: 3.4422, LR: 0.000021
# Epoch 13/100, Train Loss: 2.9875, Val Loss: 3.1671, LR: 0.000021
# Epoch 14/100, Train Loss: 2.9587, Val Loss: 3.0686, LR: 0.000021
# Epoch 15/100, Train Loss: 2.9044, Val Loss: 2.9560, LR: 0.000020
# Epoch 16/100, Train Loss: 2.8009, Val Loss: 2.7283, LR: 0.000019
# Epoch 17/100, Train Loss: 2.6545, Val Loss: 2.4502, LR: 0.000018
# Epoch 18/100, Train Loss: 2.5025, Val Loss: 2.2440, LR: 0.000017
# Epoch 19/100, Train Loss: 2.3773, Val Loss: 2.1712, LR: 0.000016
# Epoch 20/100, Train Loss: 2.3000, Val Loss: 2.1898, LR: 0.000014
# EarlyStopping counter: 1 out of 10
# Epoch 21/100, Train Loss: 2.2541, Val Loss: 2.1778, LR: 0.000013
# EarlyStopping counter: 2 out of 10
# Epoch 22/100, Train Loss: 2.2246, Val Loss: 2.1922, LR: 0.000011
# EarlyStopping counter: 3 out of 10
# Epoch 23/100, Train Loss: 2.1948, Val Loss: 2.2111, LR: 0.000010
# EarlyStopping counter: 4 out of 10
# Epoch 24/100, Train Loss: 2.1741, Val Loss: 2.2315, LR: 0.000008
# EarlyStopping counter: 5 out of 10
# Epoch 25/100, Train Loss: 2.1574, Val Loss: 2.2558, LR: 0.000007
# EarlyStopping counter: 6 out of 10
# Epoch 26/100, Train Loss: 2.1517, Val Loss: 2.2559, LR: 0.000005
# EarlyStopping counter: 7 out of 10
# Epoch 27/100, Train Loss: 2.1367, Val Loss: 2.2673, LR: 0.000004
# EarlyStopping counter: 8 out of 10
# Epoch 28/100, Train Loss: 2.1300, Val Loss: 2.2734, LR: 0.000003
# EarlyStopping counter: 9 out of 10
# Epoch 29/100, Train Loss: 2.1279, Val Loss: 2.2831, LR: 0.000002
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Epoch 1/100, Train Loss: 5.8228, Val Loss: 7.6265, LR: 0.000012
# Epoch 2/100, Train Loss: 5.6765, Val Loss: 7.3705, LR: 0.000021
# Epoch 3/100, Train Loss: 5.2857, Val Loss: 6.8557, LR: 0.000021
# Epoch 4/100, Train Loss: 4.7560, Val Loss: 6.2991, LR: 0.000019
# Epoch 5/100, Train Loss: 4.2408, Val Loss: 5.7139, LR: 0.000017
# Epoch 6/100, Train Loss: 3.7834, Val Loss: 5.1194, LR: 0.000014
# Epoch 7/100, Train Loss: 3.4474, Val Loss: 4.5772, LR: 0.000011
# Epoch 8/100, Train Loss: 3.2288, Val Loss: 4.1560, LR: 0.000008
# Epoch 9/100, Train Loss: 3.1161, Val Loss: 3.8846, LR: 0.000005
# Epoch 10/100, Train Loss: 3.0687, Val Loss: 3.7411, LR: 0.000003
# Epoch 11/100, Train Loss: 3.0457, Val Loss: 3.6727, LR: 0.000001
# Epoch 12/100, Train Loss: 3.0417, Val Loss: 3.6400, LR: 0.000021
# Epoch 13/100, Train Loss: 3.0091, Val Loss: 3.3173, LR: 0.000021
# Epoch 14/100, Train Loss: 2.9689, Val Loss: 3.1688, LR: 0.000021
# Epoch 15/100, Train Loss: 2.9205, Val Loss: 3.0163, LR: 0.000020
# Epoch 16/100, Train Loss: 2.8448, Val Loss: 2.8993, LR: 0.000019
# Epoch 17/100, Train Loss: 2.7598, Val Loss: 2.7583, LR: 0.000018
# Epoch 18/100, Train Loss: 2.6680, Val Loss: 2.6427, LR: 0.000017
# Epoch 19/100, Train Loss: 2.5781, Val Loss: 2.5096, LR: 0.000016
# Epoch 20/100, Train Loss: 2.5028, Val Loss: 2.3835, LR: 0.000014
# Epoch 21/100, Train Loss: 2.4397, Val Loss: 2.3494, LR: 0.000013
# Epoch 22/100, Train Loss: 2.3774, Val Loss: 2.2670, LR: 0.000011
# Epoch 23/100, Train Loss: 2.3391, Val Loss: 2.2392, LR: 0.000010
# Epoch 24/100, Train Loss: 2.3053, Val Loss: 2.2217, LR: 0.000008
# Epoch 25/100, Train Loss: 2.2847, Val Loss: 2.2191, LR: 0.000007
# Epoch 26/100, Train Loss: 2.2688, Val Loss: 2.2050, LR: 0.000005
# Epoch 27/100, Train Loss: 2.2539, Val Loss: 2.2140, LR: 0.000004
# EarlyStopping counter: 1 out of 10
# Epoch 28/100, Train Loss: 2.2454, Val Loss: 2.2142, LR: 0.000003
# EarlyStopping counter: 2 out of 10
# Epoch 29/100, Train Loss: 2.2412, Val Loss: 2.2151, LR: 0.000002
# EarlyStopping counter: 3 out of 10
# Epoch 30/100, Train Loss: 2.2328, Val Loss: 2.2165, LR: 0.000001
# EarlyStopping counter: 4 out of 10
# Epoch 31/100, Train Loss: 2.2298, Val Loss: 2.2201, LR: 0.000001
# EarlyStopping counter: 5 out of 10
# Epoch 32/100, Train Loss: 2.2284, Val Loss: 2.2199, LR: 0.000021
# EarlyStopping counter: 6 out of 10
# Epoch 33/100, Train Loss: 2.2098, Val Loss: 2.2409, LR: 0.000021
# EarlyStopping counter: 7 out of 10
# Epoch 34/100, Train Loss: 2.1851, Val Loss: 2.2795, LR: 0.000021
# EarlyStopping counter: 8 out of 10
# Epoch 35/100, Train Loss: 2.1519, Val Loss: 2.3309, LR: 0.000021
# EarlyStopping counter: 9 out of 10
# Epoch 36/100, Train Loss: 2.1335, Val Loss: 2.3800, LR: 0.000021
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Epoch 1/100, Train Loss: 5.5833, Val Loss: 7.5820, LR: 0.000012
# Epoch 2/100, Train Loss: 5.4452, Val Loss: 7.3578, LR: 0.000021
# Epoch 3/100, Train Loss: 5.1155, Val Loss: 6.9338, LR: 0.000021
# Epoch 4/100, Train Loss: 4.6815, Val Loss: 6.4609, LR: 0.000019
# Epoch 5/100, Train Loss: 4.2270, Val Loss: 5.9196, LR: 0.000017
# Epoch 6/100, Train Loss: 3.7932, Val Loss: 5.3494, LR: 0.000014
# Epoch 7/100, Train Loss: 3.4654, Val Loss: 4.8422, LR: 0.000011
# Epoch 8/100, Train Loss: 3.2513, Val Loss: 4.4324, LR: 0.000008
# Epoch 9/100, Train Loss: 3.1248, Val Loss: 4.1524, LR: 0.000005
# Epoch 10/100, Train Loss: 3.0631, Val Loss: 3.9951, LR: 0.000003
# Epoch 11/100, Train Loss: 3.0393, Val Loss: 3.9153, LR: 0.000001
# Epoch 12/100, Train Loss: 3.0226, Val Loss: 3.8798, LR: 0.000021
# Epoch 13/100, Train Loss: 2.9930, Val Loss: 3.5496, LR: 0.000021
# Epoch 14/100, Train Loss: 2.9440, Val Loss: 3.4440, LR: 0.000021
# Epoch 15/100, Train Loss: 2.8948, Val Loss: 3.2942, LR: 0.000020
# Epoch 16/100, Train Loss: 2.8220, Val Loss: 3.1339, LR: 0.000019
# Epoch 17/100, Train Loss: 2.6970, Val Loss: 2.8578, LR: 0.000018
# Epoch 18/100, Train Loss: 2.5285, Val Loss: 2.5313, LR: 0.000017
# Epoch 19/100, Train Loss: 2.3939, Val Loss: 2.4161, LR: 0.000016
# Epoch 20/100, Train Loss: 2.3276, Val Loss: 2.4300, LR: 0.000014
# EarlyStopping counter: 1 out of 10
# Epoch 21/100, Train Loss: 2.2789, Val Loss: 2.3839, LR: 0.000013
# Epoch 22/100, Train Loss: 2.2362, Val Loss: 2.3942, LR: 0.000011
# EarlyStopping counter: 1 out of 10
# Epoch 23/100, Train Loss: 2.2062, Val Loss: 2.3923, LR: 0.000010
# EarlyStopping counter: 2 out of 10
# Epoch 24/100, Train Loss: 2.1901, Val Loss: 2.3961, LR: 0.000008
# EarlyStopping counter: 3 out of 10
# Epoch 25/100, Train Loss: 2.1766, Val Loss: 2.3834, LR: 0.000007
# Epoch 26/100, Train Loss: 2.1665, Val Loss: 2.4034, LR: 0.000005
# EarlyStopping counter: 1 out of 10
# Epoch 27/100, Train Loss: 2.1600, Val Loss: 2.3963, LR: 0.000004
# EarlyStopping counter: 2 out of 10
# Epoch 28/100, Train Loss: 2.1533, Val Loss: 2.3993, LR: 0.000003
# EarlyStopping counter: 3 out of 10
# Epoch 29/100, Train Loss: 2.1502, Val Loss: 2.3921, LR: 0.000002
# EarlyStopping counter: 4 out of 10
# Epoch 30/100, Train Loss: 2.1479, Val Loss: 2.3933, LR: 0.000001
# EarlyStopping counter: 5 out of 10
# Epoch 31/100, Train Loss: 2.1448, Val Loss: 2.3911, LR: 0.000001
# EarlyStopping counter: 6 out of 10
# Epoch 32/100, Train Loss: 2.1434, Val Loss: 2.3902, LR: 0.000021
# EarlyStopping counter: 7 out of 10
# Epoch 33/100, Train Loss: 2.1362, Val Loss: 2.4096, LR: 0.000021
# EarlyStopping counter: 8 out of 10
# Epoch 34/100, Train Loss: 2.1209, Val Loss: 2.3878, LR: 0.000021
# EarlyStopping counter: 9 out of 10
# Epoch 35/100, Train Loss: 2.1043, Val Loss: 2.3836, LR: 0.000021
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Epoch 1/100, Train Loss: 5.9194, Val Loss: 8.1350, LR: 0.000012
# Epoch 2/100, Train Loss: 5.7916, Val Loss: 7.9091, LR: 0.000021
# Epoch 3/100, Train Loss: 5.4312, Val Loss: 7.3983, LR: 0.000021
# Epoch 4/100, Train Loss: 4.7685, Val Loss: 6.6015, LR: 0.000019
# Epoch 5/100, Train Loss: 4.0280, Val Loss: 5.7382, LR: 0.000017
# Epoch 6/100, Train Loss: 3.4565, Val Loss: 4.8855, LR: 0.000014
# Epoch 7/100, Train Loss: 3.1297, Val Loss: 4.1753, LR: 0.000011
# Epoch 8/100, Train Loss: 3.0006, Val Loss: 3.8133, LR: 0.000008
# Epoch 9/100, Train Loss: 2.9630, Val Loss: 3.6864, LR: 0.000005
# Epoch 10/100, Train Loss: 2.9523, Val Loss: 3.6405, LR: 0.000003
# Epoch 11/100, Train Loss: 2.9495, Val Loss: 3.6238, LR: 0.000001
# Epoch 12/100, Train Loss: 2.9453, Val Loss: 3.6152, LR: 0.000021
# Epoch 13/100, Train Loss: 2.9206, Val Loss: 3.5225, LR: 0.000021
# Epoch 14/100, Train Loss: 2.8689, Val Loss: 3.4179, LR: 0.000021
# Epoch 15/100, Train Loss: 2.7940, Val Loss: 3.3419, LR: 0.000020
# Epoch 16/100, Train Loss: 2.7042, Val Loss: 3.1690, LR: 0.000019
# Epoch 17/100, Train Loss: 2.6185, Val Loss: 3.0303, LR: 0.000018
# Epoch 18/100, Train Loss: 2.5380, Val Loss: 2.8760, LR: 0.000017
# Epoch 19/100, Train Loss: 2.4870, Val Loss: 2.7274, LR: 0.000016
# Epoch 20/100, Train Loss: 2.4429, Val Loss: 2.6551, LR: 0.000014
# Epoch 21/100, Train Loss: 2.4012, Val Loss: 2.5692, LR: 0.000013
# Epoch 22/100, Train Loss: 2.3699, Val Loss: 2.5102, LR: 0.000011
# Epoch 23/100, Train Loss: 2.3447, Val Loss: 2.4700, LR: 0.000010
# Epoch 24/100, Train Loss: 2.3223, Val Loss: 2.3918, LR: 0.000008
# Epoch 25/100, Train Loss: 2.3042, Val Loss: 2.3825, LR: 0.000007
# Epoch 26/100, Train Loss: 2.2898, Val Loss: 2.3460, LR: 0.000005
# Epoch 27/100, Train Loss: 2.2804, Val Loss: 2.3288, LR: 0.000004
# Epoch 28/100, Train Loss: 2.2693, Val Loss: 2.3078, LR: 0.000003
# Epoch 29/100, Train Loss: 2.2623, Val Loss: 2.3040, LR: 0.000002
# Epoch 30/100, Train Loss: 2.2605, Val Loss: 2.2995, LR: 0.000001
# Epoch 31/100, Train Loss: 2.2556, Val Loss: 2.2913, LR: 0.000001
# Epoch 32/100, Train Loss: 2.2524, Val Loss: 2.2858, LR: 0.000021
# Epoch 33/100, Train Loss: 2.2405, Val Loss: 2.2446, LR: 0.000021
# Epoch 34/100, Train Loss: 2.2147, Val Loss: 2.2239, LR: 0.000021
# Epoch 35/100, Train Loss: 2.1889, Val Loss: 2.1863, LR: 0.000021
# Epoch 36/100, Train Loss: 2.1670, Val Loss: 2.1618, LR: 0.000021
# Epoch 37/100, Train Loss: 2.1451, Val Loss: 2.1436, LR: 0.000020
# Epoch 38/100, Train Loss: 2.1239, Val Loss: 2.1304, LR: 0.000020
# Epoch 39/100, Train Loss: 2.1006, Val Loss: 2.1263, LR: 0.000020
# Epoch 40/100, Train Loss: 2.0800, Val Loss: 2.1366, LR: 0.000019
# EarlyStopping counter: 1 out of 10
# Epoch 41/100, Train Loss: 2.0589, Val Loss: 2.1351, LR: 0.000019
# EarlyStopping counter: 2 out of 10
# Epoch 42/100, Train Loss: 2.0407, Val Loss: 2.1428, LR: 0.000018
# EarlyStopping counter: 3 out of 10
# Epoch 43/100, Train Loss: 2.0254, Val Loss: 2.1474, LR: 0.000018
# EarlyStopping counter: 4 out of 10
# Epoch 44/100, Train Loss: 2.0126, Val Loss: 2.1583, LR: 0.000017
# EarlyStopping counter: 5 out of 10
# Epoch 45/100, Train Loss: 2.0011, Val Loss: 2.1583, LR: 0.000016
# EarlyStopping counter: 6 out of 10
# Epoch 46/100, Train Loss: 1.9934, Val Loss: 2.1803, LR: 0.000016
# EarlyStopping counter: 7 out of 10
# Epoch 47/100, Train Loss: 1.9842, Val Loss: 2.1913, LR: 0.000015
# EarlyStopping counter: 8 out of 10
# Epoch 48/100, Train Loss: 1.9740, Val Loss: 2.1899, LR: 0.000014
# EarlyStopping counter: 9 out of 10
# Epoch 49/100, Train Loss: 1.9674, Val Loss: 2.1888, LR: 0.000013
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Cross-Validation Results:
# Mean Absolute Error (CV): 3.0138 (±0.6589)
# Root Mean Squared Error (CV): 3.6103 (±0.6676)
# Theil's U Statistic (CV): 0.6107 (±0.0304)
# R² Score (CV): -0.8091 (±0.5828)
# Directional Accuracy (CV): 46.01% (±6.25%)
#
# Training final model on full dataset...
# Epoch 1/100, Train Loss: 6.1071, Val Loss: 8.3888, LR: 0.000012
# Epoch 2/100, Train Loss: 5.9477, Val Loss: 8.1296, LR: 0.000021
# Epoch 3/100, Train Loss: 5.5646, Val Loss: 7.6319, LR: 0.000021
# Epoch 4/100, Train Loss: 5.0348, Val Loss: 7.0820, LR: 0.000019
# Epoch 5/100, Train Loss: 4.4831, Val Loss: 6.4794, LR: 0.000017
# Epoch 6/100, Train Loss: 3.9867, Val Loss: 5.9086, LR: 0.000014
# Epoch 7/100, Train Loss: 3.6160, Val Loss: 5.3942, LR: 0.000011
# Epoch 8/100, Train Loss: 3.3603, Val Loss: 4.9625, LR: 0.000008
# Epoch 9/100, Train Loss: 3.2038, Val Loss: 4.6706, LR: 0.000005
# Epoch 10/100, Train Loss: 3.1176, Val Loss: 4.4914, LR: 0.000003
# Epoch 11/100, Train Loss: 3.0821, Val Loss: 4.3914, LR: 0.000001
# Epoch 12/100, Train Loss: 3.0597, Val Loss: 4.3429, LR: 0.000021
# Epoch 13/100, Train Loss: 3.0012, Val Loss: 3.8351, LR: 0.000021
# Epoch 14/100, Train Loss: 2.9442, Val Loss: 3.5849, LR: 0.000021
# Epoch 15/100, Train Loss: 2.9023, Val Loss: 3.4486, LR: 0.000020
# Epoch 16/100, Train Loss: 2.8517, Val Loss: 3.2515, LR: 0.000019
# Epoch 17/100, Train Loss: 2.7802, Val Loss: 3.0996, LR: 0.000018
# Epoch 18/100, Train Loss: 2.6952, Val Loss: 3.0124, LR: 0.000017
# Epoch 19/100, Train Loss: 2.6223, Val Loss: 2.9057, LR: 0.000016
# Epoch 20/100, Train Loss: 2.5595, Val Loss: 2.8319, LR: 0.000014
# Epoch 21/100, Train Loss: 2.5154, Val Loss: 2.8023, LR: 0.000013
# Epoch 22/100, Train Loss: 2.4722, Val Loss: 2.7400, LR: 0.000011
# Epoch 23/100, Train Loss: 2.4405, Val Loss: 2.6771, LR: 0.000010
# Epoch 24/100, Train Loss: 2.4180, Val Loss: 2.6671, LR: 0.000008
# Epoch 25/100, Train Loss: 2.3956, Val Loss: 2.6242, LR: 0.000007
# Epoch 26/100, Train Loss: 2.3767, Val Loss: 2.6043, LR: 0.000005
# Epoch 27/100, Train Loss: 2.3610, Val Loss: 2.5798, LR: 0.000004
# Epoch 28/100, Train Loss: 2.3484, Val Loss: 2.5532, LR: 0.000003
# Epoch 29/100, Train Loss: 2.3376, Val Loss: 2.5353, LR: 0.000002
# Epoch 30/100, Train Loss: 2.3347, Val Loss: 2.5368, LR: 0.000001
# EarlyStopping counter: 1 out of 10
# Epoch 31/100, Train Loss: 2.3275, Val Loss: 2.5339, LR: 0.000001
# Epoch 32/100, Train Loss: 2.3243, Val Loss: 2.5348, LR: 0.000021
# EarlyStopping counter: 1 out of 10
# Epoch 33/100, Train Loss: 2.3035, Val Loss: 2.5220, LR: 0.000021
# Epoch 34/100, Train Loss: 2.2682, Val Loss: 2.4771, LR: 0.000021
# Epoch 35/100, Train Loss: 2.2368, Val Loss: 2.5092, LR: 0.000021
# EarlyStopping counter: 1 out of 10
# Epoch 36/100, Train Loss: 2.2115, Val Loss: 2.4831, LR: 0.000021
# EarlyStopping counter: 2 out of 10
# Epoch 37/100, Train Loss: 2.1880, Val Loss: 2.4413, LR: 0.000020
# Epoch 38/100, Train Loss: 2.1621, Val Loss: 2.4581, LR: 0.000020
# EarlyStopping counter: 1 out of 10
# Epoch 39/100, Train Loss: 2.1414, Val Loss: 2.4554, LR: 0.000020
# EarlyStopping counter: 2 out of 10
# Epoch 40/100, Train Loss: 2.1217, Val Loss: 2.4332, LR: 0.000019
# Epoch 41/100, Train Loss: 2.1073, Val Loss: 2.3958, LR: 0.000019
# Epoch 42/100, Train Loss: 2.0970, Val Loss: 2.3731, LR: 0.000018
# Epoch 43/100, Train Loss: 2.0820, Val Loss: 2.2876, LR: 0.000018
# Epoch 44/100, Train Loss: 2.0706, Val Loss: 2.2852, LR: 0.000017
# Epoch 45/100, Train Loss: 2.0581, Val Loss: 2.3188, LR: 0.000016
# EarlyStopping counter: 1 out of 10
# Epoch 46/100, Train Loss: 2.0501, Val Loss: 2.3800, LR: 0.000016
# EarlyStopping counter: 2 out of 10
# Epoch 47/100, Train Loss: 2.0445, Val Loss: 2.3730, LR: 0.000015
# EarlyStopping counter: 3 out of 10
# Epoch 48/100, Train Loss: 2.0357, Val Loss: 2.3847, LR: 0.000014
# EarlyStopping counter: 4 out of 10
# Epoch 49/100, Train Loss: 2.0299, Val Loss: 2.4055, LR: 0.000013
# EarlyStopping counter: 5 out of 10
# Epoch 50/100, Train Loss: 2.0254, Val Loss: 2.3984, LR: 0.000013
# EarlyStopping counter: 6 out of 10
# Epoch 51/100, Train Loss: 2.0207, Val Loss: 2.4217, LR: 0.000012
# EarlyStopping counter: 7 out of 10
# Epoch 52/100, Train Loss: 2.0163, Val Loss: 2.3774, LR: 0.000011
# EarlyStopping counter: 8 out of 10
# Epoch 53/100, Train Loss: 2.0124, Val Loss: 2.4068, LR: 0.000010
# EarlyStopping counter: 9 out of 10
# Epoch 54/100, Train Loss: 2.0088, Val Loss: 2.4273, LR: 0.000010
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Results saved:
# - Predictions: 'time2vec_predictions.csv'
# - Best parameters: 'time2vec_best_params.csv'
# - Cross-validation results: 'cross_validation_results.csv'

# %%
# After getting study, predictions, cv_results from main execution
sf = pd.read_csv('../../Data/Data_larger dataset/test_set.csv')
actual_values = sf['block_median_fee_rate']
predicted_values = predictions['predicted_fee_rate']

# Initialize predictor for metrics
predictor = BitcoinFeePredictor()
metrics = predictor.calculate_metrics(actual_values.values, predicted_values.values)

# Print metrics
print("Performance Metrics:")
print(f"Mean Absolute Error (MAE): {metrics.mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {metrics.rmse:.4f}")
print(f"Theil's U Statistic: {metrics.theil_u:.4f}")

# Create plot with your preferred style
plt.figure(figsize=(15, 12))

# Plot actual values
plt.plot(actual_values.index, actual_values, 
         label='Actual Fee Rate')

# Plot predicted values
plt.plot(actual_values.index, predicted_values, 
         label='Predicted Fee Rate', linestyle='--')

# Add title and labels
plt.title('Time2vec: Actual vs Predicted Bitcoin Fee Rate', fontsize=20)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Fee Rate (sat/vB)', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Add legend and grid
plt.legend(fontsize=16)
plt.grid(alpha=0.3)
plt.savefig('time2vec_test.png',dpi=600)

plt.show()
# Out:
# Performance Metrics:
# Mean Absolute Error (MAE): 2.4425
# Root Mean Squared Error (RMSE): 2.7915
# Theil's U Statistic: 0.6042
