# %% [markdown]
# First finds optimal hyperparameters using Optuna
#
# Then validates model performance using 5-fold cross validation
#
# Finally trains one model on the entire dataset to make future predictions

# %%
import optuna
from dataclasses import asdict, dataclass
from functools import partial
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from typing import List, Dict, Tuple
import time
import random
import torch.optim.lr_scheduler as lr_scheduler
import warnings

warnings.filterwarnings('ignore')


@dataclass
class ModelConfig:
    """Configuration for LSTM model"""
    time2vec_dim: int = 20
    hidden_dim: int = 128
    num_heads: int = 4  # Added: number of attention heads
    attention_dropout: float = 0.1  # Added: attention dropout rate
    batch_size: int = 128
    learning_rate: float = 0.00005
    num_epochs: int = 100
    max_encoder_length: int = 288
    max_prediction_length: int = 144
    clip_grad_norm: float = 1.0
    warmup_epochs: int = 3
    patience: int = 10
    min_delta: float = 1e-4
    dropout: float = 0.1
    

class MultiHeadAttention(nn.Module):
    def __init__(self, hidden_dim: int, num_heads: int, dropout: float = 0.1):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.hidden_dim = hidden_dim
        assert hidden_dim % num_heads == 0, "hidden_dim must be divisible by num_heads"
        
        self.depth = hidden_dim // num_heads
        self.wq = nn.Linear(hidden_dim, hidden_dim)
        self.wk = nn.Linear(hidden_dim, hidden_dim)
        self.wv = nn.Linear(hidden_dim, hidden_dim)
        self.dense = nn.Linear(hidden_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(hidden_dim)
        
    def split_heads(self, x: torch.Tensor) -> torch.Tensor:
        batch_size = x.size(0)
        x = x.view(batch_size, -1, self.num_heads, self.depth)
        return x.permute(0, 2, 1, 3)
        
    def forward(self, query: torch.Tensor, key: torch.Tensor, value: torch.Tensor, 
                mask: torch.Tensor = None) -> torch.Tensor:
        residual = query
        
        batch_size = query.size(0)
        
        # Linear projections and split heads
        q = self.split_heads(self.wq(query))
        k = self.split_heads(self.wk(key))
        v = self.split_heads(self.wv(value))
        
        # Scaled dot-product attention
        matmul_qk = torch.matmul(q, k.transpose(-2, -1))
        dk = torch.tensor(self.depth, dtype=torch.float32)
        scaled_attention_logits = matmul_qk / torch.sqrt(dk)
        
        if mask is not None:
            scaled_attention_logits += (mask * -1e9)
        
        attention_weights = torch.softmax(scaled_attention_logits, dim=-1)
        attention_weights = self.dropout(attention_weights)
        
        output = torch.matmul(attention_weights, v)
        output = output.permute(0, 2, 1, 3).contiguous()
        output = output.view(batch_size, -1, self.hidden_dim)
        
        # Final linear projection
        output = self.dense(output)
        output = self.dropout(output)
        
        # Add & Norm
        output = self.layer_norm(output + residual)
        
        return output, attention_weights

class EarlyStopping:
    def __init__(self, patience: int = 7, min_delta: float = 1e-4, verbose: bool = True):
        self.patience = patience
        self.min_delta = min_delta
        self.verbose = verbose
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.val_loss_min = float('inf')

    def __call__(self, val_loss: float, model: nn.Module) -> bool:
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0
        return self.early_stop


class Time2Vec(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(Time2Vec, self).__init__()
        self.w0 = nn.parameter.Parameter(torch.randn(input_dim, 1))
        self.b0 = nn.parameter.Parameter(torch.randn(1))
        self.w = nn.parameter.Parameter(torch.randn(input_dim, output_dim - 1))
        self.b = nn.parameter.Parameter(torch.randn(output_dim - 1))
        self.f = torch.sin

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        v1 = torch.matmul(x, self.w0) + self.b0
        v2 = self.f(torch.matmul(x, self.w) + self.b)
        return torch.cat([v1, v2], -1)


class BitcoinFeeModel(nn.Module):
    def __init__(self, hist_input_dim: int, future_input_dim: int, config: ModelConfig):
        super(BitcoinFeeModel, self).__init__()
        self.time2vec = Time2Vec(1, config.time2vec_dim)
        
        # LSTM layer
        self.lstm = nn.LSTM(
            hist_input_dim + config.time2vec_dim,
            config.hidden_dim,
            batch_first=True,
            dropout=config.dropout
        )
        
        # Self-attention for historical features
        self.self_attention = MultiHeadAttention(
            config.hidden_dim,
            config.num_heads,
            config.attention_dropout
        )
        
        # Cross-attention between historical and future features
        self.cross_attention = MultiHeadAttention(
            config.hidden_dim,
            config.num_heads,
            config.attention_dropout
        )
        
        # Future feature projection
        self.future_projection = nn.Linear(future_input_dim, config.hidden_dim)
        
        # Output layers
        self.fc_combine = nn.Linear(config.hidden_dim * 2, config.hidden_dim)
        self.layer_norm = nn.LayerNorm(config.hidden_dim)
        self.dropout = nn.Dropout(config.dropout)
        self.fc_out = nn.Linear(config.hidden_dim, 1)
        
        self.num_predictions = config.max_prediction_length

    def forward(self, time_feature: torch.Tensor, x_hist: torch.Tensor,
                x_future: torch.Tensor) -> torch.Tensor:
        batch_size, seq_len, _ = x_hist.shape
        
        # Time encoding
        time_encoded = self.time2vec(time_feature).expand(batch_size, seq_len, -1)
        x_hist_time = torch.cat([x_hist, time_encoded], dim=-1)
        
        # LSTM processing
        lstm_out, (h_n, _) = self.lstm(x_hist_time)
        
        # Self-attention on LSTM output
        attended_hist, _ = self.self_attention(lstm_out, lstm_out, lstm_out)
        
        # Project future features
        future_projected = self.future_projection(x_future)
        
        outputs = []
        last_hidden = h_n.squeeze(0)
        
        for i in range(self.num_predictions):
            # Cross-attention between historical context and current future step
            current_future = future_projected[:, i:i+1, :]
            cross_attended, _ = self.cross_attention(
                current_future,
                attended_hist,
                attended_hist
            )
            
            # Combine features
            combined = torch.cat([last_hidden.unsqueeze(1), cross_attended], dim=-1)
            combined = self.fc_combine(combined)
            combined = self.layer_norm(combined)
            combined = self.dropout(combined)
            
            # Generate prediction
            out = self.fc_out(combined)
            outputs.append(out.squeeze(-1))
            
            # Update hidden state for next prediction
            last_hidden = combined.squeeze(1)
        
        return torch.cat(outputs, dim=1)


class Time2VecDataset(Dataset):
    def __init__(self, data: pd.DataFrame, historical_features: List[str],
                 future_known_features: List[str], target: str, config: ModelConfig):
        self.data = data
        self.historical_features = historical_features
        self.future_known_features = future_known_features
        self.target = target
        self.config = config

    def __len__(self) -> int:
        return len(self.data) - self.config.max_encoder_length - self.config.max_prediction_length + 1

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
        encoder_start = idx
        encoder_end = idx + self.config.max_encoder_length
        decoder_end = encoder_end + self.config.max_prediction_length

        historical_data = self.data.iloc[encoder_start:encoder_end][self.historical_features]
        future_known_data = self.data.iloc[encoder_end:decoder_end][self.future_known_features]
        target_values = self.data.iloc[encoder_end:decoder_end][self.target]

        time_feature = torch.arange(0, self.config.max_encoder_length, dtype=torch.float32).unsqueeze(1)
        x_hist = torch.tensor(historical_data.values, dtype=torch.float32)
        x_future = torch.tensor(future_known_data.values, dtype=torch.float32)
        y = torch.tensor(target_values.values, dtype=torch.float32)

        return time_feature, x_hist, x_future, y


@dataclass
class ModelMetrics:
    mae: float
    rmse: float
    r2: float
    mape: float
    theil_u: float
    directional_accuracy: float


class BitcoinFeePredictor:


    def __init__(self, config: ModelConfig = ModelConfig()):
        self.config = config
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        self.historical_features = [
            'tx_count', 'mempool_size_mb', 'max_fee_rate', 'avg_fee_rate',
            'median_fee_rate', 'fee_rate_10th', 'fee_rate_90th', 'fee_rate_std',
            'mempool_min_fee', 'total_fee', 'mempool_usage', 'transaction_count',
            'block_weight', 'block_interval', 'hist_low_fee_ratio',
            'hist_med_fee_ratio', 'hist_high_fee_ratio', 'hist_fee_diversity',
            'hash_rate', 'bitcoin_price_usd'
        ]

        self.known_future_features = ['block_height', 'difficulty', 'block_version']
        self.target = 'block_median_fee_rate'


    def prepare_data(self, df: pd.DataFrame, scaler=None) -> Tuple[pd.DataFrame, RobustScaler]:
        """Prepare and scale data"""
        all_features = self.historical_features + self.known_future_features

        if scaler is None:
            scaler = RobustScaler()
            df[all_features] = scaler.fit_transform(df[all_features])
        else:
            df[all_features] = scaler.transform(df[all_features])
            
        return df, scaler


    def create_validation_dataloader(self, train_data: pd.DataFrame) -> DataLoader:
        """Create validation dataloader from last 20% of training data"""
        val_size = int(len(train_data) * 0.2)
        val_data = train_data.iloc[-val_size:]
        val_dataset = Time2VecDataset(val_data, self.historical_features,
                                  self.known_future_features, self.target, self.config)
        return DataLoader(val_dataset, batch_size=self.config.batch_size,
                      shuffle=False, drop_last=True)


    def train_model(self, train_data: pd.DataFrame) -> BitcoinFeeModel:
        """Train model with validation and early stopping"""
        train_size = int(len(train_data) * 0.8)
        train_subset = train_data.iloc[:train_size]

        train_dataset = Time2VecDataset(train_subset, self.historical_features,
                                    self.known_future_features, self.target, self.config)
        train_loader = DataLoader(train_dataset, batch_size=self.config.batch_size,
                              shuffle=True, drop_last=True)
        val_loader = self.create_validation_dataloader(train_data)

        model = BitcoinFeeModel(len(self.historical_features),
                            len(self.known_future_features), self.config).to(self.device)

        criterion = nn.HuberLoss()
        optimizer = optim.AdamW(model.parameters(), lr=self.config.learning_rate,
                            weight_decay=0.01, betas=(0.9, 0.999))

        scheduler = lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, T_0=10, T_mult=2, eta_min=1e-6
        )

        warmup_scheduler = lr_scheduler.LinearLR(
            optimizer,
            start_factor=0.1,
            end_factor=1.0,
            total_iters=self.config.warmup_epochs
         ) if self.config.warmup_epochs > 0 else None

        early_stopping = EarlyStopping(
        patience=self.config.patience,
        min_delta=self.config.min_delta
        )

        best_model_state = None
        best_val_loss = float('inf')

        for epoch in range(self.config.num_epochs):
            model.train()
            running_loss = 0.0

            for time_feature, x_hist, x_future_known, y in train_loader:
                time_feature = time_feature.to(self.device)
                x_hist = x_hist.to(self.device)
                x_future_known = x_future_known.to(self.device)
                y = y.to(self.device)

                outputs = model(time_feature, x_hist, x_future_known)
                loss = criterion(outputs, y)

                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), self.config.clip_grad_norm)
                optimizer.step()
                running_loss += loss.item()

            avg_train_loss = running_loss / len(train_loader)

        # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for time_feature, x_hist, x_future_known, y in val_loader:
                    time_feature = time_feature.to(self.device)
                    x_hist = x_hist.to(self.device)
                    x_future_known = x_future_known.to(self.device)
                    y = y.to(self.device)

                    outputs = model(time_feature, x_hist, x_future_known)
                    loss = criterion(outputs, y)
                    val_loss += loss.item()

                avg_val_loss = val_loss / len(val_loader)

            # Update learning rate
            if epoch < self.config.warmup_epochs and warmup_scheduler:
                warmup_scheduler.step()
            else:
                 scheduler.step()

            current_lr = optimizer.param_groups[0]['lr']
            print(f"Epoch {epoch + 1}/{self.config.num_epochs}, "
              f"Train Loss: {avg_train_loss:.4f}, "
              f"Val Loss: {avg_val_loss:.4f}, "
              f"LR: {current_lr:.6f}")

            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model_state = model.state_dict().copy()

            if early_stopping(avg_val_loss, model):
                print("Early stopping triggered")
                break

        if best_model_state is not None:
            model.load_state_dict(best_model_state)

        return model

    def predict(self, model: BitcoinFeeModel, data: pd.DataFrame) -> np.ndarray:
        """Make predictions"""
        model.eval()
        hist_data = data.tail(self.config.max_encoder_length)[self.historical_features].values

        future_known_data = np.zeros((self.config.max_prediction_length, len(self.known_future_features)))
        last_block_height = data['block_height'].iloc[-1]
        last_difficulty = data['difficulty'].iloc[-1]
        last_block_version = data['block_version'].iloc[-1]

        for i in range(self.config.max_prediction_length):
            future_known_data[i] = [last_block_height + i + 1, last_difficulty, last_block_version]

        time_feature = torch.arange(0, self.config.max_encoder_length, dtype=torch.float32).unsqueeze(1).to(self.device)
        x_hist = torch.tensor(hist_data, dtype=torch.float32).unsqueeze(0).to(self.device)
        x_future_known = torch.tensor(future_known_data, dtype=torch.float32).unsqueeze(0).to(self.device)

        with torch.no_grad():
            predictions = model(time_feature, x_hist, x_future_known).cpu().numpy().flatten()

        return predictions



    def calculate_metrics(self, y_true: np.ndarray, y_pred: np.ndarray) -> ModelMetrics:
        """Calculate evaluation metrics"""
        def mean_absolute_percentage_error(y_true, y_pred):
            return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

        def directional_accuracy(y_true, y_pred):
            return np.mean((np.diff(y_true) * np.diff(y_pred)) > 0) * 100

        def theil_u(y_true, y_pred):
            y_true_pct = (y_true[1:] - y_true[:-1]) / y_true[:-1]
            y_pred_pct = (y_pred[1:] - y_true[:-1]) / y_true[:-1]
            numerator = np.sqrt(np.mean((y_true_pct - y_pred_pct) ** 2))
            denominator = np.sqrt(np.mean(y_true_pct ** 2)) + np.sqrt(np.mean(y_pred_pct ** 2))
            return numerator / denominator

        return ModelMetrics(
            mae=mean_absolute_error(y_true, y_pred),
            rmse=np.sqrt(mean_squared_error(y_true, y_pred)),
            r2=r2_score(y_true, y_pred),
            mape=mean_absolute_percentage_error(y_true, y_pred),
            theil_u=theil_u(y_true, y_pred),
            directional_accuracy=directional_accuracy(y_true, y_pred)
        )
    
    def plot_predictions(self, y_true: np.ndarray, y_pred: np.ndarray,
                    title: str = "Actual vs Predicted Bitcoin Fee Rates") -> None:
        """Plot actual vs predicted values with metrics"""
        plt.figure(figsize=(15, 8))
    
        # Plot actual and predicted values
        x_axis = np.arange(len(y_true))
        plt.plot(x_axis, y_true, label='Actual', color='blue', alpha=0.6, linewidth=2)
        plt.plot(x_axis, y_pred, label='Predicted', color='red', alpha=0.6, linewidth=2)
    
        # Calculate and display metrics
        metrics = self.calculate_metrics(y_true, y_pred)
        metrics_text = (f'MAE: {metrics.mae:.2f}\n'
                   f'RMSE: {metrics.rmse:.2f}\n'
                   f'R²: {metrics.r2:.2f}\n'
                   f'MAPE: {metrics.mape:.2f}%\n'
                   f'Directional Accuracy: {metrics.directional_accuracy:.2f}%')
    
        plt.text(0.02, 0.98, metrics_text,
             transform=plt.gca().transAxes,
             verticalalignment='top',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
        plt.title(title)
        plt.xlabel('Block Number')
        plt.ylabel('Fee Rate (sat/vB)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()

    def cross_validate(self, df: pd.DataFrame, n_splits: int = 5) -> Tuple[List[ModelMetrics], np.ndarray, np.ndarray]:
        """Perform time series cross-validation with combined plotting"""
        n_samples = len(df)
        metrics_list = []
        all_y_true = []
        all_y_pred = []
    
    # Create figure for combined plot
        plt.figure(figsize=(15, 8))
    
        for fold_idx in range(n_splits):
            train_end = n_samples - (n_splits - fold_idx) * self.config.max_prediction_length
            test_start = train_end
            test_end = test_start + self.config.max_prediction_length
        
        # Split and prepare data
            train_data = df.iloc[:train_end].copy()
            test_data = df.iloc[test_start:test_end].copy()
        
            train_data, scaler = self.prepare_data(train_data)
            test_data, _ = self.prepare_data(test_data, scaler)
        
        # Train model
            model = self.train_model(train_data)
        
        # Make predictions
            predictions = self.predict(model, train_data)
        
        # Get actual values
            y_true = test_data[self.target].values
        
        # Store results
            metrics = self.calculate_metrics(y_true, predictions)
            metrics_list.append(metrics)
        
        # Accumulate predictions for combined plot
            start_idx = fold_idx * len(predictions)
            all_y_true.extend(y_true)
            all_y_pred.extend(predictions)
    
    # Convert to numpy arrays for plotting
        all_y_true = np.array(all_y_true)
        all_y_pred = np.array(all_y_pred)
    
    # Create combined plot
        plt.figure(figsize=(15, 12))
        x_axis = np.arange(1,len(all_y_true)+1)
    
    # Plot actual values in blue
        plt.plot(x_axis, all_y_true, label='Actual')
    
    # Plot predicted values in orange
        plt.plot(x_axis, all_y_pred, label='Predicted')

    # Customize plot
        plt.title('Time2evc_attention: Actual vs Predicted Bitcoin Fee Rates (All Folds)', fontsize=20)
        plt.xlabel('Block Number',fontsize=20)
        plt.ylabel('Fee Rate',fontsize=20)
        plt.xticks(fontsize=16)
        plt.yticks(fontsize=16)
        plt.legend(fontsize=16)
        plt.grid(True, alpha=0.3)
        plt.savefig('time2vec_attention.png',dpi=600)
        plt.show()
        
        
    # Calculate and format metrics for display
        mae_values = [m.mae for m in metrics_list]
        rmse_values = [m.rmse for m in metrics_list]
        theil_u_values = [m.theil_u for m in metrics_list]
        r2_values = [m.r2 for m in metrics_list]
        da_values = [m.directional_accuracy for m in metrics_list]
    

    # Print metrics to console
        print("\nCross-Validation Results:")
        print(f"Mean Absolute Error (CV): {np.mean(mae_values):.4f} (±{np.std(mae_values):.4f})")
        print(f"Root Mean Squared Error (CV): {np.mean(rmse_values):.4f} (±{np.std(rmse_values):.4f})")
        print(f"Theil's U Statistic (CV): {np.mean(theil_u_values):.4f} (±{np.std(theil_u_values):.4f})")
        print(f"R² Score (CV): {np.mean(r2_values):.4f} (±{np.std(r2_values):.4f})")
        print(f"Directional Accuracy (CV): {np.mean(da_values):.2f}% (±{np.std(da_values):.2f}%)")
    
        return metrics_list, all_y_true, all_y_pred


class ModelTuner:
    def __init__(self, df, n_trials=50):
        self.df = df
        self.n_trials = n_trials
        self.best_params = None
        self.best_score = float('inf')

    def objective(self, trial):
        """Optuna objective function for hyperparameter optimization"""
        try:
            # Define hyperparameter search space
            config = ModelConfig(
                # Time2Vec parameters
                time2vec_dim=trial.suggest_int('time2vec_dim', 16, 32),

                # Model architecture
                hidden_dim=trial.suggest_int('hidden_dim', 32, 256, step=32),

                # Training parameters
                batch_size=trial.suggest_categorical('batch_size', [32, 64, 128, 256]),
                learning_rate=trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True),

                # Regularization
                dropout=trial.suggest_float('dropout', 0.1, 0.5),
                clip_grad_norm=trial.suggest_float('clip_grad_norm', 0.1, 5.0),

                # Training schedule
                warmup_epochs=trial.suggest_int('warmup_epochs', 1, 10),
                patience=trial.suggest_int('patience', 5, 15),

                # Keep other parameters fixed
                num_epochs=100,
                max_encoder_length=288,
                max_prediction_length=144,
                min_delta=1e-4
            )

            # Initialize predictor with trial config
            predictor = BitcoinFeePredictor(config)

            # Split data before scaling
            n_samples = len(self.df)
            train_end = n_samples - config.max_prediction_length
            train_data = self.df.iloc[:train_end].copy()
            test_data = self.df.iloc[train_end:].copy()

            # Fit scaler only on training data
            train_data, scaler = predictor.prepare_data(train_data)
            test_data, _ = predictor.prepare_data(test_data, scaler)  # Use same scaler

            # Train model
            model = predictor.train_model(train_data)

            # Make predictions
            predictions = predictor.predict(model, train_data)

            # Get actual values
            y_true = test_data[predictor.target].values

            # Calculate metrics
            metrics = predictor.calculate_metrics(y_true, predictions)

            # Use RMSE as the optimization metric
            return metrics.rmse

        except Exception as e:
            print(f"Trial failed with error: {str(e)}")
            return float('inf')

    def find_best_params(self):
        """Run hyperparameter optimization"""
        try:
            study = optuna.create_study(
                direction='minimize',
                pruner=optuna.pruners.MedianPruner(
                    n_startup_trials=5,
                    n_warmup_steps=5,
                    interval_steps=3
                )
            )

            study.sampler = optuna.samplers.TPESampler(
                n_startup_trials=10,
                multivariate=True,
                constant_liar=True
            )

            study.optimize(self.objective, n_trials=self.n_trials, show_progress_bar=True)

            print("\nOptimization Results:")
            print(f"Number of completed trials: {len(study.trials)}")
            print("\nBest trial:")
            trial = study.best_trial

            print(f"Value (RMSE): {trial.value:.4f}")
            print("\nBest hyperparameters:")
            for key, value in trial.params.items():
                print(f"    {key}: {value}")

            self.best_params = trial.params
            self.best_score = trial.value

            return study

        except Exception as e:
            print(f"Error in hyperparameter optimization: {str(e)}")
            raise


def main_with_tuning_and_cv():
    try:
        # Set seeds
        random.seed(42)
        np.random.seed(42)
        torch.manual_seed(42)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(42)
            torch.cuda.manual_seed_all(42)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False

        # Load data
        print("Loading data...")
        df = pd.read_csv('/kaggle/input/bitcoin-project/real_time_cleaned.csv')
        df['block_time'] = pd.to_datetime(df['block_time'])
        df = df.sort_values('block_time')
        
        # Set block_time as index
        df.set_index('block_time', inplace=True)

        # Step 1: Hyperparameter Optimization
        print("\nStarting hyperparameter optimization...")
        tuner = ModelTuner(df, n_trials=10)  # Increased trials
        study = tuner.find_best_params()

        # Create config with best parameters
        best_config = ModelConfig(**study.best_params)
        
        # Step 2: Cross Validation with Best Parameters
        print("\nPerforming cross-validation with best parameters...")
        predictor = BitcoinFeePredictor(best_config)
        metrics_list, all_y_true, all_y_pred = predictor.cross_validate(df, n_splits=5)
        
        mae_values = [m.mae for m in metrics_list]
        rmse_values = [m.rmse for m in metrics_list]
        r2_values = [m.r2 for m in metrics_list]
        

        # Step 3: Train Final Model on Full Dataset for Future Predictions
        print("\nTraining final model on full dataset...")
        df_prepared, scaler = predictor.prepare_data(df)
        model = predictor.train_model(df_prepared)
        
        # Generate predictions for next 144 blocks
        predictions = predictor.predict(model, df_prepared)

        # Create timestamps for predictions
        last_time = df.index[-1]  # Now this will be a timestamp
        prediction_times = pd.date_range(
            start=last_time,  # Use the last timestamp
            periods=145,      # Include the last timestamp
            freq='10T'
        )[1:]  # Exclude the first timestamp which is the last actual data point

        # Create results DataFrame with proper timestamps
        results_df = pd.DataFrame({
            'timestamp': prediction_times,
            'predicted_fee_rate': predictions[:144]
        })

        # Plot final results with proper time axis
        plt.figure(figsize=(15, 8))
        
        # Plot historical data
        historical_data = df['block_median_fee_rate'].iloc[-144:]
        plt.plot(historical_data.index, historical_data.values,
                 label='Historical', color='gray', alpha=0.5)
        
        # Plot predictions
        plt.plot(results_df['timestamp'], results_df['predicted_fee_rate'],
                 label='Predicted', color='blue', marker='o', markersize=4)
        
        plt.title('Bitcoin Fee Rate Predictions - Next 144 Blocks')
        plt.xlabel('Time')
        plt.ylabel('Fee Rate (sat/vB)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.gcf().autofmt_xdate()
        plt.tight_layout()
        plt.show()

        # Save results
        results_df.to_csv('time2vec_predictions_attention.csv')
        best_params_df = pd.DataFrame([study.best_params])
        best_params_df.to_csv('time2vec_best_params_attention.csv', index=False)

        # Save cross-validation results with more detailed metrics
        cv_results = pd.DataFrame({
            'fold': range(1, len(metrics_list) + 1),
            'mae': [m.mae for m in metrics_list],
            'rmse': [m.rmse for m in metrics_list],
            'r2': [m.r2 for m in metrics_list],
            'mape': [m.mape for m in metrics_list],
            'theil_u': [m.theil_u for m in metrics_list],
            'directional_accuracy': [m.directional_accuracy for m in metrics_list]
        })
        cv_results.to_csv('time2vec_cross_validation_results_attention.csv', index=False)

        print("\nResults saved:")
        print("- Predictions: 'time2vec_predictions_attention.csv'")
        print("- Best parameters: 'time2vec_best_params_attention.csv'")
        print("- Cross-validation results: 'cross_validation_results_attention.csv'")

        return study, results_df, cv_results

    except Exception as e:
        print(f"Error in main process: {str(e)}")
        raise

if __name__ == "__main__":
    study, predictions, cv_results = main_with_tuning_and_cv()
# Out:
# [I 2024-12-10 15:23:36,434] A new study created in memory with name: no-name-f4d7811e-0af8-4847-80ab-3e1e829a0257
# Loading data...
#
# Starting hyperparameter optimization...
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/100, Train Loss: 3.9493, Val Loss: 8.5604, LR: 0.000027
# Epoch 2/100, Train Loss: 2.7933, Val Loss: 5.4817, LR: 0.000045
# Epoch 3/100, Train Loss: 2.5405, Val Loss: 4.2553, LR: 0.000063
# Epoch 4/100, Train Loss: 2.3480, Val Loss: 3.8083, LR: 0.000081
# Epoch 5/100, Train Loss: 2.2166, Val Loss: 3.6548, LR: 0.000098
# Epoch 6/100, Train Loss: 2.0983, Val Loss: 3.5873, LR: 0.000096
# Epoch 7/100, Train Loss: 2.0337, Val Loss: 3.5525, LR: 0.000089
# Epoch 8/100, Train Loss: 2.0106, Val Loss: 3.5156, LR: 0.000078
# Epoch 9/100, Train Loss: 1.9788, Val Loss: 3.5057, LR: 0.000065
# Epoch 10/100, Train Loss: 1.9650, Val Loss: 3.4970, LR: 0.000050
# Epoch 11/100, Train Loss: 1.9512, Val Loss: 3.4841, LR: 0.000035
# Epoch 12/100, Train Loss: 1.9444, Val Loss: 3.4857, LR: 0.000021
# EarlyStopping counter: 1 out of 13
# Epoch 13/100, Train Loss: 1.9340, Val Loss: 3.4786, LR: 0.000010
# Epoch 14/100, Train Loss: 1.9237, Val Loss: 3.4763, LR: 0.000003
# Epoch 15/100, Train Loss: 1.9199, Val Loss: 3.4747, LR: 0.000098
# Epoch 16/100, Train Loss: 1.9020, Val Loss: 3.4770, LR: 0.000098
# EarlyStopping counter: 1 out of 13
# Epoch 17/100, Train Loss: 1.8812, Val Loss: 3.4781, LR: 0.000096
# EarlyStopping counter: 2 out of 13
# Epoch 18/100, Train Loss: 1.8617, Val Loss: 3.4880, LR: 0.000093
# EarlyStopping counter: 3 out of 13
# Epoch 19/100, Train Loss: 1.8466, Val Loss: 3.5068, LR: 0.000089
# EarlyStopping counter: 4 out of 13
# Epoch 20/100, Train Loss: 1.8319, Val Loss: 3.5148, LR: 0.000084
# EarlyStopping counter: 5 out of 13
# Epoch 21/100, Train Loss: 1.8186, Val Loss: 3.5398, LR: 0.000078
# EarlyStopping counter: 6 out of 13
# Epoch 22/100, Train Loss: 1.8119, Val Loss: 3.5545, LR: 0.000072
# EarlyStopping counter: 7 out of 13
# Epoch 23/100, Train Loss: 1.7977, Val Loss: 3.5768, LR: 0.000065
# EarlyStopping counter: 8 out of 13
# Epoch 24/100, Train Loss: 1.7833, Val Loss: 3.6100, LR: 0.000057
# EarlyStopping counter: 9 out of 13
# Epoch 25/100, Train Loss: 1.7715, Val Loss: 3.6476, LR: 0.000050
# EarlyStopping counter: 10 out of 13
# Epoch 26/100, Train Loss: 1.7569, Val Loss: 3.6786, LR: 0.000042
# EarlyStopping counter: 11 out of 13
# Epoch 27/100, Train Loss: 1.7449, Val Loss: 3.7297, LR: 0.000035
# EarlyStopping counter: 12 out of 13
# Epoch 28/100, Train Loss: 1.7337, Val Loss: 3.7623, LR: 0.000028
# EarlyStopping counter: 13 out of 13
# Early stopping triggered
# [I 2024-12-10 16:01:49,605] Trial 0 finished with value: 3.7821019935814957 and parameters: {'time2vec_dim': 30, 'hidden_dim': 256, 'batch_size': 128, 'learning_rate': 9.81717183428573e-05, 'dropout': 0.364209321551768, 'clip_grad_norm': 3.0934413360194633, 'warmup_epochs': 5, 'patience': 13}. Best is trial 0 with value: 3.7821019935814957.
# Epoch 1/100, Train Loss: 5.1279, Val Loss: 10.9136, LR: 0.000006
# Epoch 2/100, Train Loss: 4.9163, Val Loss: 10.5409, LR: 0.000010
# Epoch 3/100, Train Loss: 4.4023, Val Loss: 9.8122, LR: 0.000015
# Epoch 4/100, Train Loss: 3.7143, Val Loss: 8.7729, LR: 0.000014
# Epoch 5/100, Train Loss: 3.1805, Val Loss: 7.8835, LR: 0.000013
# Epoch 6/100, Train Loss: 2.9162, Val Loss: 7.2035, LR: 0.000012
# Epoch 7/100, Train Loss: 2.7829, Val Loss: 6.7559, LR: 0.000010
# Epoch 8/100, Train Loss: 2.7363, Val Loss: 6.5160, LR: 0.000008
# Epoch 9/100, Train Loss: 2.7142, Val Loss: 6.3861, LR: 0.000006
# Epoch 10/100, Train Loss: 2.7001, Val Loss: 6.3199, LR: 0.000004
# Epoch 11/100, Train Loss: 2.6978, Val Loss: 6.2829, LR: 0.000002
# Epoch 12/100, Train Loss: 2.6917, Val Loss: 6.2632, LR: 0.000001
# Epoch 13/100, Train Loss: 2.6830, Val Loss: 6.2519, LR: 0.000015
# Epoch 14/100, Train Loss: 2.6870, Val Loss: 6.1392, LR: 0.000015
# Epoch 15/100, Train Loss: 2.6638, Val Loss: 6.0692, LR: 0.000014
# Epoch 16/100, Train Loss: 2.6562, Val Loss: 6.0129, LR: 0.000014
# Epoch 17/100, Train Loss: 2.6413, Val Loss: 5.9733, LR: 0.000013
# Epoch 18/100, Train Loss: 2.6354, Val Loss: 5.9427, LR: 0.000013
# Epoch 19/100, Train Loss: 2.6224, Val Loss: 5.9233, LR: 0.000012
# Epoch 20/100, Train Loss: 2.6124, Val Loss: 5.9035, LR: 0.000011
# Epoch 21/100, Train Loss: 2.6081, Val Loss: 5.8829, LR: 0.000010
# Epoch 22/100, Train Loss: 2.5988, Val Loss: 5.8665, LR: 0.000009
# Epoch 23/100, Train Loss: 2.5909, Val Loss: 5.8536, LR: 0.000008
# Epoch 24/100, Train Loss: 2.5899, Val Loss: 5.8415, LR: 0.000007
# Epoch 25/100, Train Loss: 2.5782, Val Loss: 5.8314, LR: 0.000006
# Epoch 26/100, Train Loss: 2.5776, Val Loss: 5.8202, LR: 0.000005
# Epoch 27/100, Train Loss: 2.5775, Val Loss: 5.8118, LR: 0.000004
# Epoch 28/100, Train Loss: 2.5671, Val Loss: 5.8059, LR: 0.000003
# Epoch 29/100, Train Loss: 2.5763, Val Loss: 5.8020, LR: 0.000002
# Epoch 30/100, Train Loss: 2.5700, Val Loss: 5.7982, LR: 0.000002
# Epoch 31/100, Train Loss: 2.5659, Val Loss: 5.7952, LR: 0.000001
# Epoch 32/100, Train Loss: 2.5714, Val Loss: 5.7921, LR: 0.000001
# Epoch 33/100, Train Loss: 2.5627, Val Loss: 5.7905, LR: 0.000015
# Epoch 34/100, Train Loss: 2.5673, Val Loss: 5.7662, LR: 0.000015
# Epoch 35/100, Train Loss: 2.5601, Val Loss: 5.7348, LR: 0.000015
# Epoch 36/100, Train Loss: 2.5458, Val Loss: 5.7075, LR: 0.000015
# Epoch 37/100, Train Loss: 2.5449, Val Loss: 5.6800, LR: 0.000014
# Epoch 38/100, Train Loss: 2.5345, Val Loss: 5.6648, LR: 0.000014
# Epoch 39/100, Train Loss: 2.5273, Val Loss: 5.6435, LR: 0.000014
# Epoch 40/100, Train Loss: 2.5210, Val Loss: 5.6278, LR: 0.000014
# Epoch 41/100, Train Loss: 2.5173, Val Loss: 5.6047, LR: 0.000013
# Epoch 42/100, Train Loss: 2.5092, Val Loss: 5.5809, LR: 0.000013
# Epoch 43/100, Train Loss: 2.4988, Val Loss: 5.5607, LR: 0.000013
# Epoch 44/100, Train Loss: 2.4895, Val Loss: 5.5406, LR: 0.000012
# Epoch 45/100, Train Loss: 2.4852, Val Loss: 5.5186, LR: 0.000012
# Epoch 46/100, Train Loss: 2.4843, Val Loss: 5.4965, LR: 0.000011
# Epoch 47/100, Train Loss: 2.4735, Val Loss: 5.4813, LR: 0.000011
# Epoch 48/100, Train Loss: 2.4703, Val Loss: 5.4636, LR: 0.000010
# Epoch 49/100, Train Loss: 2.4658, Val Loss: 5.4443, LR: 0.000010
# Epoch 50/100, Train Loss: 2.4574, Val Loss: 5.4292, LR: 0.000009
# Epoch 51/100, Train Loss: 2.4521, Val Loss: 5.4080, LR: 0.000009
# Epoch 52/100, Train Loss: 2.4496, Val Loss: 5.3959, LR: 0.000008
# Epoch 53/100, Train Loss: 2.4459, Val Loss: 5.3837, LR: 0.000008
# Epoch 54/100, Train Loss: 2.4371, Val Loss: 5.3657, LR: 0.000007
# Epoch 55/100, Train Loss: 2.4410, Val Loss: 5.3549, LR: 0.000007
# Epoch 56/100, Train Loss: 2.4360, Val Loss: 5.3459, LR: 0.000006
# Epoch 57/100, Train Loss: 2.4338, Val Loss: 5.3385, LR: 0.000006
# Epoch 58/100, Train Loss: 2.4314, Val Loss: 5.3285, LR: 0.000005
# Epoch 59/100, Train Loss: 2.4220, Val Loss: 5.3192, LR: 0.000005
# Epoch 60/100, Train Loss: 2.4240, Val Loss: 5.3108, LR: 0.000004
# Epoch 61/100, Train Loss: 2.4219, Val Loss: 5.3017, LR: 0.000004
# Epoch 62/100, Train Loss: 2.4264, Val Loss: 5.2958, LR: 0.000003
# Epoch 63/100, Train Loss: 2.4216, Val Loss: 5.2906, LR: 0.000003
# Epoch 64/100, Train Loss: 2.4228, Val Loss: 5.2857, LR: 0.000003
# Epoch 65/100, Train Loss: 2.4166, Val Loss: 5.2801, LR: 0.000002
# Epoch 66/100, Train Loss: 2.4146, Val Loss: 5.2777, LR: 0.000002
# Epoch 67/100, Train Loss: 2.4117, Val Loss: 5.2749, LR: 0.000002
# Epoch 68/100, Train Loss: 2.4159, Val Loss: 5.2715, LR: 0.000002
# Epoch 69/100, Train Loss: 2.4138, Val Loss: 5.2701, LR: 0.000001
# Epoch 70/100, Train Loss: 2.4094, Val Loss: 5.2688, LR: 0.000001
# Epoch 71/100, Train Loss: 2.4124, Val Loss: 5.2663, LR: 0.000001
# Epoch 72/100, Train Loss: 2.4156, Val Loss: 5.2646, LR: 0.000001
# Epoch 73/100, Train Loss: 2.4117, Val Loss: 5.2628, LR: 0.000015
# Epoch 74/100, Train Loss: 2.4101, Val Loss: 5.2552, LR: 0.000015
# Epoch 75/100, Train Loss: 2.4013, Val Loss: 5.2169, LR: 0.000015
# Epoch 76/100, Train Loss: 2.3977, Val Loss: 5.2118, LR: 0.000015
# Epoch 77/100, Train Loss: 2.3871, Val Loss: 5.1914, LR: 0.000015
# Epoch 78/100, Train Loss: 2.3786, Val Loss: 5.1662, LR: 0.000015
# Epoch 79/100, Train Loss: 2.3654, Val Loss: 5.1486, LR: 0.000015
# Epoch 80/100, Train Loss: 2.3651, Val Loss: 5.1475, LR: 0.000014
# Epoch 81/100, Train Loss: 2.3548, Val Loss: 5.1463, LR: 0.000014
# Epoch 82/100, Train Loss: 2.3469, Val Loss: 5.1310, LR: 0.000014
# Epoch 83/100, Train Loss: 2.3463, Val Loss: 5.1248, LR: 0.000014
# Epoch 84/100, Train Loss: 2.3347, Val Loss: 5.0943, LR: 0.000014
# Epoch 85/100, Train Loss: 2.3262, Val Loss: 5.1117, LR: 0.000014
# EarlyStopping counter: 1 out of 5
# Epoch 86/100, Train Loss: 2.3137, Val Loss: 5.0718, LR: 0.000014
# Epoch 87/100, Train Loss: 2.3084, Val Loss: 5.0606, LR: 0.000014
# Epoch 88/100, Train Loss: 2.3029, Val Loss: 5.0786, LR: 0.000014
# EarlyStopping counter: 1 out of 5
# Epoch 89/100, Train Loss: 2.2987, Val Loss: 5.0409, LR: 0.000013
# Epoch 90/100, Train Loss: 2.2860, Val Loss: 5.0089, LR: 0.000013
# Epoch 91/100, Train Loss: 2.2815, Val Loss: 5.0146, LR: 0.000013
# EarlyStopping counter: 1 out of 5
# Epoch 92/100, Train Loss: 2.2783, Val Loss: 5.0047, LR: 0.000013
# Epoch 93/100, Train Loss: 2.2718, Val Loss: 4.9871, LR: 0.000013
# Epoch 94/100, Train Loss: 2.2625, Val Loss: 4.9799, LR: 0.000013
# Epoch 95/100, Train Loss: 2.2540, Val Loss: 4.9331, LR: 0.000012
# Epoch 96/100, Train Loss: 2.2497, Val Loss: 4.9219, LR: 0.000012
# Epoch 97/100, Train Loss: 2.2434, Val Loss: 4.8969, LR: 0.000012
# Epoch 98/100, Train Loss: 2.2421, Val Loss: 4.8808, LR: 0.000012
# Epoch 99/100, Train Loss: 2.2324, Val Loss: 4.8534, LR: 0.000011
# Epoch 100/100, Train Loss: 2.2253, Val Loss: 4.8433, LR: 0.000011
# [I 2024-12-10 16:44:26,321] Trial 1 finished with value: 5.030126057956857 and parameters: {'time2vec_dim': 27, 'hidden_dim': 64, 'batch_size': 64, 'learning_rate': 1.4719673276896975e-05, 'dropout': 0.2970278656091043, 'clip_grad_norm': 1.1890288162465323, 'warmup_epochs': 3, 'patience': 5}. Best is trial 0 with value: 3.7821019935814957.
# Epoch 1/100, Train Loss: 4.0068, Val Loss: 6.9645, LR: 0.000033
# Epoch 2/100, Train Loss: 2.6270, Val Loss: 4.6839, LR: 0.000054
# Epoch 3/100, Train Loss: 2.4236, Val Loss: 4.2168, LR: 0.000075
# Epoch 4/100, Train Loss: 2.2309, Val Loss: 3.9246, LR: 0.000096
# Epoch 5/100, Train Loss: 2.1093, Val Loss: 3.7237, LR: 0.000117
# Epoch 6/100, Train Loss: 2.0411, Val Loss: 3.5878, LR: 0.000115
# Epoch 7/100, Train Loss: 1.9799, Val Loss: 3.5245, LR: 0.000106
# Epoch 8/100, Train Loss: 1.9369, Val Loss: 3.5146, LR: 0.000093
# Epoch 9/100, Train Loss: 1.9021, Val Loss: 3.5308, LR: 0.000077
# EarlyStopping counter: 1 out of 14
# Epoch 10/100, Train Loss: 1.8617, Val Loss: 3.5682, LR: 0.000059
# EarlyStopping counter: 2 out of 14
# Epoch 11/100, Train Loss: 1.8299, Val Loss: 3.6150, LR: 0.000041
# EarlyStopping counter: 3 out of 14
# Epoch 12/100, Train Loss: 1.8059, Val Loss: 3.6450, LR: 0.000025
# EarlyStopping counter: 4 out of 14
# Epoch 13/100, Train Loss: 1.7911, Val Loss: 3.6723, LR: 0.000012
# EarlyStopping counter: 5 out of 14
# Epoch 14/100, Train Loss: 1.7767, Val Loss: 3.6921, LR: 0.000004
# EarlyStopping counter: 6 out of 14
# Epoch 15/100, Train Loss: 1.7731, Val Loss: 3.7002, LR: 0.000117
# EarlyStopping counter: 7 out of 14
# Epoch 16/100, Train Loss: 1.7501, Val Loss: 3.8216, LR: 0.000117
# EarlyStopping counter: 8 out of 14
# Epoch 17/100, Train Loss: 1.7098, Val Loss: 3.9887, LR: 0.000115
# EarlyStopping counter: 9 out of 14
# Epoch 18/100, Train Loss: 1.6793, Val Loss: 4.0040, LR: 0.000111
# EarlyStopping counter: 10 out of 14
# Epoch 19/100, Train Loss: 1.6512, Val Loss: 4.1735, LR: 0.000106
# EarlyStopping counter: 11 out of 14
# Epoch 20/100, Train Loss: 1.6264, Val Loss: 4.3058, LR: 0.000100
# EarlyStopping counter: 12 out of 14
# Epoch 21/100, Train Loss: 1.6074, Val Loss: 4.4721, LR: 0.000093
# EarlyStopping counter: 13 out of 14
# Epoch 22/100, Train Loss: 1.5951, Val Loss: 4.4317, LR: 0.000086
# EarlyStopping counter: 14 out of 14
# Early stopping triggered
# [I 2024-12-10 17:00:35,772] Trial 2 finished with value: 4.91536446795205 and parameters: {'time2vec_dim': 25, 'hidden_dim': 128, 'batch_size': 32, 'learning_rate': 0.00011744652759001535, 'dropout': 0.35318317455824544, 'clip_grad_norm': 1.6475039070171837, 'warmup_epochs': 5, 'patience': 14}. Best is trial 0 with value: 3.7821019935814957.
# Epoch 1/100, Train Loss: 3.4237, Val Loss: 6.7469, LR: 0.000015
# Epoch 2/100, Train Loss: 2.6411, Val Loss: 4.8697, LR: 0.000024
# Epoch 3/100, Train Loss: 2.4849, Val Loss: 4.4948, LR: 0.000033
# Epoch 4/100, Train Loss: 2.3659, Val Loss: 4.2838, LR: 0.000042
# Epoch 5/100, Train Loss: 2.2840, Val Loss: 4.1795, LR: 0.000052
# Epoch 6/100, Train Loss: 2.2380, Val Loss: 4.1042, LR: 0.000061
# Epoch 7/100, Train Loss: 2.1882, Val Loss: 3.9826, LR: 0.000059
# Epoch 8/100, Train Loss: 2.1435, Val Loss: 3.9077, LR: 0.000055
# Epoch 9/100, Train Loss: 2.1071, Val Loss: 3.8214, LR: 0.000048
# Epoch 10/100, Train Loss: 2.0787, Val Loss: 3.7596, LR: 0.000040
# Epoch 11/100, Train Loss: 2.0536, Val Loss: 3.6987, LR: 0.000031
# Epoch 12/100, Train Loss: 2.0319, Val Loss: 3.6557, LR: 0.000022
# Epoch 13/100, Train Loss: 2.0155, Val Loss: 3.6282, LR: 0.000013
# Epoch 14/100, Train Loss: 2.0051, Val Loss: 3.6125, LR: 0.000007
# Epoch 15/100, Train Loss: 1.9919, Val Loss: 3.6005, LR: 0.000002
# Epoch 16/100, Train Loss: 1.9925, Val Loss: 3.5960, LR: 0.000061
# Epoch 17/100, Train Loss: 1.9843, Val Loss: 3.5466, LR: 0.000060
# Epoch 18/100, Train Loss: 1.9520, Val Loss: 3.5133, LR: 0.000059
# Epoch 19/100, Train Loss: 1.9247, Val Loss: 3.4879, LR: 0.000057
# Epoch 20/100, Train Loss: 1.9039, Val Loss: 3.4776, LR: 0.000055
# Epoch 21/100, Train Loss: 1.8744, Val Loss: 3.4708, LR: 0.000052
# Epoch 22/100, Train Loss: 1.8477, Val Loss: 3.4695, LR: 0.000048
# Epoch 23/100, Train Loss: 1.8218, Val Loss: 3.4933, LR: 0.000044
# EarlyStopping counter: 1 out of 11
# Epoch 24/100, Train Loss: 1.7982, Val Loss: 3.5152, LR: 0.000040
# EarlyStopping counter: 2 out of 11
# Epoch 25/100, Train Loss: 1.7809, Val Loss: 3.5312, LR: 0.000035
# EarlyStopping counter: 3 out of 11
# Epoch 26/100, Train Loss: 1.7596, Val Loss: 3.5639, LR: 0.000031
# EarlyStopping counter: 4 out of 11
# Epoch 27/100, Train Loss: 1.7351, Val Loss: 3.5836, LR: 0.000026
# EarlyStopping counter: 5 out of 11
# Epoch 28/100, Train Loss: 1.7182, Val Loss: 3.6410, LR: 0.000022
# EarlyStopping counter: 6 out of 11
# Epoch 29/100, Train Loss: 1.7036, Val Loss: 3.6615, LR: 0.000017
# EarlyStopping counter: 7 out of 11
# Epoch 30/100, Train Loss: 1.6936, Val Loss: 3.6760, LR: 0.000013
# EarlyStopping counter: 8 out of 11
# Epoch 31/100, Train Loss: 1.6787, Val Loss: 3.7197, LR: 0.000010
# EarlyStopping counter: 9 out of 11
# Epoch 32/100, Train Loss: 1.6739, Val Loss: 3.7357, LR: 0.000007
# EarlyStopping counter: 10 out of 11
# Epoch 33/100, Train Loss: 1.6670, Val Loss: 3.7599, LR: 0.000004
# EarlyStopping counter: 11 out of 11
# Early stopping triggered
# [I 2024-12-10 17:29:18,327] Trial 3 finished with value: 3.986182672314301 and parameters: {'time2vec_dim': 20, 'hidden_dim': 160, 'batch_size': 32, 'learning_rate': 6.064010122295884e-05, 'dropout': 0.287151782623188, 'clip_grad_norm': 2.9341048066090614, 'warmup_epochs': 6, 'patience': 11}. Best is trial 0 with value: 3.7821019935814957.
# Epoch 1/100, Train Loss: 5.1515, Val Loss: 10.7707, LR: 0.000019
# Epoch 2/100, Train Loss: 4.5628, Val Loss: 9.7024, LR: 0.000029
# Epoch 3/100, Train Loss: 3.7583, Val Loss: 8.6178, LR: 0.000039
# Epoch 4/100, Train Loss: 3.0907, Val Loss: 7.5729, LR: 0.000050
# Epoch 5/100, Train Loss: 2.7915, Val Loss: 6.8672, LR: 0.000060
# Epoch 6/100, Train Loss: 2.7136, Val Loss: 6.5010, LR: 0.000071
# Epoch 7/100, Train Loss: 2.6777, Val Loss: 6.2589, LR: 0.000081
# Epoch 8/100, Train Loss: 2.6475, Val Loss: 6.0550, LR: 0.000079
# Epoch 9/100, Train Loss: 2.6193, Val Loss: 5.9220, LR: 0.000073
# Epoch 10/100, Train Loss: 2.5844, Val Loss: 5.8393, LR: 0.000064
# Epoch 11/100, Train Loss: 2.5542, Val Loss: 5.7760, LR: 0.000053
# Epoch 12/100, Train Loss: 2.5222, Val Loss: 5.7519, LR: 0.000041
# Epoch 13/100, Train Loss: 2.4833, Val Loss: 5.6680, LR: 0.000029
# Epoch 14/100, Train Loss: 2.4666, Val Loss: 5.6015, LR: 0.000017
# Epoch 15/100, Train Loss: 2.4492, Val Loss: 5.5738, LR: 0.000009
# Epoch 16/100, Train Loss: 2.4365, Val Loss: 5.5537, LR: 0.000003
# Epoch 17/100, Train Loss: 2.4340, Val Loss: 5.5477, LR: 0.000081
# Epoch 18/100, Train Loss: 2.4138, Val Loss: 5.3747, LR: 0.000080
# Epoch 19/100, Train Loss: 2.3723, Val Loss: 5.2753, LR: 0.000079
# Epoch 20/100, Train Loss: 2.3431, Val Loss: 5.1924, LR: 0.000077
# Epoch 21/100, Train Loss: 2.3093, Val Loss: 5.1233, LR: 0.000073
# Epoch 22/100, Train Loss: 2.2980, Val Loss: 5.0685, LR: 0.000069
# Epoch 23/100, Train Loss: 2.2847, Val Loss: 5.0333, LR: 0.000064
# Epoch 24/100, Train Loss: 2.2716, Val Loss: 4.9965, LR: 0.000059
# Epoch 25/100, Train Loss: 2.2628, Val Loss: 4.9589, LR: 0.000053
# Epoch 26/100, Train Loss: 2.2420, Val Loss: 4.9218, LR: 0.000047
# Epoch 27/100, Train Loss: 2.2323, Val Loss: 4.8902, LR: 0.000041
# Epoch 28/100, Train Loss: 2.2270, Val Loss: 4.8497, LR: 0.000035
# Epoch 29/100, Train Loss: 2.2127, Val Loss: 4.8150, LR: 0.000029
# Epoch 30/100, Train Loss: 2.2058, Val Loss: 4.7827, LR: 0.000023
# Epoch 31/100, Train Loss: 2.1981, Val Loss: 4.7671, LR: 0.000017
# Epoch 32/100, Train Loss: 2.1938, Val Loss: 4.7484, LR: 0.000013
# Epoch 33/100, Train Loss: 2.1923, Val Loss: 4.7360, LR: 0.000009
# Epoch 34/100, Train Loss: 2.1870, Val Loss: 4.7271, LR: 0.000005
# Epoch 35/100, Train Loss: 2.1897, Val Loss: 4.7218, LR: 0.000003
# Epoch 36/100, Train Loss: 2.1912, Val Loss: 4.7177, LR: 0.000001
# Epoch 37/100, Train Loss: 2.1909, Val Loss: 4.7169, LR: 0.000081
# Epoch 38/100, Train Loss: 2.1822, Val Loss: 4.6399, LR: 0.000081
# Epoch 39/100, Train Loss: 2.1625, Val Loss: 4.5569, LR: 0.000080
# Epoch 40/100, Train Loss: 2.1544, Val Loss: 4.4862, LR: 0.000080
# Epoch 41/100, Train Loss: 2.1415, Val Loss: 4.4361, LR: 0.000079
# Epoch 42/100, Train Loss: 2.1321, Val Loss: 4.3857, LR: 0.000078
# Epoch 43/100, Train Loss: 2.1178, Val Loss: 4.3153, LR: 0.000077
# Epoch 44/100, Train Loss: 2.1040, Val Loss: 4.2506, LR: 0.000075
# Epoch 45/100, Train Loss: 2.0959, Val Loss: 4.2046, LR: 0.000073
# Epoch 46/100, Train Loss: 2.0835, Val Loss: 4.1542, LR: 0.000071
# Epoch 47/100, Train Loss: 2.0711, Val Loss: 4.1057, LR: 0.000069
# Epoch 48/100, Train Loss: 2.0606, Val Loss: 4.0540, LR: 0.000067
# Epoch 49/100, Train Loss: 2.0509, Val Loss: 4.0109, LR: 0.000064
# Epoch 50/100, Train Loss: 2.0424, Val Loss: 3.9733, LR: 0.000062
# Epoch 51/100, Train Loss: 2.0389, Val Loss: 3.9376, LR: 0.000059
# Epoch 52/100, Train Loss: 2.0276, Val Loss: 3.9046, LR: 0.000056
# Epoch 53/100, Train Loss: 2.0152, Val Loss: 3.8706, LR: 0.000053
# Epoch 54/100, Train Loss: 2.0056, Val Loss: 3.8377, LR: 0.000050
# Epoch 55/100, Train Loss: 2.0040, Val Loss: 3.8120, LR: 0.000047
# Epoch 56/100, Train Loss: 1.9954, Val Loss: 3.7891, LR: 0.000044
# Epoch 57/100, Train Loss: 1.9925, Val Loss: 3.7680, LR: 0.000041
# Epoch 58/100, Train Loss: 1.9810, Val Loss: 3.7512, LR: 0.000038
# Epoch 59/100, Train Loss: 1.9755, Val Loss: 3.7336, LR: 0.000035
# Epoch 60/100, Train Loss: 1.9751, Val Loss: 3.7155, LR: 0.000032
# Epoch 61/100, Train Loss: 1.9673, Val Loss: 3.7012, LR: 0.000029
# Epoch 62/100, Train Loss: 1.9652, Val Loss: 3.6915, LR: 0.000026
# Epoch 63/100, Train Loss: 1.9618, Val Loss: 3.6791, LR: 0.000023
# Epoch 64/100, Train Loss: 1.9572, Val Loss: 3.6678, LR: 0.000020
# Epoch 65/100, Train Loss: 1.9542, Val Loss: 3.6595, LR: 0.000017
# Epoch 66/100, Train Loss: 1.9531, Val Loss: 3.6532, LR: 0.000015
# Epoch 67/100, Train Loss: 1.9502, Val Loss: 3.6483, LR: 0.000013
# Epoch 68/100, Train Loss: 1.9480, Val Loss: 3.6430, LR: 0.000011
# Epoch 69/100, Train Loss: 1.9465, Val Loss: 3.6388, LR: 0.000009
# Epoch 70/100, Train Loss: 1.9464, Val Loss: 3.6354, LR: 0.000007
# Epoch 71/100, Train Loss: 1.9433, Val Loss: 3.6328, LR: 0.000005
# Epoch 72/100, Train Loss: 1.9426, Val Loss: 3.6307, LR: 0.000004
# Epoch 73/100, Train Loss: 1.9426, Val Loss: 3.6288, LR: 0.000003
# Epoch 74/100, Train Loss: 1.9400, Val Loss: 3.6278, LR: 0.000002
# Epoch 75/100, Train Loss: 1.9432, Val Loss: 3.6271, LR: 0.000001
# Epoch 76/100, Train Loss: 1.9408, Val Loss: 3.6267, LR: 0.000001
# Epoch 77/100, Train Loss: 1.9417, Val Loss: 3.6261, LR: 0.000081
# Epoch 78/100, Train Loss: 1.9373, Val Loss: 3.5987, LR: 0.000081
# Epoch 79/100, Train Loss: 1.9251, Val Loss: 3.5785, LR: 0.000081
# Epoch 80/100, Train Loss: 1.9174, Val Loss: 3.5600, LR: 0.000081
# Epoch 81/100, Train Loss: 1.9079, Val Loss: 3.5411, LR: 0.000080
# Epoch 82/100, Train Loss: 1.8955, Val Loss: 3.5331, LR: 0.000080
# Epoch 83/100, Train Loss: 1.8882, Val Loss: 3.5192, LR: 0.000080
# Epoch 84/100, Train Loss: 1.8767, Val Loss: 3.5100, LR: 0.000079
# Epoch 85/100, Train Loss: 1.8655, Val Loss: 3.5012, LR: 0.000079
# Epoch 86/100, Train Loss: 1.8563, Val Loss: 3.4976, LR: 0.000079
# Epoch 87/100, Train Loss: 1.8518, Val Loss: 3.4931, LR: 0.000078
# Epoch 88/100, Train Loss: 1.8394, Val Loss: 3.4895, LR: 0.000077
# Epoch 89/100, Train Loss: 1.8340, Val Loss: 3.4901, LR: 0.000077
# EarlyStopping counter: 1 out of 12
# Epoch 90/100, Train Loss: 1.8241, Val Loss: 3.4909, LR: 0.000076
# EarlyStopping counter: 2 out of 12
# Epoch 91/100, Train Loss: 1.8145, Val Loss: 3.4943, LR: 0.000075
# EarlyStopping counter: 3 out of 12
# Epoch 92/100, Train Loss: 1.8088, Val Loss: 3.4992, LR: 0.000074
# EarlyStopping counter: 4 out of 12
# Epoch 93/100, Train Loss: 1.8008, Val Loss: 3.5052, LR: 0.000073
# EarlyStopping counter: 5 out of 12
# Epoch 94/100, Train Loss: 1.7933, Val Loss: 3.5132, LR: 0.000072
# EarlyStopping counter: 6 out of 12
# Epoch 95/100, Train Loss: 1.7844, Val Loss: 3.5263, LR: 0.000071
# EarlyStopping counter: 7 out of 12
# Epoch 96/100, Train Loss: 1.7778, Val Loss: 3.5376, LR: 0.000070
# EarlyStopping counter: 8 out of 12
# Epoch 97/100, Train Loss: 1.7718, Val Loss: 3.5506, LR: 0.000069
# EarlyStopping counter: 9 out of 12
# Epoch 98/100, Train Loss: 1.7618, Val Loss: 3.5686, LR: 0.000068
# EarlyStopping counter: 10 out of 12
# Epoch 99/100, Train Loss: 1.7549, Val Loss: 3.5846, LR: 0.000067
# EarlyStopping counter: 11 out of 12
# Epoch 100/100, Train Loss: 1.7462, Val Loss: 3.6039, LR: 0.000066
# EarlyStopping counter: 12 out of 12
# Early stopping triggered
# [I 2024-12-10 17:59:53,361] Trial 4 finished with value: 3.8743805415428043 and parameters: {'time2vec_dim': 25, 'hidden_dim': 64, 'batch_size': 128, 'learning_rate': 8.097149324929324e-05, 'dropout': 0.16614655490957767, 'clip_grad_norm': 4.980620699828993, 'warmup_epochs': 7, 'patience': 12}. Best is trial 0 with value: 3.7821019935814957.
# Epoch 1/100, Train Loss: 3.9035, Val Loss: 8.0920, LR: 0.000916
# Epoch 2/100, Train Loss: 2.7600, Val Loss: 6.2799, LR: 0.000894
# Epoch 3/100, Train Loss: 2.5750, Val Loss: 5.2607, LR: 0.000829
# Epoch 4/100, Train Loss: 2.3300, Val Loss: 4.4709, LR: 0.000728
# Epoch 5/100, Train Loss: 2.1472, Val Loss: 3.8912, LR: 0.000600
# Epoch 6/100, Train Loss: 2.0288, Val Loss: 3.6350, LR: 0.000459
# Epoch 7/100, Train Loss: 1.9627, Val Loss: 3.5181, LR: 0.000317
# Epoch 8/100, Train Loss: 1.9198, Val Loss: 3.4801, LR: 0.000190
# Epoch 9/100, Train Loss: 1.8874, Val Loss: 3.4766, LR: 0.000088
# Epoch 10/100, Train Loss: 1.8633, Val Loss: 3.4778, LR: 0.000023
# EarlyStopping counter: 1 out of 5
# Epoch 11/100, Train Loss: 1.8569, Val Loss: 3.4782, LR: 0.000916
# EarlyStopping counter: 2 out of 5
# Epoch 12/100, Train Loss: 1.8112, Val Loss: 3.6235, LR: 0.000911
# EarlyStopping counter: 3 out of 5
# Epoch 13/100, Train Loss: 1.7646, Val Loss: 3.7867, LR: 0.000894
# EarlyStopping counter: 4 out of 5
# Epoch 14/100, Train Loss: 1.7269, Val Loss: 3.9442, LR: 0.000866
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# [I 2024-12-10 18:04:10,529] Trial 5 finished with value: 3.823477099512158 and parameters: {'time2vec_dim': 17, 'hidden_dim': 64, 'batch_size': 128, 'learning_rate': 0.0009162245317156163, 'dropout': 0.3682898584199904, 'clip_grad_norm': 1.3573694236472529, 'warmup_epochs': 1, 'patience': 5}. Best is trial 0 with value: 3.7821019935814957.
# Epoch 1/100, Train Loss: 4.0593, Val Loss: 8.0391, LR: 0.000010
# Epoch 2/100, Train Loss: 2.7832, Val Loss: 5.4296, LR: 0.000015
# Epoch 3/100, Train Loss: 2.5577, Val Loss: 4.3782, LR: 0.000020
# Epoch 4/100, Train Loss: 2.4080, Val Loss: 3.8979, LR: 0.000025
# Epoch 5/100, Train Loss: 2.3016, Val Loss: 3.7851, LR: 0.000030
# Epoch 6/100, Train Loss: 2.2035, Val Loss: 3.7050, LR: 0.000035
# Epoch 7/100, Train Loss: 2.1122, Val Loss: 3.6116, LR: 0.000040
# Epoch 8/100, Train Loss: 2.0623, Val Loss: 3.5598, LR: 0.000045
# Epoch 9/100, Train Loss: 2.0247, Val Loss: 3.5361, LR: 0.000050
# Epoch 10/100, Train Loss: 1.9909, Val Loss: 3.5139, LR: 0.000055
# Epoch 11/100, Train Loss: 1.9602, Val Loss: 3.4961, LR: 0.000054
# Epoch 12/100, Train Loss: 1.9313, Val Loss: 3.4938, LR: 0.000050
# Epoch 13/100, Train Loss: 1.9166, Val Loss: 3.4883, LR: 0.000044
# Epoch 14/100, Train Loss: 1.8962, Val Loss: 3.4866, LR: 0.000036
# Epoch 15/100, Train Loss: 1.8770, Val Loss: 3.4896, LR: 0.000028
# EarlyStopping counter: 1 out of 5
# Epoch 16/100, Train Loss: 1.8645, Val Loss: 3.4975, LR: 0.000020
# EarlyStopping counter: 2 out of 5
# Epoch 17/100, Train Loss: 1.8545, Val Loss: 3.4998, LR: 0.000012
# EarlyStopping counter: 3 out of 5
# Epoch 18/100, Train Loss: 1.8475, Val Loss: 3.5054, LR: 0.000006
# EarlyStopping counter: 4 out of 5
# Epoch 19/100, Train Loss: 1.8407, Val Loss: 3.5094, LR: 0.000002
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# [I 2024-12-10 18:29:44,885] Trial 6 finished with value: 3.7284453183284936 and parameters: {'time2vec_dim': 20, 'hidden_dim': 256, 'batch_size': 64, 'learning_rate': 5.4878277865959156e-05, 'dropout': 0.3550216240380967, 'clip_grad_norm': 3.1518173039593664, 'warmup_epochs': 10, 'patience': 5}. Best is trial 6 with value: 3.7284453183284936.
# Epoch 1/100, Train Loss: 4.3553, Val Loss: 8.5160, LR: 0.000008
# Epoch 2/100, Train Loss: 2.9501, Val Loss: 5.6137, LR: 0.000013
# Epoch 3/100, Train Loss: 2.6134, Val Loss: 4.5537, LR: 0.000017
# Epoch 4/100, Train Loss: 2.4682, Val Loss: 3.9715, LR: 0.000021
# Epoch 5/100, Train Loss: 2.3679, Val Loss: 3.8082, LR: 0.000026
# Epoch 6/100, Train Loss: 2.2935, Val Loss: 3.7673, LR: 0.000030
# Epoch 7/100, Train Loss: 2.2289, Val Loss: 3.6971, LR: 0.000035
# Epoch 8/100, Train Loss: 2.1872, Val Loss: 3.6619, LR: 0.000039
# Epoch 9/100, Train Loss: 2.1391, Val Loss: 3.6232, LR: 0.000038
# Epoch 10/100, Train Loss: 2.0945, Val Loss: 3.5894, LR: 0.000035
# Epoch 11/100, Train Loss: 2.0622, Val Loss: 3.5708, LR: 0.000031
# Epoch 12/100, Train Loss: 2.0352, Val Loss: 3.5490, LR: 0.000026
# Epoch 13/100, Train Loss: 2.0203, Val Loss: 3.5348, LR: 0.000020
# Epoch 14/100, Train Loss: 2.0050, Val Loss: 3.5298, LR: 0.000014
# Epoch 15/100, Train Loss: 1.9910, Val Loss: 3.5157, LR: 0.000009
# Epoch 16/100, Train Loss: 1.9859, Val Loss: 3.5195, LR: 0.000005
# EarlyStopping counter: 1 out of 5
# Epoch 17/100, Train Loss: 1.9788, Val Loss: 3.5180, LR: 0.000002
# EarlyStopping counter: 2 out of 5
# Epoch 18/100, Train Loss: 1.9785, Val Loss: 3.5181, LR: 0.000039
# EarlyStopping counter: 3 out of 5
# Epoch 19/100, Train Loss: 1.9682, Val Loss: 3.5061, LR: 0.000039
# Epoch 20/100, Train Loss: 1.9632, Val Loss: 3.4931, LR: 0.000038
# Epoch 21/100, Train Loss: 1.9457, Val Loss: 3.4860, LR: 0.000037
# Epoch 22/100, Train Loss: 1.9348, Val Loss: 3.4829, LR: 0.000035
# Epoch 23/100, Train Loss: 1.9236, Val Loss: 3.4752, LR: 0.000033
# Epoch 24/100, Train Loss: 1.9140, Val Loss: 3.4704, LR: 0.000031
# Epoch 25/100, Train Loss: 1.9036, Val Loss: 3.4693, LR: 0.000029
# Epoch 26/100, Train Loss: 1.8976, Val Loss: 3.4675, LR: 0.000026
# Epoch 27/100, Train Loss: 1.8848, Val Loss: 3.4659, LR: 0.000023
# Epoch 28/100, Train Loss: 1.8812, Val Loss: 3.4644, LR: 0.000020
# Epoch 29/100, Train Loss: 1.8758, Val Loss: 3.4684, LR: 0.000017
# EarlyStopping counter: 1 out of 5
# Epoch 30/100, Train Loss: 1.8680, Val Loss: 3.4655, LR: 0.000014
# EarlyStopping counter: 2 out of 5
# Epoch 31/100, Train Loss: 1.8631, Val Loss: 3.4690, LR: 0.000011
# EarlyStopping counter: 3 out of 5
# Epoch 32/100, Train Loss: 1.8552, Val Loss: 3.4685, LR: 0.000009
# EarlyStopping counter: 4 out of 5
# Epoch 33/100, Train Loss: 1.8526, Val Loss: 3.4734, LR: 0.000007
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# [I 2024-12-10 19:14:12,143] Trial 7 finished with value: 3.781928082457884 and parameters: {'time2vec_dim': 30, 'hidden_dim': 256, 'batch_size': 64, 'learning_rate': 3.895255894262483e-05, 'dropout': 0.40583446014277424, 'clip_grad_norm': 4.450469756515442, 'warmup_epochs': 8, 'patience': 5}. Best is trial 6 with value: 3.7284453183284936.
# Epoch 1/100, Train Loss: 5.0821, Val Loss: 10.2272, LR: 0.000011
# Epoch 2/100, Train Loss: 4.4828, Val Loss: 9.3608, LR: 0.000017
# Epoch 3/100, Train Loss: 3.5619, Val Loss: 8.1042, LR: 0.000023
# Epoch 4/100, Train Loss: 2.8804, Val Loss: 6.5334, LR: 0.000029
# Epoch 5/100, Train Loss: 2.6942, Val Loss: 5.8308, LR: 0.000035
# Epoch 6/100, Train Loss: 2.6360, Val Loss: 5.4085, LR: 0.000041
# Epoch 7/100, Train Loss: 2.5654, Val Loss: 5.0925, LR: 0.000047
# Epoch 8/100, Train Loss: 2.5077, Val Loss: 4.8675, LR: 0.000045
# Epoch 9/100, Train Loss: 2.4535, Val Loss: 4.7073, LR: 0.000042
# Epoch 10/100, Train Loss: 2.4207, Val Loss: 4.6831, LR: 0.000037
# Epoch 11/100, Train Loss: 2.3889, Val Loss: 4.6101, LR: 0.000031
# Epoch 12/100, Train Loss: 2.3635, Val Loss: 4.5879, LR: 0.000024
# Epoch 13/100, Train Loss: 2.3320, Val Loss: 4.5682, LR: 0.000017
# Epoch 14/100, Train Loss: 2.3154, Val Loss: 4.5636, LR: 0.000010
# Epoch 15/100, Train Loss: 2.3009, Val Loss: 4.5357, LR: 0.000005
# Epoch 16/100, Train Loss: 2.2989, Val Loss: 4.5308, LR: 0.000002
# Epoch 17/100, Train Loss: 2.2967, Val Loss: 4.5331, LR: 0.000047
# EarlyStopping counter: 1 out of 9
# Epoch 18/100, Train Loss: 2.2759, Val Loss: 4.4617, LR: 0.000046
# Epoch 19/100, Train Loss: 2.2432, Val Loss: 4.4649, LR: 0.000045
# EarlyStopping counter: 1 out of 9
# Epoch 20/100, Train Loss: 2.2126, Val Loss: 4.3454, LR: 0.000044
# Epoch 21/100, Train Loss: 2.1869, Val Loss: 4.3116, LR: 0.000042
# Epoch 22/100, Train Loss: 2.1584, Val Loss: 4.1919, LR: 0.000040
# Epoch 23/100, Train Loss: 2.1388, Val Loss: 4.1387, LR: 0.000037
# Epoch 24/100, Train Loss: 2.1209, Val Loss: 4.0867, LR: 0.000034
# Epoch 25/100, Train Loss: 2.1072, Val Loss: 4.0401, LR: 0.000031
# Epoch 26/100, Train Loss: 2.0904, Val Loss: 3.9962, LR: 0.000027
# Epoch 27/100, Train Loss: 2.0825, Val Loss: 3.9348, LR: 0.000024
# Epoch 28/100, Train Loss: 2.0681, Val Loss: 3.9199, LR: 0.000020
# Epoch 29/100, Train Loss: 2.0577, Val Loss: 3.8866, LR: 0.000017
# Epoch 30/100, Train Loss: 2.0534, Val Loss: 3.8774, LR: 0.000013
# Epoch 31/100, Train Loss: 2.0464, Val Loss: 3.8524, LR: 0.000010
# Epoch 32/100, Train Loss: 2.0405, Val Loss: 3.8420, LR: 0.000008
# Epoch 33/100, Train Loss: 2.0402, Val Loss: 3.8317, LR: 0.000005
# Epoch 34/100, Train Loss: 2.0308, Val Loss: 3.8269, LR: 0.000003
# Epoch 35/100, Train Loss: 2.0387, Val Loss: 3.8214, LR: 0.000002
# Epoch 36/100, Train Loss: 2.0311, Val Loss: 3.8198, LR: 0.000001
# Epoch 37/100, Train Loss: 2.0310, Val Loss: 3.8190, LR: 0.000047
# Epoch 38/100, Train Loss: 2.0269, Val Loss: 3.7777, LR: 0.000046
# Epoch 39/100, Train Loss: 2.0150, Val Loss: 3.7269, LR: 0.000046
# Epoch 40/100, Train Loss: 2.0018, Val Loss: 3.6865, LR: 0.000046
# Epoch 41/100, Train Loss: 1.9880, Val Loss: 3.6599, LR: 0.000045
# Epoch 42/100, Train Loss: 1.9728, Val Loss: 3.6226, LR: 0.000045
# Epoch 43/100, Train Loss: 1.9613, Val Loss: 3.5963, LR: 0.000044
# Epoch 44/100, Train Loss: 1.9505, Val Loss: 3.5727, LR: 0.000043
# Epoch 45/100, Train Loss: 1.9420, Val Loss: 3.5454, LR: 0.000042
# Epoch 46/100, Train Loss: 1.9335, Val Loss: 3.5232, LR: 0.000041
# Epoch 47/100, Train Loss: 1.9182, Val Loss: 3.5108, LR: 0.000040
# Epoch 48/100, Train Loss: 1.9130, Val Loss: 3.4938, LR: 0.000039
# Epoch 49/100, Train Loss: 1.9044, Val Loss: 3.4799, LR: 0.000037
# Epoch 50/100, Train Loss: 1.8965, Val Loss: 3.4693, LR: 0.000036
# Epoch 51/100, Train Loss: 1.8916, Val Loss: 3.4595, LR: 0.000034
# Epoch 52/100, Train Loss: 1.8830, Val Loss: 3.4541, LR: 0.000032
# Epoch 53/100, Train Loss: 1.8773, Val Loss: 3.4477, LR: 0.000031
# Epoch 54/100, Train Loss: 1.8691, Val Loss: 3.4398, LR: 0.000029
# Epoch 55/100, Train Loss: 1.8618, Val Loss: 3.4366, LR: 0.000027
# Epoch 56/100, Train Loss: 1.8562, Val Loss: 3.4349, LR: 0.000026
# Epoch 57/100, Train Loss: 1.8500, Val Loss: 3.4296, LR: 0.000024
# Epoch 58/100, Train Loss: 1.8443, Val Loss: 3.4275, LR: 0.000022
# Epoch 59/100, Train Loss: 1.8386, Val Loss: 3.4206, LR: 0.000020
# Epoch 60/100, Train Loss: 1.8341, Val Loss: 3.4186, LR: 0.000018
# Epoch 61/100, Train Loss: 1.8273, Val Loss: 3.4164, LR: 0.000017
# Epoch 62/100, Train Loss: 1.8253, Val Loss: 3.4140, LR: 0.000015
# Epoch 63/100, Train Loss: 1.8218, Val Loss: 3.4122, LR: 0.000013
# Epoch 64/100, Train Loss: 1.8158, Val Loss: 3.4111, LR: 0.000012
# Epoch 65/100, Train Loss: 1.8131, Val Loss: 3.4100, LR: 0.000010
# Epoch 66/100, Train Loss: 1.8127, Val Loss: 3.4095, LR: 0.000009
# Epoch 67/100, Train Loss: 1.8118, Val Loss: 3.4090, LR: 0.000008
# Epoch 68/100, Train Loss: 1.8056, Val Loss: 3.4087, LR: 0.000006
# Epoch 69/100, Train Loss: 1.8017, Val Loss: 3.4080, LR: 0.000005
# Epoch 70/100, Train Loss: 1.8039, Val Loss: 3.4079, LR: 0.000004
# EarlyStopping counter: 1 out of 9
# Epoch 71/100, Train Loss: 1.8028, Val Loss: 3.4077, LR: 0.000003
# Epoch 72/100, Train Loss: 1.8025, Val Loss: 3.4075, LR: 0.000003
# Epoch 73/100, Train Loss: 1.7987, Val Loss: 3.4075, LR: 0.000002
# EarlyStopping counter: 1 out of 9
# Epoch 74/100, Train Loss: 1.8022, Val Loss: 3.4073, LR: 0.000002
# Epoch 75/100, Train Loss: 1.7955, Val Loss: 3.4072, LR: 0.000001
# Epoch 76/100, Train Loss: 1.7970, Val Loss: 3.4072, LR: 0.000001
# EarlyStopping counter: 1 out of 9
# Epoch 77/100, Train Loss: 1.7996, Val Loss: 3.4072, LR: 0.000047
# EarlyStopping counter: 2 out of 9
# Epoch 78/100, Train Loss: 1.7951, Val Loss: 3.4045, LR: 0.000047
# Epoch 79/100, Train Loss: 1.7848, Val Loss: 3.4053, LR: 0.000046
# EarlyStopping counter: 1 out of 9
# Epoch 80/100, Train Loss: 1.7748, Val Loss: 3.4028, LR: 0.000046
# Epoch 81/100, Train Loss: 1.7676, Val Loss: 3.4071, LR: 0.000046
# EarlyStopping counter: 1 out of 9
# Epoch 82/100, Train Loss: 1.7585, Val Loss: 3.4084, LR: 0.000046
# EarlyStopping counter: 2 out of 9
# Epoch 83/100, Train Loss: 1.7496, Val Loss: 3.4077, LR: 0.000046
# EarlyStopping counter: 3 out of 9
# Epoch 84/100, Train Loss: 1.7398, Val Loss: 3.4124, LR: 0.000046
# EarlyStopping counter: 4 out of 9
# Epoch 85/100, Train Loss: 1.7331, Val Loss: 3.4081, LR: 0.000045
# EarlyStopping counter: 5 out of 9
# Epoch 86/100, Train Loss: 1.7252, Val Loss: 3.4154, LR: 0.000045
# EarlyStopping counter: 6 out of 9
# Epoch 87/100, Train Loss: 1.7166, Val Loss: 3.4123, LR: 0.000045
# EarlyStopping counter: 7 out of 9
# Epoch 88/100, Train Loss: 1.7110, Val Loss: 3.4174, LR: 0.000044
# EarlyStopping counter: 8 out of 9
# Epoch 89/100, Train Loss: 1.6991, Val Loss: 3.4277, LR: 0.000044
# EarlyStopping counter: 9 out of 9
# Early stopping triggered
# [I 2024-12-10 20:00:50,620] Trial 8 finished with value: 3.905819930713647 and parameters: {'time2vec_dim': 28, 'hidden_dim': 128, 'batch_size': 128, 'learning_rate': 4.655510835158026e-05, 'dropout': 0.31698487548122833, 'clip_grad_norm': 3.303838258928474, 'warmup_epochs': 7, 'patience': 9}. Best is trial 6 with value: 3.7284453183284936.
# Trial failed with error: CUDA out of memory. Tried to allocate 54.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 32.12 MiB is free. Process 2364 has 14.71 GiB memory in use. Of the allocated memory 14.56 GiB is allocated by PyTorch, and 17.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [I 2024-12-10 20:00:52,239] Trial 9 finished with value: inf and parameters: {'time2vec_dim': 20, 'hidden_dim': 192, 'batch_size': 256, 'learning_rate': 0.00020998186164502853, 'dropout': 0.1624223337541078, 'clip_grad_norm': 2.902756764141866, 'warmup_epochs': 1, 'patience': 5}. Best is trial 6 with value: 3.7284453183284936.
#
# Optimization Results:
# Number of completed trials: 10
#
# Best trial:
# Value (RMSE): 3.7284
#
# Best hyperparameters:
#     time2vec_dim: 20
#     hidden_dim: 256
#     batch_size: 64
#     learning_rate: 5.4878277865959156e-05
#     dropout: 0.3550216240380967
#     clip_grad_norm: 3.1518173039593664
#     warmup_epochs: 10
#     patience: 5
#
# Performing cross-validation with best parameters...
# Epoch 1/100, Train Loss: 2.7350, Val Loss: 8.7132, LR: 0.000010
# Epoch 2/100, Train Loss: 1.7764, Val Loss: 7.1231, LR: 0.000015
# Epoch 3/100, Train Loss: 1.6836, Val Loss: 6.7690, LR: 0.000020
# Epoch 4/100, Train Loss: 1.6676, Val Loss: 6.5463, LR: 0.000025
# Epoch 5/100, Train Loss: 1.6446, Val Loss: 6.3173, LR: 0.000030
# Epoch 6/100, Train Loss: 1.6042, Val Loss: 6.3392, LR: 0.000035
# EarlyStopping counter: 1 out of 5
# Epoch 7/100, Train Loss: 1.5497, Val Loss: 5.7544, LR: 0.000040
# Epoch 8/100, Train Loss: 1.4886, Val Loss: 5.3087, LR: 0.000045
# Epoch 9/100, Train Loss: 1.4656, Val Loss: 5.2117, LR: 0.000050
# Epoch 10/100, Train Loss: 1.4518, Val Loss: 5.1667, LR: 0.000055
# Epoch 11/100, Train Loss: 1.4427, Val Loss: 4.9774, LR: 0.000054
# Epoch 12/100, Train Loss: 1.4349, Val Loss: 5.0721, LR: 0.000050
# EarlyStopping counter: 1 out of 5
# Epoch 13/100, Train Loss: 1.4296, Val Loss: 5.0363, LR: 0.000044
# EarlyStopping counter: 2 out of 5
# Epoch 14/100, Train Loss: 1.4262, Val Loss: 4.9768, LR: 0.000036
# Epoch 15/100, Train Loss: 1.4237, Val Loss: 5.0201, LR: 0.000028
# EarlyStopping counter: 1 out of 5
# Epoch 16/100, Train Loss: 1.4231, Val Loss: 5.0360, LR: 0.000020
# EarlyStopping counter: 2 out of 5
# Epoch 17/100, Train Loss: 1.4190, Val Loss: 4.9716, LR: 0.000012
# Epoch 18/100, Train Loss: 1.4187, Val Loss: 4.9594, LR: 0.000006
# Epoch 19/100, Train Loss: 1.4180, Val Loss: 5.0031, LR: 0.000002
# EarlyStopping counter: 1 out of 5
# Epoch 20/100, Train Loss: 1.4170, Val Loss: 5.0028, LR: 0.000055
# EarlyStopping counter: 2 out of 5
# Epoch 21/100, Train Loss: 1.4186, Val Loss: 4.9892, LR: 0.000055
# EarlyStopping counter: 3 out of 5
# Epoch 22/100, Train Loss: 1.4152, Val Loss: 5.0344, LR: 0.000054
# EarlyStopping counter: 4 out of 5
# Epoch 23/100, Train Loss: 1.4140, Val Loss: 4.9926, LR: 0.000052
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# Epoch 1/100, Train Loss: 2.8095, Val Loss: 8.8159, LR: 0.000010
# Epoch 2/100, Train Loss: 1.9168, Val Loss: 6.9585, LR: 0.000015
# Epoch 3/100, Train Loss: 1.8477, Val Loss: 6.1766, LR: 0.000020
# Epoch 4/100, Train Loss: 1.8096, Val Loss: 5.3466, LR: 0.000025
# Epoch 5/100, Train Loss: 1.7663, Val Loss: 4.9505, LR: 0.000030
# Epoch 6/100, Train Loss: 1.6777, Val Loss: 4.8519, LR: 0.000035
# Epoch 7/100, Train Loss: 1.6082, Val Loss: 4.6632, LR: 0.000040
# Epoch 8/100, Train Loss: 1.5800, Val Loss: 4.5805, LR: 0.000045
# Epoch 9/100, Train Loss: 1.5577, Val Loss: 4.5582, LR: 0.000050
# Epoch 10/100, Train Loss: 1.5440, Val Loss: 4.4972, LR: 0.000055
# Epoch 11/100, Train Loss: 1.5332, Val Loss: 4.4634, LR: 0.000054
# Epoch 12/100, Train Loss: 1.5257, Val Loss: 4.3181, LR: 0.000050
# Epoch 13/100, Train Loss: 1.5180, Val Loss: 4.2865, LR: 0.000044
# Epoch 14/100, Train Loss: 1.5170, Val Loss: 4.1852, LR: 0.000036
# Epoch 15/100, Train Loss: 1.5134, Val Loss: 4.1619, LR: 0.000028
# Epoch 16/100, Train Loss: 1.5114, Val Loss: 4.1145, LR: 0.000020
# Epoch 17/100, Train Loss: 1.5018, Val Loss: 4.0881, LR: 0.000012
# Epoch 18/100, Train Loss: 1.5032, Val Loss: 4.0841, LR: 0.000006
# Epoch 19/100, Train Loss: 1.5037, Val Loss: 4.0722, LR: 0.000002
# Epoch 20/100, Train Loss: 1.5020, Val Loss: 4.0675, LR: 0.000055
# Epoch 21/100, Train Loss: 1.4998, Val Loss: 4.0062, LR: 0.000055
# Epoch 22/100, Train Loss: 1.4988, Val Loss: 4.0091, LR: 0.000054
# EarlyStopping counter: 1 out of 5
# Epoch 23/100, Train Loss: 1.4995, Val Loss: 3.9688, LR: 0.000052
# Epoch 24/100, Train Loss: 1.4945, Val Loss: 4.0061, LR: 0.000050
# EarlyStopping counter: 1 out of 5
# Epoch 25/100, Train Loss: 1.4916, Val Loss: 3.9824, LR: 0.000047
# EarlyStopping counter: 2 out of 5
# Epoch 26/100, Train Loss: 1.4940, Val Loss: 3.9776, LR: 0.000044
# EarlyStopping counter: 3 out of 5
# Epoch 27/100, Train Loss: 1.4908, Val Loss: 3.9705, LR: 0.000040
# EarlyStopping counter: 4 out of 5
# Epoch 28/100, Train Loss: 1.4885, Val Loss: 4.0332, LR: 0.000036
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# Epoch 1/100, Train Loss: 2.9107, Val Loss: 8.9972, LR: 0.000010
# Epoch 2/100, Train Loss: 2.1158, Val Loss: 6.8331, LR: 0.000015
# Epoch 3/100, Train Loss: 2.0191, Val Loss: 5.7921, LR: 0.000020
# Epoch 4/100, Train Loss: 1.9418, Val Loss: 5.2071, LR: 0.000025
# Epoch 5/100, Train Loss: 1.8287, Val Loss: 4.8747, LR: 0.000030
# Epoch 6/100, Train Loss: 1.7568, Val Loss: 4.5357, LR: 0.000035
# Epoch 7/100, Train Loss: 1.7140, Val Loss: 4.3068, LR: 0.000040
# Epoch 8/100, Train Loss: 1.6817, Val Loss: 4.1345, LR: 0.000045
# Epoch 9/100, Train Loss: 1.6695, Val Loss: 4.0318, LR: 0.000050
# Epoch 10/100, Train Loss: 1.6544, Val Loss: 3.9550, LR: 0.000055
# Epoch 11/100, Train Loss: 1.6431, Val Loss: 3.8956, LR: 0.000054
# Epoch 12/100, Train Loss: 1.6340, Val Loss: 3.8390, LR: 0.000050
# Epoch 13/100, Train Loss: 1.6267, Val Loss: 3.7999, LR: 0.000044
# Epoch 14/100, Train Loss: 1.6213, Val Loss: 3.7630, LR: 0.000036
# Epoch 15/100, Train Loss: 1.6132, Val Loss: 3.7245, LR: 0.000028
# Epoch 16/100, Train Loss: 1.6101, Val Loss: 3.7036, LR: 0.000020
# Epoch 17/100, Train Loss: 1.6072, Val Loss: 3.6845, LR: 0.000012
# Epoch 18/100, Train Loss: 1.6033, Val Loss: 3.6751, LR: 0.000006
# Epoch 19/100, Train Loss: 1.6050, Val Loss: 3.6698, LR: 0.000002
# Epoch 20/100, Train Loss: 1.6068, Val Loss: 3.6673, LR: 0.000055
# Epoch 21/100, Train Loss: 1.6015, Val Loss: 3.6235, LR: 0.000055
# Epoch 22/100, Train Loss: 1.5991, Val Loss: 3.5917, LR: 0.000054
# Epoch 23/100, Train Loss: 1.5911, Val Loss: 3.5588, LR: 0.000052
# Epoch 24/100, Train Loss: 1.5973, Val Loss: 3.5399, LR: 0.000050
# Epoch 25/100, Train Loss: 1.5904, Val Loss: 3.5230, LR: 0.000047
# Epoch 26/100, Train Loss: 1.5877, Val Loss: 3.5046, LR: 0.000044
# Epoch 27/100, Train Loss: 1.5877, Val Loss: 3.4872, LR: 0.000040
# Epoch 28/100, Train Loss: 1.5838, Val Loss: 3.4733, LR: 0.000036
# Epoch 29/100, Train Loss: 1.5839, Val Loss: 3.4651, LR: 0.000032
# Epoch 30/100, Train Loss: 1.5819, Val Loss: 3.4547, LR: 0.000028
# Epoch 31/100, Train Loss: 1.5810, Val Loss: 3.4461, LR: 0.000024
# Epoch 32/100, Train Loss: 1.5779, Val Loss: 3.4409, LR: 0.000020
# Epoch 33/100, Train Loss: 1.5785, Val Loss: 3.4374, LR: 0.000016
# Epoch 34/100, Train Loss: 1.5768, Val Loss: 3.4298, LR: 0.000012
# Epoch 35/100, Train Loss: 1.5736, Val Loss: 3.4267, LR: 0.000009
# Epoch 36/100, Train Loss: 1.5785, Val Loss: 3.4286, LR: 0.000006
# EarlyStopping counter: 1 out of 5
# Epoch 37/100, Train Loss: 1.5770, Val Loss: 3.4289, LR: 0.000004
# EarlyStopping counter: 2 out of 5
# Epoch 38/100, Train Loss: 1.5731, Val Loss: 3.4255, LR: 0.000002
# Epoch 39/100, Train Loss: 1.5722, Val Loss: 3.4244, LR: 0.000001
# Epoch 40/100, Train Loss: 1.5782, Val Loss: 3.4245, LR: 0.000055
# EarlyStopping counter: 1 out of 5
# Epoch 41/100, Train Loss: 1.5742, Val Loss: 3.4097, LR: 0.000055
# Epoch 42/100, Train Loss: 1.5714, Val Loss: 3.4099, LR: 0.000055
# EarlyStopping counter: 1 out of 5
# Epoch 43/100, Train Loss: 1.5705, Val Loss: 3.3935, LR: 0.000054
# Epoch 44/100, Train Loss: 1.5637, Val Loss: 3.3832, LR: 0.000054
# Epoch 45/100, Train Loss: 1.5657, Val Loss: 3.3854, LR: 0.000053
# EarlyStopping counter: 1 out of 5
# Epoch 46/100, Train Loss: 1.5608, Val Loss: 3.3993, LR: 0.000052
# EarlyStopping counter: 2 out of 5
# Epoch 47/100, Train Loss: 1.5599, Val Loss: 3.3886, LR: 0.000051
# EarlyStopping counter: 3 out of 5
# Epoch 48/100, Train Loss: 1.5559, Val Loss: 3.4890, LR: 0.000050
# EarlyStopping counter: 4 out of 5
# Epoch 49/100, Train Loss: 1.5488, Val Loss: 3.6685, LR: 0.000048
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# Epoch 1/100, Train Loss: 3.6615, Val Loss: 8.2088, LR: 0.000010
# Epoch 2/100, Train Loss: 2.4698, Val Loss: 6.0180, LR: 0.000015
# Epoch 3/100, Train Loss: 2.3117, Val Loss: 4.9831, LR: 0.000020
# Epoch 4/100, Train Loss: 2.2103, Val Loss: 4.4180, LR: 0.000025
# Epoch 5/100, Train Loss: 2.0762, Val Loss: 4.1932, LR: 0.000030
# Epoch 6/100, Train Loss: 1.9685, Val Loss: 4.0813, LR: 0.000035
# Epoch 7/100, Train Loss: 1.9043, Val Loss: 3.9799, LR: 0.000040
# Epoch 8/100, Train Loss: 1.8754, Val Loss: 3.8847, LR: 0.000045
# Epoch 9/100, Train Loss: 1.8419, Val Loss: 3.7915, LR: 0.000050
# Epoch 10/100, Train Loss: 1.8186, Val Loss: 3.7378, LR: 0.000055
# Epoch 11/100, Train Loss: 1.8043, Val Loss: 3.6894, LR: 0.000054
# Epoch 12/100, Train Loss: 1.7774, Val Loss: 3.6539, LR: 0.000050
# Epoch 13/100, Train Loss: 1.7628, Val Loss: 3.6436, LR: 0.000044
# Epoch 14/100, Train Loss: 1.7526, Val Loss: 3.6134, LR: 0.000036
# Epoch 15/100, Train Loss: 1.7429, Val Loss: 3.6016, LR: 0.000028
# Epoch 16/100, Train Loss: 1.7247, Val Loss: 3.6026, LR: 0.000020
# EarlyStopping counter: 1 out of 5
# Epoch 17/100, Train Loss: 1.7196, Val Loss: 3.5968, LR: 0.000012
# Epoch 18/100, Train Loss: 1.7131, Val Loss: 3.6028, LR: 0.000006
# EarlyStopping counter: 1 out of 5
# Epoch 19/100, Train Loss: 1.7077, Val Loss: 3.5986, LR: 0.000002
# EarlyStopping counter: 2 out of 5
# Epoch 20/100, Train Loss: 1.7078, Val Loss: 3.6026, LR: 0.000055
# EarlyStopping counter: 3 out of 5
# Epoch 21/100, Train Loss: 1.6943, Val Loss: 3.6121, LR: 0.000055
# EarlyStopping counter: 4 out of 5
# Epoch 22/100, Train Loss: 1.6857, Val Loss: 3.6302, LR: 0.000054
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# Epoch 1/100, Train Loss: 4.0538, Val Loss: 8.1607, LR: 0.000010
# Epoch 2/100, Train Loss: 2.7892, Val Loss: 5.4876, LR: 0.000015
# Epoch 3/100, Train Loss: 2.5502, Val Loss: 4.3548, LR: 0.000020
# Epoch 4/100, Train Loss: 2.3949, Val Loss: 3.9016, LR: 0.000025
# Epoch 5/100, Train Loss: 2.2993, Val Loss: 3.7881, LR: 0.000030
# Epoch 6/100, Train Loss: 2.2394, Val Loss: 3.7567, LR: 0.000035
# Epoch 7/100, Train Loss: 2.1944, Val Loss: 3.6817, LR: 0.000040
# Epoch 8/100, Train Loss: 2.1358, Val Loss: 3.6386, LR: 0.000045
# Epoch 9/100, Train Loss: 2.0795, Val Loss: 3.6014, LR: 0.000050
# Epoch 10/100, Train Loss: 2.0697, Val Loss: 3.5422, LR: 0.000055
# Epoch 11/100, Train Loss: 2.0477, Val Loss: 3.5351, LR: 0.000054
# Epoch 12/100, Train Loss: 1.9917, Val Loss: 3.4927, LR: 0.000050
# Epoch 13/100, Train Loss: 1.9476, Val Loss: 3.4658, LR: 0.000044
# Epoch 14/100, Train Loss: 1.9038, Val Loss: 3.4538, LR: 0.000036
# Epoch 15/100, Train Loss: 1.8752, Val Loss: 3.4510, LR: 0.000028
# Epoch 16/100, Train Loss: 1.8535, Val Loss: 3.4592, LR: 0.000020
# EarlyStopping counter: 1 out of 5
# Epoch 17/100, Train Loss: 1.8387, Val Loss: 3.4656, LR: 0.000012
# EarlyStopping counter: 2 out of 5
# Epoch 18/100, Train Loss: 1.8317, Val Loss: 3.4762, LR: 0.000006
# EarlyStopping counter: 3 out of 5
# Epoch 19/100, Train Loss: 1.8225, Val Loss: 3.4807, LR: 0.000002
# EarlyStopping counter: 4 out of 5
# Epoch 20/100, Train Loss: 1.8212, Val Loss: 3.4826, LR: 0.000055
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# Cross-Validation Results:
# Mean Absolute Error (CV): 6.8294 (±4.0562)
# Root Mean Squared Error (CV): 7.6507 (±3.9708)
# Theil's U Statistic (CV): 0.6827 (±0.1199)
# R² Score (CV): -4.3504 (±4.4922)
# Directional Accuracy (CV): 47.83% (±9.81%)
#
# Training final model on full dataset...
# Epoch 1/100, Train Loss: 4.3490, Val Loss: 6.5268, LR: 0.000010
# Epoch 2/100, Train Loss: 2.9666, Val Loss: 4.0676, LR: 0.000015
# Epoch 3/100, Train Loss: 2.6547, Val Loss: 3.3794, LR: 0.000020
# Epoch 4/100, Train Loss: 2.4604, Val Loss: 3.2169, LR: 0.000025
# Epoch 5/100, Train Loss: 2.3355, Val Loss: 3.1875, LR: 0.000030
# Epoch 6/100, Train Loss: 2.2484, Val Loss: 3.1978, LR: 0.000035
# EarlyStopping counter: 1 out of 5
# Epoch 7/100, Train Loss: 2.1734, Val Loss: 3.2238, LR: 0.000040
# EarlyStopping counter: 2 out of 5
# Epoch 8/100, Train Loss: 2.1120, Val Loss: 3.2600, LR: 0.000045
# EarlyStopping counter: 3 out of 5
# Epoch 9/100, Train Loss: 2.0582, Val Loss: 3.3150, LR: 0.000050
# EarlyStopping counter: 4 out of 5
# Epoch 10/100, Train Loss: 2.0227, Val Loss: 3.3595, LR: 0.000055
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# Results saved:
# - Predictions: 'time2vec_predictions_attention.csv'
# - Best parameters: 'time2vec_best_params_attention.csv'
# - Cross-validation results: 'cross_validation_results_attention.csv'

# %%
# After getting study, predictions, cv_results from main execution
sf = pd.read_csv('/kaggle/input/bitcoin-project/test.csv')
actual_values = sf['block_median_fee_rate']
predicted_values = predictions['predicted_fee_rate']

# Initialize predictor for metrics
predictor = BitcoinFeePredictor()
metrics = predictor.calculate_metrics(actual_values.values, predicted_values.values)

# Print metrics
print("Performance Metrics:")
print(f"Mean Absolute Error (MAE): {metrics.mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {metrics.rmse:.4f}")
print(f"Theil's U Statistic: {metrics.theil_u:.4f}")

# Create plot with your preferred style
plt.figure(figsize=(15, 12))

# Plot actual values
plt.plot(actual_values.index, actual_values, 
         label='Actual Fee Rate')

# Plot predicted values
plt.plot(actual_values.index, predicted_values, 
         label='Predicted Fee Rate', linestyle='--')

# Add title and labels
plt.title('Time2vec_attention: Actual vs Predicted Bitcoin Fee Rate', fontsize=20)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Fee Rate (sat/vB)', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Add legend and grid
plt.legend(fontsize=16)
plt.grid(alpha=0.3)
plt.savefig('time2vec_test.png',dpi=600)

plt.show()
# Out:
# Performance Metrics:
# Mean Absolute Error (MAE): 3.5605
# Root Mean Squared Error (RMSE): 5.0223
# Theil's U Statistic: 0.6270
