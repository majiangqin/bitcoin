# %%
import sys
import os
from bitcoin.rpc import RawProxy, JSONRPCError
from datetime import datetime, timedelta
import numpy as np
from decimal import Decimal
import concurrent.futures
import threading
import time
import logging
import csv

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def check_bitcoin_core_status():
    logging.info("Checking Bitcoin Core status...")
    try:
        # Check if bitcoind process is running
        import psutil
        for proc in psutil.process_iter(['name']):
            if proc.info['name'] == 'bitcoind':
                logging.info("Bitcoin Core (bitcoind) is running.")
                return True
        logging.error("Bitcoin Core (bitcoind) is not running.")
        return False
    except ImportError:
        logging.warning("psutil not installed. Unable to check if Bitcoin Core is running.")
        return None

def test_rpc_connection(rpc_user, rpc_password, rpc_host='192.168.180.178', rpc_port=8332):
    logging.info(f"Testing RPC connection to {rpc_host}:{rpc_port}...")
    try:
        p = RawProxy(service_url=f"http://{rpc_user}:{rpc_password}@{rpc_host}:{rpc_port}")
        block_count = p.getblockcount()
        logging.info(f"Successfully connected to Bitcoin node. Current block count: {block_count}")
        return p
    except Exception as e:
        logging.error(f"Failed to connect to Bitcoin node: {e}")
        return None

def check_data_directory(directory):
    logging.info(f"Checking data directory: {directory}")
    if not os.path.exists(directory):
        logging.error(f"Directory does not exist: {directory}")
        return False
    if not os.access(directory, os.W_OK):
        logging.error(f"No write permission for directory: {directory}")
        return False
    logging.info(f"Data directory is accessible and writable: {directory}")
    return True

def main():
    # Check Bitcoin Core status
    if not check_bitcoin_core_status():
        logging.error("Please ensure Bitcoin Core is running before executing this script.")
        return

    # Test RPC connection
    rpc_user = 'aiteam'
    rpc_password = 'jhecX4Hd12fj'
    p = test_rpc_connection(rpc_user, rpc_password)
    if not p:
        logging.error("Unable to establish RPC connection. Please check your Bitcoin Core configuration.")
        return

    # Check data directory
    data_dir = '/mnt/volume_nyc1_01/bitcoin/'
    if not check_data_directory(data_dir):
        logging.error("Please ensure the data directory exists and is writable.")
        return


    logging.info("Script execution completed successfully.")

if __name__ == "__main__":
    main()
# Out:
# 2024-08-25 10:16:34,045 - INFO - Checking Bitcoin Core status...
# 2024-08-25 10:16:34,065 - ERROR - Bitcoin Core (bitcoind) is not running.
# 2024-08-25 10:16:34,066 - ERROR - Please ensure Bitcoin Core is running before executing this script.

# %%
import psutil
import logging

def check_bitcoin_core_status():
    logging.info("Checking Bitcoin Core status...")
    try:
        for proc in psutil.process_iter(['name', 'cmdline']):
            if proc.info['name'] == 'bitcoind' or (proc.info['cmdline'] and 'bitcoind' in proc.info['cmdline'][0]):
                logging.info(f"Bitcoin Core (bitcoind) is running. PID: {proc.pid}")
                return True
        logging.error("Bitcoin Core (bitcoind) is not running.")
        return False
    except Exception as e:
        logging.error(f"Error checking Bitcoin Core status: {e}")
        return False

# Rest of your script remains the same...

def main():
    # Check Bitcoin Core status
    if not check_bitcoin_core_status():
        logging.error("Please ensure Bitcoin Core is running before executing this script.")
        return

if __name__ == "__main__":
    main()
# Out:
# 2024-08-25 08:23:01,042 - INFO - Checking Bitcoin Core status...
# 2024-08-25 08:23:01,082 - ERROR - Bitcoin Core (bitcoind) is not running.
# 2024-08-25 08:23:01,083 - ERROR - Please ensure Bitcoin Core is running before executing this script.

# %%
from bitcoin.rpc import RawProxy, JSONRPCError
from datetime import datetime, timedelta
import numpy as np
from decimal import Decimal
import concurrent.futures
import threading
import time
import logging
import csv
import os

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Create a lock for thread-safe access to the RPC connection
rpc_lock = threading.Lock()

# Connect to local Bitcoin node
# Note: We're connecting to localhost because the RPC is only listening on 127.0.0.1
p = RawProxy(service_url="http://aiteam:jhecX4Hd12fj@127.0.0.1:8332")

def safe_rpc_call(method, *args, timeout=30):
    def call_rpc():
        with rpc_lock:
            return getattr(p, method)(*args)

    with concurrent.futures.ThreadPoolExecutor(max_workers=1) as executor:
        future = executor.submit(call_rpc)
        try:
            return future.result(timeout=timeout)
        except concurrent.futures.TimeoutError:
            logging.error(f"RPC call {method} timed out after {timeout} seconds")
            raise TimeoutError(f"RPC call {method} timed out")

def test_bitcoin_connection():
    try:
        block_count = safe_rpc_call('getblockcount')
        logging.info(f"Successfully connected to Bitcoin node. Current block count: {block_count}")
        return True
    except Exception as e:
        logging.error(f"Failed to connect to Bitcoin node: {e}")
        return False

def get_block_data(block_hash):
    logging.info(f"Fetching block data for hash: {block_hash}")
    try:
        block = safe_rpc_call('getblock', block_hash)
        result = {
            'timestamp': block['time'],
            'size': block['size'],
            'transaction_count': len(block['tx']),
            'difficulty': block['difficulty'],
            'weight': block.get('weight', None),
            'version': block['version'],
            'median_time_past': block['mediantime'],
        }
        return result
    except Exception as e:
        logging.error(f"Error in get_block_data: {e}")
        raise

def calculate_total_fees_and_fee_rates(txid, block_hash):
    try:
        tx = safe_rpc_call('getrawtransaction', txid, 1, block_hash)
        
        # Skip coinbase transactions (they have no inputs)
        if 'coinbase' in tx['vin'][0]:
            return Decimal(0), Decimal(0)
        
        input_sum = Decimal(0)
        for vin in tx['vin']:
            prev_tx = safe_rpc_call('getrawtransaction', vin['txid'], 1, block_hash)
            input_sum += Decimal(prev_tx['vout'][vin['vout']]['value'])
        
        output_sum = sum(Decimal(vout['value']) for vout in tx['vout'])
        fee = input_sum - output_sum
        
        # Ensure fee is not negative
        if fee < 0:
            logging.warning(f"Negative fee calculated for transaction {txid}. Setting to 0.")
            fee = Decimal(0)
        
        fee_rate = (fee * Decimal(1e8)) / tx['vsize'] if tx['vsize'] > 0 else Decimal(0)

        return fee, fee_rate
    except Exception as e:
        logging.error(f"Error processing transaction {txid}: {e}")
        return Decimal(0), Decimal(0)

def process_block_transactions(block_hash, tx_count, max_txs=100):
    total_fees = Decimal(0)
    fee_rates = []
    
    txids = safe_rpc_call('getblock', block_hash)['tx'][:max_txs]
    
    for txid in txids:
        try:
            fee, fee_rate = calculate_total_fees_and_fee_rates(txid, block_hash)
            total_fees += fee
            if fee_rate > 0:
                fee_rates.append(fee_rate)
        except Exception as e:
            logging.error(f"Error processing transaction {txid}: {e}")
    
    median_fee_rate = np.median(fee_rates) if fee_rates else Decimal(0)
    return total_fees, median_fee_rate

def get_historical_data(start_time, end_time, interval_minutes=10):
    data = []
    logging.info(f"Starting historical data retrieval from {start_time} to {end_time} at {interval_minutes}-minute intervals")
    current_time = start_time
    
    while current_time <= end_time:
        try:
            # Find the appropriate block for the current time
            block_count = safe_rpc_call('getblockcount')
            while True:
                block_hash = safe_rpc_call('getblockhash', block_count)
                block = safe_rpc_call('getblock', block_hash)
                if block['time'] >= current_time.timestamp():
                    break
                block_count -= 1
            
            logging.info(f"Processing block at time {datetime.fromtimestamp(block['time'])}")
            
            block_data = get_block_data(block_hash)
            mempool_info = safe_rpc_call('getmempoolinfo')
            chain_info = safe_rpc_call('getblockchaininfo')
            network_hash_rate = safe_rpc_call('getnetworkhashps')
            
            total_fees, median_fee_rate = process_block_transactions(block_hash, block_data['transaction_count'], max_txs=100)
            
            data.append({
                'timestamp': datetime.fromtimestamp(block['time']),
                'block_size': block_data['size'],
                'transaction_count': block_data['transaction_count'],
                'difficulty': block_data['difficulty'],
                'block_weight': block_data['weight'],
                'block_version': block_data['version'],
                'median_time_past': block_data['median_time_past'],
                'mempool_size': mempool_info['bytes'] / 1000000,
                'mempool_count': mempool_info['size'],
                'chain_height': chain_info['blocks'],
                'network_hash_rate': network_hash_rate,
                'total_fees': float(total_fees),
                'median_fee_rate': float(median_fee_rate),
                'relay_fee': mempool_info.get('relayfee', None),
            })
            
            logging.info(f"Processed block at {datetime.fromtimestamp(block['time'])}")
            
        except Exception as e:
            logging.error(f"Error processing block at {current_time}: {e}")
        
        current_time += timedelta(minutes=interval_minutes)
    
    logging.info(f"Finished collecting historical data. Total entries: {len(data)}")
    return data


def check_pruning_status():
    try:
        blockchain_info = safe_rpc_call('getblockchaininfo')
        if blockchain_info['pruned']:
            logging.info(f"Blockchain is already pruned. Prune height: {blockchain_info['pruneheight']}")
            return True
        return False
    except Exception as e:
        logging.error(f"Failed to check pruning status: {e}")
        return False

def enable_pruning(prune_target_size_mb):
    logging.info(f"Attempting to enable pruning with target size {prune_target_size_mb} MB")
    try:
        result = safe_rpc_call('pruneblockchain', prune_target_size_mb)
        logging.info(f"Pruning enabled. Height of last pruned block: {result}")
    except Exception as e:
        logging.error(f"Failed to enable pruning: {e}")

if __name__ == "__main__":
    if not test_bitcoin_connection():
        logging.error("Cannot proceed due to connection issues with the Bitcoin node.")
        exit(1)

    # Check and enable pruning if necessary
    if not check_pruning_status():
        enable_pruning(200000)  # 200 GB

    end_time = datetime.now()
    start_time = end_time - timedelta(days=365)  # 1 year of data
    logging.info("Starting script execution")
    historical_data = get_historical_data(start_time, end_time, interval_minutes=60)
    logging.info("Finished collecting historical data")

    # Print out the collected historical data
    for entry in historical_data:
        print(f"Timestamp: {entry['timestamp']}, "
              f"Block Size: {entry['block_size']} bytes, "
              f"Transaction Count: {entry['transaction_count']}, "
              f"Difficulty: {entry['difficulty']}, "
              f"Block Weight: {entry['block_weight']} WU, "
              f"Block Version: {entry['block_version']}, "
              f"Median Time Past: {entry['median_time_past']}, "
              f"Mempool Size: {entry['mempool_size']} MB, "
              f"Mempool Count: {entry['mempool_count']}, "
              f"Chain Height: {entry['chain_height']}, "
              f"Network Hash Rate: {entry['network_hash_rate']} H/s, "
              f"Total Fees: {entry['total_fees']} BTC, "
              f"Median Fee Rate: {entry['median_fee_rate']} sat/byte, "
              f"Relay Fee: {entry['relay_fee'] if entry['relay_fee'] is not None else 'N/A'} BTC/kB")

    # Save the data to a CSV file in the specified data directory
    csv_path = os.path.join('/mnt/volume_nyc1_01/bitcoin/', 'bitcoin_historical_data.csv')
    with open(csv_path, 'w', newline='') as csvfile:
        fieldnames = historical_data[0].keys() if historical_data else []
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for entry in historical_data:
            writer.writerow(entry)
    logging.info(f"Data saved to {csv_path}")
# Out:
# 2024-08-25 08:14:46,024 - ERROR - Failed to connect to Bitcoin node: [Errno 61] Connection refused
# 2024-08-25 08:14:46,025 - ERROR - Cannot proceed due to connection issues with the Bitcoin node.
# 2024-08-25 08:14:46,026 - ERROR - Failed to check pruning status: Request-sent
# 2024-08-25 08:14:46,026 - INFO - Attempting to enable pruning with target size 200000 MB
# 2024-08-25 08:14:46,028 - ERROR - Failed to enable pruning: Request-sent
# 2024-08-25 08:14:46,028 - INFO - Starting script execution
# 2024-08-25 08:14:46,029 - INFO - Starting historical data retrieval from 2023-08-26 08:14:46.028734 to 2024-08-25 08:14:46.028734 at 60-minute intervals
# 2024-08-25 08:14:46,030 - ERROR - Error processing block at 2023-08-26 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,032 - ERROR - Error processing block at 2023-08-26 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,033 - ERROR - Error processing block at 2023-08-26 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,034 - ERROR - Error processing block at 2023-08-26 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,035 - ERROR - Error processing block at 2023-08-26 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,037 - ERROR - Error processing block at 2023-08-26 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,038 - ERROR - Error processing block at 2023-08-26 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,040 - ERROR - Error processing block at 2023-08-26 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,041 - ERROR - Error processing block at 2023-08-26 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,042 - ERROR - Error processing block at 2023-08-26 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,043 - ERROR - Error processing block at 2023-08-26 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,045 - ERROR - Error processing block at 2023-08-26 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,046 - ERROR - Error processing block at 2023-08-26 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,047 - ERROR - Error processing block at 2023-08-26 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,048 - ERROR - Error processing block at 2023-08-26 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,049 - ERROR - Error processing block at 2023-08-26 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,051 - ERROR - Error processing block at 2023-08-27 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,052 - ERROR - Error processing block at 2023-08-27 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,054 - ERROR - Error processing block at 2023-08-27 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,055 - ERROR - Error processing block at 2023-08-27 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,056 - ERROR - Error processing block at 2023-08-27 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,057 - ERROR - Error processing block at 2023-08-27 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,059 - ERROR - Error processing block at 2023-08-27 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,060 - ERROR - Error processing block at 2023-08-27 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,061 - ERROR - Error processing block at 2023-08-27 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,062 - ERROR - Error processing block at 2023-08-27 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,063 - ERROR - Error processing block at 2023-08-27 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,065 - ERROR - Error processing block at 2023-08-27 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,066 - ERROR - Error processing block at 2023-08-27 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,067 - ERROR - Error processing block at 2023-08-27 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,068 - ERROR - Error processing block at 2023-08-27 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,069 - ERROR - Error processing block at 2023-08-27 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,071 - ERROR - Error processing block at 2023-08-27 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,072 - ERROR - Error processing block at 2023-08-27 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,073 - ERROR - Error processing block at 2023-08-27 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,074 - ERROR - Error processing block at 2023-08-27 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,075 - ERROR - Error processing block at 2023-08-27 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,077 - ERROR - Error processing block at 2023-08-27 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,078 - ERROR - Error processing block at 2023-08-27 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,079 - ERROR - Error processing block at 2023-08-27 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,080 - ERROR - Error processing block at 2023-08-28 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,081 - ERROR - Error processing block at 2023-08-28 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,082 - ERROR - Error processing block at 2023-08-28 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,083 - ERROR - Error processing block at 2023-08-28 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,085 - ERROR - Error processing block at 2023-08-28 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,086 - ERROR - Error processing block at 2023-08-28 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,087 - ERROR - Error processing block at 2023-08-28 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,088 - ERROR - Error processing block at 2023-08-28 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,090 - ERROR - Error processing block at 2023-08-28 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,091 - ERROR - Error processing block at 2023-08-28 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,092 - ERROR - Error processing block at 2023-08-28 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,094 - ERROR - Error processing block at 2023-08-28 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,095 - ERROR - Error processing block at 2023-08-28 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,100 - ERROR - Error processing block at 2023-08-28 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,102 - ERROR - Error processing block at 2023-08-28 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,103 - ERROR - Error processing block at 2023-08-28 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,104 - ERROR - Error processing block at 2023-08-28 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,105 - ERROR - Error processing block at 2023-08-28 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,106 - ERROR - Error processing block at 2023-08-28 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,107 - ERROR - Error processing block at 2023-08-28 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,108 - ERROR - Error processing block at 2023-08-28 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,110 - ERROR - Error processing block at 2023-08-28 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,110 - ERROR - Error processing block at 2023-08-28 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,111 - ERROR - Error processing block at 2023-08-28 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,113 - ERROR - Error processing block at 2023-08-29 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,114 - ERROR - Error processing block at 2023-08-29 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,115 - ERROR - Error processing block at 2023-08-29 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,117 - ERROR - Error processing block at 2023-08-29 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,117 - ERROR - Error processing block at 2023-08-29 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,118 - ERROR - Error processing block at 2023-08-29 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,119 - ERROR - Error processing block at 2023-08-29 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,121 - ERROR - Error processing block at 2023-08-29 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,123 - ERROR - Error processing block at 2023-08-29 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,124 - ERROR - Error processing block at 2023-08-29 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,125 - ERROR - Error processing block at 2023-08-29 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,126 - ERROR - Error processing block at 2023-08-29 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,127 - ERROR - Error processing block at 2023-08-29 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,128 - ERROR - Error processing block at 2023-08-29 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,129 - ERROR - Error processing block at 2023-08-29 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,130 - ERROR - Error processing block at 2023-08-29 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,132 - ERROR - Error processing block at 2023-08-29 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,133 - ERROR - Error processing block at 2023-08-29 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,136 - ERROR - Error processing block at 2023-08-29 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,137 - ERROR - Error processing block at 2023-08-29 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,139 - ERROR - Error processing block at 2023-08-29 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,142 - ERROR - Error processing block at 2023-08-29 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,143 - ERROR - Error processing block at 2023-08-29 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,144 - ERROR - Error processing block at 2023-08-29 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,146 - ERROR - Error processing block at 2023-08-30 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,147 - ERROR - Error processing block at 2023-08-30 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,148 - ERROR - Error processing block at 2023-08-30 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,150 - ERROR - Error processing block at 2023-08-30 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,151 - ERROR - Error processing block at 2023-08-30 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,153 - ERROR - Error processing block at 2023-08-30 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,154 - ERROR - Error processing block at 2023-08-30 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,155 - ERROR - Error processing block at 2023-08-30 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,156 - ERROR - Error processing block at 2023-08-30 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,157 - ERROR - Error processing block at 2023-08-30 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,159 - ERROR - Error processing block at 2023-08-30 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,160 - ERROR - Error processing block at 2023-08-30 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,161 - ERROR - Error processing block at 2023-08-30 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,162 - ERROR - Error processing block at 2023-08-30 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,163 - ERROR - Error processing block at 2023-08-30 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,164 - ERROR - Error processing block at 2023-08-30 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,165 - ERROR - Error processing block at 2023-08-30 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,167 - ERROR - Error processing block at 2023-08-30 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,168 - ERROR - Error processing block at 2023-08-30 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,169 - ERROR - Error processing block at 2023-08-30 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,171 - ERROR - Error processing block at 2023-08-30 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,172 - ERROR - Error processing block at 2023-08-30 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,173 - ERROR - Error processing block at 2023-08-30 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,174 - ERROR - Error processing block at 2023-08-30 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,175 - ERROR - Error processing block at 2023-08-31 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,176 - ERROR - Error processing block at 2023-08-31 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,178 - ERROR - Error processing block at 2023-08-31 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,179 - ERROR - Error processing block at 2023-08-31 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,180 - ERROR - Error processing block at 2023-08-31 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,182 - ERROR - Error processing block at 2023-08-31 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,183 - ERROR - Error processing block at 2023-08-31 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,184 - ERROR - Error processing block at 2023-08-31 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,185 - ERROR - Error processing block at 2023-08-31 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,187 - ERROR - Error processing block at 2023-08-31 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,188 - ERROR - Error processing block at 2023-08-31 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,189 - ERROR - Error processing block at 2023-08-31 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,191 - ERROR - Error processing block at 2023-08-31 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,192 - ERROR - Error processing block at 2023-08-31 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,193 - ERROR - Error processing block at 2023-08-31 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,194 - ERROR - Error processing block at 2023-08-31 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,196 - ERROR - Error processing block at 2023-08-31 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,197 - ERROR - Error processing block at 2023-08-31 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,199 - ERROR - Error processing block at 2023-08-31 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,201 - ERROR - Error processing block at 2023-08-31 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,202 - ERROR - Error processing block at 2023-08-31 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,203 - ERROR - Error processing block at 2023-08-31 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,204 - ERROR - Error processing block at 2023-08-31 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,204 - ERROR - Error processing block at 2023-08-31 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,205 - ERROR - Error processing block at 2023-09-01 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,206 - ERROR - Error processing block at 2023-09-01 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,208 - ERROR - Error processing block at 2023-09-01 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,209 - ERROR - Error processing block at 2023-09-01 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,210 - ERROR - Error processing block at 2023-09-01 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,212 - ERROR - Error processing block at 2023-09-01 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,213 - ERROR - Error processing block at 2023-09-01 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,214 - ERROR - Error processing block at 2023-09-01 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,215 - ERROR - Error processing block at 2023-09-01 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,216 - ERROR - Error processing block at 2023-09-01 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,217 - ERROR - Error processing block at 2023-09-01 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,219 - ERROR - Error processing block at 2023-09-01 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,220 - ERROR - Error processing block at 2023-09-01 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,221 - ERROR - Error processing block at 2023-09-01 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,223 - ERROR - Error processing block at 2023-09-01 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,224 - ERROR - Error processing block at 2023-09-01 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,225 - ERROR - Error processing block at 2023-09-01 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,226 - ERROR - Error processing block at 2023-09-01 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,229 - ERROR - Error processing block at 2023-09-01 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,231 - ERROR - Error processing block at 2023-09-01 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,233 - ERROR - Error processing block at 2023-09-01 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,235 - ERROR - Error processing block at 2023-09-01 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,237 - ERROR - Error processing block at 2023-09-01 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,239 - ERROR - Error processing block at 2023-09-01 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,243 - ERROR - Error processing block at 2023-09-02 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,247 - ERROR - Error processing block at 2023-09-02 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,248 - ERROR - Error processing block at 2023-09-02 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,251 - ERROR - Error processing block at 2023-09-02 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,254 - ERROR - Error processing block at 2023-09-02 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,258 - ERROR - Error processing block at 2023-09-02 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,261 - ERROR - Error processing block at 2023-09-02 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,265 - ERROR - Error processing block at 2023-09-02 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,269 - ERROR - Error processing block at 2023-09-02 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,271 - ERROR - Error processing block at 2023-09-02 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,272 - ERROR - Error processing block at 2023-09-02 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,273 - ERROR - Error processing block at 2023-09-02 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,274 - ERROR - Error processing block at 2023-09-02 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,276 - ERROR - Error processing block at 2023-09-02 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,277 - ERROR - Error processing block at 2023-09-02 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,278 - ERROR - Error processing block at 2023-09-02 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,279 - ERROR - Error processing block at 2023-09-02 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,281 - ERROR - Error processing block at 2023-09-02 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,281 - ERROR - Error processing block at 2023-09-02 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,283 - ERROR - Error processing block at 2023-09-02 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,284 - ERROR - Error processing block at 2023-09-02 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,286 - ERROR - Error processing block at 2023-09-02 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,287 - ERROR - Error processing block at 2023-09-02 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,288 - ERROR - Error processing block at 2023-09-02 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,289 - ERROR - Error processing block at 2023-09-03 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,290 - ERROR - Error processing block at 2023-09-03 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,291 - ERROR - Error processing block at 2023-09-03 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,292 - ERROR - Error processing block at 2023-09-03 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,292 - ERROR - Error processing block at 2023-09-03 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,293 - ERROR - Error processing block at 2023-09-03 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,294 - ERROR - Error processing block at 2023-09-03 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,294 - ERROR - Error processing block at 2023-09-03 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,295 - ERROR - Error processing block at 2023-09-03 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,295 - ERROR - Error processing block at 2023-09-03 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,296 - ERROR - Error processing block at 2023-09-03 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,297 - ERROR - Error processing block at 2023-09-03 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,297 - ERROR - Error processing block at 2023-09-03 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,298 - ERROR - Error processing block at 2023-09-03 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,299 - ERROR - Error processing block at 2023-09-03 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,300 - ERROR - Error processing block at 2023-09-03 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,301 - ERROR - Error processing block at 2023-09-03 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,302 - ERROR - Error processing block at 2023-09-03 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,302 - ERROR - Error processing block at 2023-09-03 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,303 - ERROR - Error processing block at 2023-09-03 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,323 - ERROR - Error processing block at 2023-09-03 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,324 - ERROR - Error processing block at 2023-09-03 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,325 - ERROR - Error processing block at 2023-09-03 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,325 - ERROR - Error processing block at 2023-09-03 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,326 - ERROR - Error processing block at 2023-09-04 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,326 - ERROR - Error processing block at 2023-09-04 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,327 - ERROR - Error processing block at 2023-09-04 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,328 - ERROR - Error processing block at 2023-09-04 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,328 - ERROR - Error processing block at 2023-09-04 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,329 - ERROR - Error processing block at 2023-09-04 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,330 - ERROR - Error processing block at 2023-09-04 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,331 - ERROR - Error processing block at 2023-09-04 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,331 - ERROR - Error processing block at 2023-09-04 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,332 - ERROR - Error processing block at 2023-09-04 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,332 - ERROR - Error processing block at 2023-09-04 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,333 - ERROR - Error processing block at 2023-09-04 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,333 - ERROR - Error processing block at 2023-09-04 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,334 - ERROR - Error processing block at 2023-09-04 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,335 - ERROR - Error processing block at 2023-09-04 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,335 - ERROR - Error processing block at 2023-09-04 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,336 - ERROR - Error processing block at 2023-09-04 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,336 - ERROR - Error processing block at 2023-09-04 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,337 - ERROR - Error processing block at 2023-09-04 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,338 - ERROR - Error processing block at 2023-09-04 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,338 - ERROR - Error processing block at 2023-09-04 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,339 - ERROR - Error processing block at 2023-09-04 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,340 - ERROR - Error processing block at 2023-09-04 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,341 - ERROR - Error processing block at 2023-09-04 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,342 - ERROR - Error processing block at 2023-09-05 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,343 - ERROR - Error processing block at 2023-09-05 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,344 - ERROR - Error processing block at 2023-09-05 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,344 - ERROR - Error processing block at 2023-09-05 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,345 - ERROR - Error processing block at 2023-09-05 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,346 - ERROR - Error processing block at 2023-09-05 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,346 - ERROR - Error processing block at 2023-09-05 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,347 - ERROR - Error processing block at 2023-09-05 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,348 - ERROR - Error processing block at 2023-09-05 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,349 - ERROR - Error processing block at 2023-09-05 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,349 - ERROR - Error processing block at 2023-09-05 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,350 - ERROR - Error processing block at 2023-09-05 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,351 - ERROR - Error processing block at 2023-09-05 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,352 - ERROR - Error processing block at 2023-09-05 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,354 - ERROR - Error processing block at 2023-09-05 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,355 - ERROR - Error processing block at 2023-09-05 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,356 - ERROR - Error processing block at 2023-09-05 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,357 - ERROR - Error processing block at 2023-09-05 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,358 - ERROR - Error processing block at 2023-09-05 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,358 - ERROR - Error processing block at 2023-09-05 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,359 - ERROR - Error processing block at 2023-09-05 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,360 - ERROR - Error processing block at 2023-09-05 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,361 - ERROR - Error processing block at 2023-09-05 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,362 - ERROR - Error processing block at 2023-09-05 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,363 - ERROR - Error processing block at 2023-09-06 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,364 - ERROR - Error processing block at 2023-09-06 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,365 - ERROR - Error processing block at 2023-09-06 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,366 - ERROR - Error processing block at 2023-09-06 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,367 - ERROR - Error processing block at 2023-09-06 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,368 - ERROR - Error processing block at 2023-09-06 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,368 - ERROR - Error processing block at 2023-09-06 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,369 - ERROR - Error processing block at 2023-09-06 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,369 - ERROR - Error processing block at 2023-09-06 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,370 - ERROR - Error processing block at 2023-09-06 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,370 - ERROR - Error processing block at 2023-09-06 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,371 - ERROR - Error processing block at 2023-09-06 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,371 - ERROR - Error processing block at 2023-09-06 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,372 - ERROR - Error processing block at 2023-09-06 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,373 - ERROR - Error processing block at 2023-09-06 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,373 - ERROR - Error processing block at 2023-09-06 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,374 - ERROR - Error processing block at 2023-09-06 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,375 - ERROR - Error processing block at 2023-09-06 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,376 - ERROR - Error processing block at 2023-09-06 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,376 - ERROR - Error processing block at 2023-09-06 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,377 - ERROR - Error processing block at 2023-09-06 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,378 - ERROR - Error processing block at 2023-09-06 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,379 - ERROR - Error processing block at 2023-09-06 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,379 - ERROR - Error processing block at 2023-09-06 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,380 - ERROR - Error processing block at 2023-09-07 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,380 - ERROR - Error processing block at 2023-09-07 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,381 - ERROR - Error processing block at 2023-09-07 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,382 - ERROR - Error processing block at 2023-09-07 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,382 - ERROR - Error processing block at 2023-09-07 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,383 - ERROR - Error processing block at 2023-09-07 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,383 - ERROR - Error processing block at 2023-09-07 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,384 - ERROR - Error processing block at 2023-09-07 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,384 - ERROR - Error processing block at 2023-09-07 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,385 - ERROR - Error processing block at 2023-09-07 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,385 - ERROR - Error processing block at 2023-09-07 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,386 - ERROR - Error processing block at 2023-09-07 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,386 - ERROR - Error processing block at 2023-09-07 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,387 - ERROR - Error processing block at 2023-09-07 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,387 - ERROR - Error processing block at 2023-09-07 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,387 - ERROR - Error processing block at 2023-09-07 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,388 - ERROR - Error processing block at 2023-09-07 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,388 - ERROR - Error processing block at 2023-09-07 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,389 - ERROR - Error processing block at 2023-09-07 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,390 - ERROR - Error processing block at 2023-09-07 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,390 - ERROR - Error processing block at 2023-09-07 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,391 - ERROR - Error processing block at 2023-09-07 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,391 - ERROR - Error processing block at 2023-09-07 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,392 - ERROR - Error processing block at 2023-09-07 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,392 - ERROR - Error processing block at 2023-09-08 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,393 - ERROR - Error processing block at 2023-09-08 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,393 - ERROR - Error processing block at 2023-09-08 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,394 - ERROR - Error processing block at 2023-09-08 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,394 - ERROR - Error processing block at 2023-09-08 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,394 - ERROR - Error processing block at 2023-09-08 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,395 - ERROR - Error processing block at 2023-09-08 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,396 - ERROR - Error processing block at 2023-09-08 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,396 - ERROR - Error processing block at 2023-09-08 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,397 - ERROR - Error processing block at 2023-09-08 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,397 - ERROR - Error processing block at 2023-09-08 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,398 - ERROR - Error processing block at 2023-09-08 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,398 - ERROR - Error processing block at 2023-09-08 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,399 - ERROR - Error processing block at 2023-09-08 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,399 - ERROR - Error processing block at 2023-09-08 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,400 - ERROR - Error processing block at 2023-09-08 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,400 - ERROR - Error processing block at 2023-09-08 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,401 - ERROR - Error processing block at 2023-09-08 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,401 - ERROR - Error processing block at 2023-09-08 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,402 - ERROR - Error processing block at 2023-09-08 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,402 - ERROR - Error processing block at 2023-09-08 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,402 - ERROR - Error processing block at 2023-09-08 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,403 - ERROR - Error processing block at 2023-09-08 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,403 - ERROR - Error processing block at 2023-09-08 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,404 - ERROR - Error processing block at 2023-09-09 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,404 - ERROR - Error processing block at 2023-09-09 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,405 - ERROR - Error processing block at 2023-09-09 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,405 - ERROR - Error processing block at 2023-09-09 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,406 - ERROR - Error processing block at 2023-09-09 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,406 - ERROR - Error processing block at 2023-09-09 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,407 - ERROR - Error processing block at 2023-09-09 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,408 - ERROR - Error processing block at 2023-09-09 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,408 - ERROR - Error processing block at 2023-09-09 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,409 - ERROR - Error processing block at 2023-09-09 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,409 - ERROR - Error processing block at 2023-09-09 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,410 - ERROR - Error processing block at 2023-09-09 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,410 - ERROR - Error processing block at 2023-09-09 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,411 - ERROR - Error processing block at 2023-09-09 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,412 - ERROR - Error processing block at 2023-09-09 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,412 - ERROR - Error processing block at 2023-09-09 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,413 - ERROR - Error processing block at 2023-09-09 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,414 - ERROR - Error processing block at 2023-09-09 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,414 - ERROR - Error processing block at 2023-09-09 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,415 - ERROR - Error processing block at 2023-09-09 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,415 - ERROR - Error processing block at 2023-09-09 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,416 - ERROR - Error processing block at 2023-09-09 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,417 - ERROR - Error processing block at 2023-09-09 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,418 - ERROR - Error processing block at 2023-09-09 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,419 - ERROR - Error processing block at 2023-09-10 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,420 - ERROR - Error processing block at 2023-09-10 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,420 - ERROR - Error processing block at 2023-09-10 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,421 - ERROR - Error processing block at 2023-09-10 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,422 - ERROR - Error processing block at 2023-09-10 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,422 - ERROR - Error processing block at 2023-09-10 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,423 - ERROR - Error processing block at 2023-09-10 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,424 - ERROR - Error processing block at 2023-09-10 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,425 - ERROR - Error processing block at 2023-09-10 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,425 - ERROR - Error processing block at 2023-09-10 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,426 - ERROR - Error processing block at 2023-09-10 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,427 - ERROR - Error processing block at 2023-09-10 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,428 - ERROR - Error processing block at 2023-09-10 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,429 - ERROR - Error processing block at 2023-09-10 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,429 - ERROR - Error processing block at 2023-09-10 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,430 - ERROR - Error processing block at 2023-09-10 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,431 - ERROR - Error processing block at 2023-09-10 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,431 - ERROR - Error processing block at 2023-09-10 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,432 - ERROR - Error processing block at 2023-09-10 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,432 - ERROR - Error processing block at 2023-09-10 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,434 - ERROR - Error processing block at 2023-09-10 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,436 - ERROR - Error processing block at 2023-09-10 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,436 - ERROR - Error processing block at 2023-09-10 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,437 - ERROR - Error processing block at 2023-09-10 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,438 - ERROR - Error processing block at 2023-09-11 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,439 - ERROR - Error processing block at 2023-09-11 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,440 - ERROR - Error processing block at 2023-09-11 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,440 - ERROR - Error processing block at 2023-09-11 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,441 - ERROR - Error processing block at 2023-09-11 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,442 - ERROR - Error processing block at 2023-09-11 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,442 - ERROR - Error processing block at 2023-09-11 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,443 - ERROR - Error processing block at 2023-09-11 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,443 - ERROR - Error processing block at 2023-09-11 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,444 - ERROR - Error processing block at 2023-09-11 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,444 - ERROR - Error processing block at 2023-09-11 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,445 - ERROR - Error processing block at 2023-09-11 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,445 - ERROR - Error processing block at 2023-09-11 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,446 - ERROR - Error processing block at 2023-09-11 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,447 - ERROR - Error processing block at 2023-09-11 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,448 - ERROR - Error processing block at 2023-09-11 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,448 - ERROR - Error processing block at 2023-09-11 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,449 - ERROR - Error processing block at 2023-09-11 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,450 - ERROR - Error processing block at 2023-09-11 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,451 - ERROR - Error processing block at 2023-09-11 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,452 - ERROR - Error processing block at 2023-09-11 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,452 - ERROR - Error processing block at 2023-09-11 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,453 - ERROR - Error processing block at 2023-09-11 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,454 - ERROR - Error processing block at 2023-09-11 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,454 - ERROR - Error processing block at 2023-09-12 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,455 - ERROR - Error processing block at 2023-09-12 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,455 - ERROR - Error processing block at 2023-09-12 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,456 - ERROR - Error processing block at 2023-09-12 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,456 - ERROR - Error processing block at 2023-09-12 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,457 - ERROR - Error processing block at 2023-09-12 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,458 - ERROR - Error processing block at 2023-09-12 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,458 - ERROR - Error processing block at 2023-09-12 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,459 - ERROR - Error processing block at 2023-09-12 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,459 - ERROR - Error processing block at 2023-09-12 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,459 - ERROR - Error processing block at 2023-09-12 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,460 - ERROR - Error processing block at 2023-09-12 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,460 - ERROR - Error processing block at 2023-09-12 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,461 - ERROR - Error processing block at 2023-09-12 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,462 - ERROR - Error processing block at 2023-09-12 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,462 - ERROR - Error processing block at 2023-09-12 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,463 - ERROR - Error processing block at 2023-09-12 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,463 - ERROR - Error processing block at 2023-09-12 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,464 - ERROR - Error processing block at 2023-09-12 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,464 - ERROR - Error processing block at 2023-09-12 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,465 - ERROR - Error processing block at 2023-09-12 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,465 - ERROR - Error processing block at 2023-09-12 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,466 - ERROR - Error processing block at 2023-09-12 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,466 - ERROR - Error processing block at 2023-09-12 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,467 - ERROR - Error processing block at 2023-09-13 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,467 - ERROR - Error processing block at 2023-09-13 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,468 - ERROR - Error processing block at 2023-09-13 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,468 - ERROR - Error processing block at 2023-09-13 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,469 - ERROR - Error processing block at 2023-09-13 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,469 - ERROR - Error processing block at 2023-09-13 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,470 - ERROR - Error processing block at 2023-09-13 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,470 - ERROR - Error processing block at 2023-09-13 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,470 - ERROR - Error processing block at 2023-09-13 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,471 - ERROR - Error processing block at 2023-09-13 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,471 - ERROR - Error processing block at 2023-09-13 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,472 - ERROR - Error processing block at 2023-09-13 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,472 - ERROR - Error processing block at 2023-09-13 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,473 - ERROR - Error processing block at 2023-09-13 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,473 - ERROR - Error processing block at 2023-09-13 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,473 - ERROR - Error processing block at 2023-09-13 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,474 - ERROR - Error processing block at 2023-09-13 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,474 - ERROR - Error processing block at 2023-09-13 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,475 - ERROR - Error processing block at 2023-09-13 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,476 - ERROR - Error processing block at 2023-09-13 19:14:46.028734: Request-sent
# 2024-08-25 08:14:46,476 - ERROR - Error processing block at 2023-09-13 20:14:46.028734: Request-sent
# 2024-08-25 08:14:46,477 - ERROR - Error processing block at 2023-09-13 21:14:46.028734: Request-sent
# 2024-08-25 08:14:46,477 - ERROR - Error processing block at 2023-09-13 22:14:46.028734: Request-sent
# 2024-08-25 08:14:46,478 - ERROR - Error processing block at 2023-09-13 23:14:46.028734: Request-sent
# 2024-08-25 08:14:46,478 - ERROR - Error processing block at 2023-09-14 00:14:46.028734: Request-sent
# 2024-08-25 08:14:46,478 - ERROR - Error processing block at 2023-09-14 01:14:46.028734: Request-sent
# 2024-08-25 08:14:46,479 - ERROR - Error processing block at 2023-09-14 02:14:46.028734: Request-sent
# 2024-08-25 08:14:46,479 - ERROR - Error processing block at 2023-09-14 03:14:46.028734: Request-sent
# 2024-08-25 08:14:46,480 - ERROR - Error processing block at 2023-09-14 04:14:46.028734: Request-sent
# 2024-08-25 08:14:46,480 - ERROR - Error processing block at 2023-09-14 05:14:46.028734: Request-sent
# 2024-08-25 08:14:46,481 - ERROR - Error processing block at 2023-09-14 06:14:46.028734: Request-sent
# 2024-08-25 08:14:46,481 - ERROR - Error processing block at 2023-09-14 07:14:46.028734: Request-sent
# 2024-08-25 08:14:46,482 - ERROR - Error processing block at 2023-09-14 08:14:46.028734: Request-sent
# 2024-08-25 08:14:46,482 - ERROR - Error processing block at 2023-09-14 09:14:46.028734: Request-sent
# 2024-08-25 08:14:46,483 - ERROR - Error processing block at 2023-09-14 10:14:46.028734: Request-sent
# 2024-08-25 08:14:46,483 - ERROR - Error processing block at 2023-09-14 11:14:46.028734: Request-sent
# 2024-08-25 08:14:46,484 - ERROR - Error processing block at 2023-09-14 12:14:46.028734: Request-sent
# 2024-08-25 08:14:46,484 - ERROR - Error processing block at 2023-09-14 13:14:46.028734: Request-sent
# 2024-08-25 08:14:46,485 - ERROR - Error processing block at 2023-09-14 14:14:46.028734: Request-sent
# 2024-08-25 08:14:46,485 - ERROR - Error processing block at 2023-09-14 15:14:46.028734: Request-sent
# 2024-08-25 08:14:46,486 - ERROR - Error processing block at 2023-09-14 16:14:46.028734: Request-sent
# 2024-08-25 08:14:46,486 - ERROR - Error processing block at 2023-09-14 17:14:46.028734: Request-sent
# 2024-08-25 08:14:46,487 - ERROR - Error processing block at 2023-09-14 18:14:46.028734: Request-sent
# 2024-08-25 08:14:46,487 - ERROR - Error processing block at 2023-09-14 19:14:46.028734: Request-sent
# ...
# 2024-08-25 08:14:50,989 - ERROR - Error processing block at 2024-08-19 08:14:46.028734: Request-sent
# 2024-08-25 08:14:50,990 - ERROR - Error processing block at 2024-08-19 09:14:46.028734: Request-sent
# 2024-08-25 08:14:50,990 - ERROR - Error processing block at 2024-08-19 10:14:46.028734: Request-sent
# 2024-08-25 08:14:50,991 - ERROR - Error processing block at 2024-08-19 11:14:46.028734: Request-sent
# 2024-08-25 08:14:50,991 - ERROR - Error processing block at 2024-08-19 12:14:46.028734: Request-sent
# 2024-08-25 08:14:50,994 - ERROR - Error processing block at 2024-08-19 13:14:46.028734: Request-sent
# 2024-08-25 08:14:50,996 - ERROR - Error processing block at 2024-08-19 14:14:46.028734: Request-sent
# 2024-08-25 08:14:50,996 - ERROR - Error processing block at 2024-08-19 15:14:46.028734: Request-sent
# 2024-08-25 08:14:50,997 - ERROR - Error processing block at 2024-08-19 16:14:46.028734: Request-sent
# 2024-08-25 08:14:50,997 - ERROR - Error processing block at 2024-08-19 17:14:46.028734: Request-sent
# 2024-08-25 08:14:50,998 - ERROR - Error processing block at 2024-08-19 18:14:46.028734: Request-sent
# 2024-08-25 08:14:50,998 - ERROR - Error processing block at 2024-08-19 19:14:46.028734: Request-sent
# 2024-08-25 08:14:50,999 - ERROR - Error processing block at 2024-08-19 20:14:46.028734: Request-sent
# 2024-08-25 08:14:50,999 - ERROR - Error processing block at 2024-08-19 21:14:46.028734: Request-sent
# 2024-08-25 08:14:50,999 - ERROR - Error processing block at 2024-08-19 22:14:46.028734: Request-sent
# 2024-08-25 08:14:51,000 - ERROR - Error processing block at 2024-08-19 23:14:46.028734: Request-sent
# 2024-08-25 08:14:51,000 - ERROR - Error processing block at 2024-08-20 00:14:46.028734: Request-sent
# 2024-08-25 08:14:51,001 - ERROR - Error processing block at 2024-08-20 01:14:46.028734: Request-sent
# 2024-08-25 08:14:51,001 - ERROR - Error processing block at 2024-08-20 02:14:46.028734: Request-sent
# 2024-08-25 08:14:51,001 - ERROR - Error processing block at 2024-08-20 03:14:46.028734: Request-sent
# 2024-08-25 08:14:51,002 - ERROR - Error processing block at 2024-08-20 04:14:46.028734: Request-sent
# 2024-08-25 08:14:51,002 - ERROR - Error processing block at 2024-08-20 05:14:46.028734: Request-sent
# 2024-08-25 08:14:51,002 - ERROR - Error processing block at 2024-08-20 06:14:46.028734: Request-sent
# 2024-08-25 08:14:51,003 - ERROR - Error processing block at 2024-08-20 07:14:46.028734: Request-sent
# 2024-08-25 08:14:51,003 - ERROR - Error processing block at 2024-08-20 08:14:46.028734: Request-sent
# 2024-08-25 08:14:51,004 - ERROR - Error processing block at 2024-08-20 09:14:46.028734: Request-sent
# 2024-08-25 08:14:51,004 - ERROR - Error processing block at 2024-08-20 10:14:46.028734: Request-sent
# 2024-08-25 08:14:51,005 - ERROR - Error processing block at 2024-08-20 11:14:46.028734: Request-sent
# 2024-08-25 08:14:51,005 - ERROR - Error processing block at 2024-08-20 12:14:46.028734: Request-sent
# 2024-08-25 08:14:51,006 - ERROR - Error processing block at 2024-08-20 13:14:46.028734: Request-sent
# 2024-08-25 08:14:51,006 - ERROR - Error processing block at 2024-08-20 14:14:46.028734: Request-sent
# 2024-08-25 08:14:51,007 - ERROR - Error processing block at 2024-08-20 15:14:46.028734: Request-sent
# 2024-08-25 08:14:51,008 - ERROR - Error processing block at 2024-08-20 16:14:46.028734: Request-sent
# 2024-08-25 08:14:51,008 - ERROR - Error processing block at 2024-08-20 17:14:46.028734: Request-sent
# 2024-08-25 08:14:51,009 - ERROR - Error processing block at 2024-08-20 18:14:46.028734: Request-sent
# 2024-08-25 08:14:51,009 - ERROR - Error processing block at 2024-08-20 19:14:46.028734: Request-sent
# 2024-08-25 08:14:51,010 - ERROR - Error processing block at 2024-08-20 20:14:46.028734: Request-sent
# 2024-08-25 08:14:51,010 - ERROR - Error processing block at 2024-08-20 21:14:46.028734: Request-sent
# 2024-08-25 08:14:51,011 - ERROR - Error processing block at 2024-08-20 22:14:46.028734: Request-sent
# 2024-08-25 08:14:51,011 - ERROR - Error processing block at 2024-08-20 23:14:46.028734: Request-sent
# 2024-08-25 08:14:51,011 - ERROR - Error processing block at 2024-08-21 00:14:46.028734: Request-sent
# 2024-08-25 08:14:51,011 - ERROR - Error processing block at 2024-08-21 01:14:46.028734: Request-sent
# 2024-08-25 08:14:51,012 - ERROR - Error processing block at 2024-08-21 02:14:46.028734: Request-sent
# 2024-08-25 08:14:51,012 - ERROR - Error processing block at 2024-08-21 03:14:46.028734: Request-sent
# 2024-08-25 08:14:51,013 - ERROR - Error processing block at 2024-08-21 04:14:46.028734: Request-sent
# 2024-08-25 08:14:51,013 - ERROR - Error processing block at 2024-08-21 05:14:46.028734: Request-sent
# 2024-08-25 08:14:51,013 - ERROR - Error processing block at 2024-08-21 06:14:46.028734: Request-sent
# 2024-08-25 08:14:51,014 - ERROR - Error processing block at 2024-08-21 07:14:46.028734: Request-sent
# 2024-08-25 08:14:51,014 - ERROR - Error processing block at 2024-08-21 08:14:46.028734: Request-sent
# 2024-08-25 08:14:51,015 - ERROR - Error processing block at 2024-08-21 09:14:46.028734: Request-sent
# 2024-08-25 08:14:51,015 - ERROR - Error processing block at 2024-08-21 10:14:46.028734: Request-sent
# 2024-08-25 08:14:51,016 - ERROR - Error processing block at 2024-08-21 11:14:46.028734: Request-sent
# 2024-08-25 08:14:51,016 - ERROR - Error processing block at 2024-08-21 12:14:46.028734: Request-sent
# 2024-08-25 08:14:51,016 - ERROR - Error processing block at 2024-08-21 13:14:46.028734: Request-sent
# 2024-08-25 08:14:51,017 - ERROR - Error processing block at 2024-08-21 14:14:46.028734: Request-sent
# 2024-08-25 08:14:51,017 - ERROR - Error processing block at 2024-08-21 15:14:46.028734: Request-sent
# 2024-08-25 08:14:51,018 - ERROR - Error processing block at 2024-08-21 16:14:46.028734: Request-sent
# 2024-08-25 08:14:51,018 - ERROR - Error processing block at 2024-08-21 17:14:46.028734: Request-sent
# 2024-08-25 08:14:51,019 - ERROR - Error processing block at 2024-08-21 18:14:46.028734: Request-sent
# 2024-08-25 08:14:51,019 - ERROR - Error processing block at 2024-08-21 19:14:46.028734: Request-sent
# 2024-08-25 08:14:51,020 - ERROR - Error processing block at 2024-08-21 20:14:46.028734: Request-sent
# 2024-08-25 08:14:51,020 - ERROR - Error processing block at 2024-08-21 21:14:46.028734: Request-sent
# 2024-08-25 08:14:51,020 - ERROR - Error processing block at 2024-08-21 22:14:46.028734: Request-sent
# 2024-08-25 08:14:51,021 - ERROR - Error processing block at 2024-08-21 23:14:46.028734: Request-sent
# 2024-08-25 08:14:51,021 - ERROR - Error processing block at 2024-08-22 00:14:46.028734: Request-sent
# 2024-08-25 08:14:51,022 - ERROR - Error processing block at 2024-08-22 01:14:46.028734: Request-sent
# 2024-08-25 08:14:51,022 - ERROR - Error processing block at 2024-08-22 02:14:46.028734: Request-sent
# 2024-08-25 08:14:51,022 - ERROR - Error processing block at 2024-08-22 03:14:46.028734: Request-sent
# 2024-08-25 08:14:51,023 - ERROR - Error processing block at 2024-08-22 04:14:46.028734: Request-sent
# 2024-08-25 08:14:51,025 - ERROR - Error processing block at 2024-08-22 05:14:46.028734: Request-sent
# 2024-08-25 08:14:51,026 - ERROR - Error processing block at 2024-08-22 06:14:46.028734: Request-sent
# 2024-08-25 08:14:51,027 - ERROR - Error processing block at 2024-08-22 07:14:46.028734: Request-sent
# 2024-08-25 08:14:51,028 - ERROR - Error processing block at 2024-08-22 08:14:46.028734: Request-sent
# 2024-08-25 08:14:51,029 - ERROR - Error processing block at 2024-08-22 09:14:46.028734: Request-sent
# 2024-08-25 08:14:51,029 - ERROR - Error processing block at 2024-08-22 10:14:46.028734: Request-sent
# 2024-08-25 08:14:51,030 - ERROR - Error processing block at 2024-08-22 11:14:46.028734: Request-sent
# 2024-08-25 08:14:51,031 - ERROR - Error processing block at 2024-08-22 12:14:46.028734: Request-sent
# 2024-08-25 08:14:51,033 - ERROR - Error processing block at 2024-08-22 13:14:46.028734: Request-sent
# 2024-08-25 08:14:51,033 - ERROR - Error processing block at 2024-08-22 14:14:46.028734: Request-sent
# 2024-08-25 08:14:51,033 - ERROR - Error processing block at 2024-08-22 15:14:46.028734: Request-sent
# 2024-08-25 08:14:51,034 - ERROR - Error processing block at 2024-08-22 16:14:46.028734: Request-sent
# 2024-08-25 08:14:51,034 - ERROR - Error processing block at 2024-08-22 17:14:46.028734: Request-sent
# 2024-08-25 08:14:51,035 - ERROR - Error processing block at 2024-08-22 18:14:46.028734: Request-sent
# 2024-08-25 08:14:51,035 - ERROR - Error processing block at 2024-08-22 19:14:46.028734: Request-sent
# 2024-08-25 08:14:51,036 - ERROR - Error processing block at 2024-08-22 20:14:46.028734: Request-sent
# 2024-08-25 08:14:51,038 - ERROR - Error processing block at 2024-08-22 21:14:46.028734: Request-sent
# 2024-08-25 08:14:51,038 - ERROR - Error processing block at 2024-08-22 22:14:46.028734: Request-sent
# 2024-08-25 08:14:51,039 - ERROR - Error processing block at 2024-08-22 23:14:46.028734: Request-sent
# 2024-08-25 08:14:51,039 - ERROR - Error processing block at 2024-08-23 00:14:46.028734: Request-sent
# 2024-08-25 08:14:51,040 - ERROR - Error processing block at 2024-08-23 01:14:46.028734: Request-sent
# 2024-08-25 08:14:51,040 - ERROR - Error processing block at 2024-08-23 02:14:46.028734: Request-sent
# 2024-08-25 08:14:51,041 - ERROR - Error processing block at 2024-08-23 03:14:46.028734: Request-sent
# 2024-08-25 08:14:51,041 - ERROR - Error processing block at 2024-08-23 04:14:46.028734: Request-sent
# 2024-08-25 08:14:51,042 - ERROR - Error processing block at 2024-08-23 05:14:46.028734: Request-sent
# 2024-08-25 08:14:51,042 - ERROR - Error processing block at 2024-08-23 06:14:46.028734: Request-sent
# 2024-08-25 08:14:51,043 - ERROR - Error processing block at 2024-08-23 07:14:46.028734: Request-sent
# 2024-08-25 08:14:51,043 - ERROR - Error processing block at 2024-08-23 08:14:46.028734: Request-sent
# 2024-08-25 08:14:51,044 - ERROR - Error processing block at 2024-08-23 09:14:46.028734: Request-sent
# 2024-08-25 08:14:51,044 - ERROR - Error processing block at 2024-08-23 10:14:46.028734: Request-sent
# 2024-08-25 08:14:51,045 - ERROR - Error processing block at 2024-08-23 11:14:46.028734: Request-sent
# 2024-08-25 08:14:51,046 - ERROR - Error processing block at 2024-08-23 12:14:46.028734: Request-sent
# 2024-08-25 08:14:51,047 - ERROR - Error processing block at 2024-08-23 13:14:46.028734: Request-sent
# 2024-08-25 08:14:51,048 - ERROR - Error processing block at 2024-08-23 14:14:46.028734: Request-sent
# 2024-08-25 08:14:51,049 - ERROR - Error processing block at 2024-08-23 15:14:46.028734: Request-sent
# 2024-08-25 08:14:51,051 - ERROR - Error processing block at 2024-08-23 16:14:46.028734: Request-sent
# 2024-08-25 08:14:51,053 - ERROR - Error processing block at 2024-08-23 17:14:46.028734: Request-sent
# 2024-08-25 08:14:51,055 - ERROR - Error processing block at 2024-08-23 18:14:46.028734: Request-sent
# 2024-08-25 08:14:51,055 - ERROR - Error processing block at 2024-08-23 19:14:46.028734: Request-sent
# 2024-08-25 08:14:51,056 - ERROR - Error processing block at 2024-08-23 20:14:46.028734: Request-sent
# 2024-08-25 08:14:51,058 - ERROR - Error processing block at 2024-08-23 21:14:46.028734: Request-sent
# 2024-08-25 08:14:51,059 - ERROR - Error processing block at 2024-08-23 22:14:46.028734: Request-sent
# 2024-08-25 08:14:51,060 - ERROR - Error processing block at 2024-08-23 23:14:46.028734: Request-sent
# 2024-08-25 08:14:51,061 - ERROR - Error processing block at 2024-08-24 00:14:46.028734: Request-sent
# 2024-08-25 08:14:51,062 - ERROR - Error processing block at 2024-08-24 01:14:46.028734: Request-sent
# 2024-08-25 08:14:51,062 - ERROR - Error processing block at 2024-08-24 02:14:46.028734: Request-sent
# 2024-08-25 08:14:51,063 - ERROR - Error processing block at 2024-08-24 03:14:46.028734: Request-sent
# 2024-08-25 08:14:51,064 - ERROR - Error processing block at 2024-08-24 04:14:46.028734: Request-sent
# 2024-08-25 08:14:51,065 - ERROR - Error processing block at 2024-08-24 05:14:46.028734: Request-sent
# 2024-08-25 08:14:51,066 - ERROR - Error processing block at 2024-08-24 06:14:46.028734: Request-sent
# 2024-08-25 08:14:51,067 - ERROR - Error processing block at 2024-08-24 07:14:46.028734: Request-sent
# 2024-08-25 08:14:51,068 - ERROR - Error processing block at 2024-08-24 08:14:46.028734: Request-sent
# 2024-08-25 08:14:51,069 - ERROR - Error processing block at 2024-08-24 09:14:46.028734: Request-sent
# 2024-08-25 08:14:51,070 - ERROR - Error processing block at 2024-08-24 10:14:46.028734: Request-sent
# 2024-08-25 08:14:51,071 - ERROR - Error processing block at 2024-08-24 11:14:46.028734: Request-sent
# 2024-08-25 08:14:51,071 - ERROR - Error processing block at 2024-08-24 12:14:46.028734: Request-sent
# 2024-08-25 08:14:51,072 - ERROR - Error processing block at 2024-08-24 13:14:46.028734: Request-sent
# 2024-08-25 08:14:51,073 - ERROR - Error processing block at 2024-08-24 14:14:46.028734: Request-sent
# 2024-08-25 08:14:51,074 - ERROR - Error processing block at 2024-08-24 15:14:46.028734: Request-sent
# 2024-08-25 08:14:51,075 - ERROR - Error processing block at 2024-08-24 16:14:46.028734: Request-sent
# 2024-08-25 08:14:51,075 - ERROR - Error processing block at 2024-08-24 17:14:46.028734: Request-sent
# 2024-08-25 08:14:51,076 - ERROR - Error processing block at 2024-08-24 18:14:46.028734: Request-sent
# 2024-08-25 08:14:51,077 - ERROR - Error processing block at 2024-08-24 19:14:46.028734: Request-sent
# 2024-08-25 08:14:51,078 - ERROR - Error processing block at 2024-08-24 20:14:46.028734: Request-sent
# 2024-08-25 08:14:51,078 - ERROR - Error processing block at 2024-08-24 21:14:46.028734: Request-sent
# 2024-08-25 08:14:51,079 - ERROR - Error processing block at 2024-08-24 22:14:46.028734: Request-sent
# 2024-08-25 08:14:51,080 - ERROR - Error processing block at 2024-08-24 23:14:46.028734: Request-sent
# 2024-08-25 08:14:51,081 - ERROR - Error processing block at 2024-08-25 00:14:46.028734: Request-sent
# 2024-08-25 08:14:51,081 - ERROR - Error processing block at 2024-08-25 01:14:46.028734: Request-sent
# 2024-08-25 08:14:51,082 - ERROR - Error processing block at 2024-08-25 02:14:46.028734: Request-sent
# 2024-08-25 08:14:51,083 - ERROR - Error processing block at 2024-08-25 03:14:46.028734: Request-sent
# 2024-08-25 08:14:51,083 - ERROR - Error processing block at 2024-08-25 04:14:46.028734: Request-sent
# 2024-08-25 08:14:51,084 - ERROR - Error processing block at 2024-08-25 05:14:46.028734: Request-sent
# 2024-08-25 08:14:51,086 - ERROR - Error processing block at 2024-08-25 06:14:46.028734: Request-sent
# 2024-08-25 08:14:51,086 - ERROR - Error processing block at 2024-08-25 07:14:46.028734: Request-sent
# 2024-08-25 08:14:51,088 - ERROR - Error processing block at 2024-08-25 08:14:46.028734: Request-sent
# 2024-08-25 08:14:51,088 - INFO - Finished collecting historical data. Total entries: 0
# 2024-08-25 08:14:51,089 - INFO - Finished collecting historical data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 213
#     211 # Save the data to a CSV file in the specified data directory
#     212 csv_path = os.path.join('/mnt/volume_nyc1_01/bitcoin/', 'bitcoin_historical_data.csv')
# --> 213 with open(csv_path, 'w', newline='') as csvfile:
#     214     fieldnames = historical_data[0].keys() if historical_data else []
#     215     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#
# File ~/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/volume_nyc1_01/bitcoin/bitcoin_historical_data.csv'
