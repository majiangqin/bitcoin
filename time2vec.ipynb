# %% [markdown]
# ## The workflow

# %% [markdown]
# First finds optimal hyperparameters using Optuna
#
# Then validates model performance using 5-fold cross validation
#
# Finally trains one model on the entire dataset to make future predictions

# %%
import optuna
from dataclasses import asdict, dataclass
from functools import partial
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from typing import List, Dict, Tuple
import time
import random
import torch.optim.lr_scheduler as lr_scheduler
import warnings

warnings.filterwarnings('ignore')


@dataclass
class ModelConfig:
    """Configuration for LSTM model"""
    time2vec_dim: int = 20
    hidden_dim: int = 128
    batch_size: int = 128
    learning_rate: float = 0.00005
    num_epochs: int = 100
    max_encoder_length: int = 288
    max_prediction_length: int = 144
    clip_grad_norm: float = 1.0
    warmup_epochs: int = 3
    patience: int = 10
    min_delta: float = 1e-4
    dropout: float = 0.1


class EarlyStopping:
    def __init__(self, patience: int = 7, min_delta: float = 1e-4, verbose: bool = True):
        self.patience = patience
        self.min_delta = min_delta
        self.verbose = verbose
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.val_loss_min = float('inf')

    def __call__(self, val_loss: float, model: nn.Module) -> bool:
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0
        return self.early_stop


class Time2Vec(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(Time2Vec, self).__init__()
        self.w0 = nn.parameter.Parameter(torch.randn(input_dim, 1))
        self.b0 = nn.parameter.Parameter(torch.randn(1))
        self.w = nn.parameter.Parameter(torch.randn(input_dim, output_dim - 1))
        self.b = nn.parameter.Parameter(torch.randn(output_dim - 1))
        self.f = torch.sin

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        v1 = torch.matmul(x, self.w0) + self.b0
        v2 = self.f(torch.matmul(x, self.w) + self.b)
        return torch.cat([v1, v2], -1)


class BitcoinFeeModel(nn.Module):
    def __init__(self, hist_input_dim: int, future_input_dim: int, config: ModelConfig):
        super(BitcoinFeeModel, self).__init__()
        self.time2vec = Time2Vec(1, config.time2vec_dim)
        self.lstm = nn.LSTM(
            hist_input_dim + config.time2vec_dim,
            config.hidden_dim,
            batch_first=True,
            dropout=config.dropout
        )
        self.fc_combine = nn.Linear(config.hidden_dim + future_input_dim, config.hidden_dim)
        self.fc_out = nn.Linear(config.hidden_dim, 1)
        self.num_predictions = config.max_prediction_length

    def forward(self, time_feature: torch.Tensor, x_hist: torch.Tensor,
                x_future: torch.Tensor) -> torch.Tensor:
        batch_size, seq_len, _ = x_hist.shape
        time_encoded = self.time2vec(time_feature).expand(batch_size, seq_len, -1)
        x_hist_time = torch.cat([x_hist, time_encoded], dim=-1)

        _, (h_n, _) = self.lstm(x_hist_time)
        h_n = h_n.squeeze(0)

        outputs = []
        for i in range(self.num_predictions):
            combined = torch.cat((h_n, x_future[:, i, :]), dim=1)
            hidden = self.fc_combine(combined)
            out = self.fc_out(hidden)
            outputs.append(out)

        return torch.cat(outputs, dim=1)


class Time2VecDataset(Dataset):
    def __init__(self, data: pd.DataFrame, historical_features: List[str],
                 future_known_features: List[str], target: str, config: ModelConfig):
        self.data = data
        self.historical_features = historical_features
        self.future_known_features = future_known_features
        self.target = target
        self.config = config

    def __len__(self) -> int:
        return len(self.data) - self.config.max_encoder_length - self.config.max_prediction_length + 1

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
        encoder_start = idx
        encoder_end = idx + self.config.max_encoder_length
        decoder_end = encoder_end + self.config.max_prediction_length

        historical_data = self.data.iloc[encoder_start:encoder_end][self.historical_features]
        future_known_data = self.data.iloc[encoder_end:decoder_end][self.future_known_features]
        target_values = self.data.iloc[encoder_end:decoder_end][self.target]

        time_feature = torch.arange(0, self.config.max_encoder_length, dtype=torch.float32).unsqueeze(1)
        x_hist = torch.tensor(historical_data.values, dtype=torch.float32)
        x_future = torch.tensor(future_known_data.values, dtype=torch.float32)
        y = torch.tensor(target_values.values, dtype=torch.float32)

        return time_feature, x_hist, x_future, y


@dataclass
class ModelMetrics:
    mae: float
    rmse: float
    r2: float
    mape: float
    theil_u: float
    directional_accuracy: float


class BitcoinFeePredictor:


    def __init__(self, config: ModelConfig = ModelConfig()):
        self.config = config
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        self.historical_features = [
            'tx_count', 'mempool_size_mb', 'max_fee_rate', 'avg_fee_rate',
            'median_fee_rate', 'fee_rate_10th', 'fee_rate_90th', 'fee_rate_std',
            'mempool_min_fee', 'total_fee', 'mempool_usage', 'transaction_count',
            'block_weight', 'block_interval', 'hist_low_fee_ratio',
            'hist_med_fee_ratio', 'hist_high_fee_ratio', 'hist_fee_diversity',
            'hash_rate', 'bitcoin_price_usd'
        ]

        self.known_future_features = ['block_height', 'difficulty', 'block_version']
        self.target = 'block_median_fee_rate'


    def prepare_data(self, df: pd.DataFrame, scaler=None) -> Tuple[pd.DataFrame, RobustScaler]:
        """Prepare and scale data"""
        all_features = self.historical_features + self.known_future_features

        if scaler is None:
            scaler = RobustScaler()
            df[all_features] = scaler.fit_transform(df[all_features])
        else:
            df[all_features] = scaler.transform(df[all_features])
            
        return df, scaler


    def create_validation_dataloader(self, train_data: pd.DataFrame) -> DataLoader:
        """Create validation dataloader from last 20% of training data"""
        val_size = int(len(train_data) * 0.2)
        val_data = train_data.iloc[-val_size:]
        val_dataset = Time2VecDataset(val_data, self.historical_features,
                                  self.known_future_features, self.target, self.config)
        return DataLoader(val_dataset, batch_size=self.config.batch_size,
                      shuffle=False, drop_last=True)


    def train_model(self, train_data: pd.DataFrame) -> BitcoinFeeModel:
        """Train model with validation and early stopping"""
        train_size = int(len(train_data) * 0.8)
        train_subset = train_data.iloc[:train_size]

        train_dataset = Time2VecDataset(train_subset, self.historical_features,
                                    self.known_future_features, self.target, self.config)
        train_loader = DataLoader(train_dataset, batch_size=self.config.batch_size,
                              shuffle=True, drop_last=True)
        val_loader = self.create_validation_dataloader(train_data)

        model = BitcoinFeeModel(len(self.historical_features),
                            len(self.known_future_features), self.config).to(self.device)

        criterion = nn.HuberLoss()
        optimizer = optim.AdamW(model.parameters(), lr=self.config.learning_rate,
                            weight_decay=0.01, betas=(0.9, 0.999))

        scheduler = lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, T_0=10, T_mult=2, eta_min=1e-6
        )

        warmup_scheduler = lr_scheduler.LinearLR(
            optimizer,
            start_factor=0.1,
            end_factor=1.0,
            total_iters=self.config.warmup_epochs
         ) if self.config.warmup_epochs > 0 else None

        early_stopping = EarlyStopping(
        patience=self.config.patience,
        min_delta=self.config.min_delta
        )

        best_model_state = None
        best_val_loss = float('inf')

        for epoch in range(self.config.num_epochs):
            model.train()
            running_loss = 0.0

            for time_feature, x_hist, x_future_known, y in train_loader:
                time_feature = time_feature.to(self.device)
                x_hist = x_hist.to(self.device)
                x_future_known = x_future_known.to(self.device)
                y = y.to(self.device)

                outputs = model(time_feature, x_hist, x_future_known)
                loss = criterion(outputs, y)

                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), self.config.clip_grad_norm)
                optimizer.step()
                running_loss += loss.item()

            avg_train_loss = running_loss / len(train_loader)

        # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for time_feature, x_hist, x_future_known, y in val_loader:
                    time_feature = time_feature.to(self.device)
                    x_hist = x_hist.to(self.device)
                    x_future_known = x_future_known.to(self.device)
                    y = y.to(self.device)

                    outputs = model(time_feature, x_hist, x_future_known)
                    loss = criterion(outputs, y)
                    val_loss += loss.item()

                avg_val_loss = val_loss / len(val_loader)

            # Update learning rate
            if epoch < self.config.warmup_epochs and warmup_scheduler:
                warmup_scheduler.step()
            else:
                 scheduler.step()

            current_lr = optimizer.param_groups[0]['lr']
            print(f"Epoch {epoch + 1}/{self.config.num_epochs}, "
              f"Train Loss: {avg_train_loss:.4f}, "
              f"Val Loss: {avg_val_loss:.4f}, "
              f"LR: {current_lr:.6f}")

            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model_state = model.state_dict().copy()

            if early_stopping(avg_val_loss, model):
                print("Early stopping triggered")
                break

        if best_model_state is not None:
            model.load_state_dict(best_model_state)

        return model

    def predict(self, model: BitcoinFeeModel, data: pd.DataFrame) -> np.ndarray:
        """Make predictions"""
        model.eval()
        hist_data = data.tail(self.config.max_encoder_length)[self.historical_features].values

        future_known_data = np.zeros((self.config.max_prediction_length, len(self.known_future_features)))
        last_block_height = data['block_height'].iloc[-1]
        last_difficulty = data['difficulty'].iloc[-1]
        last_block_version = data['block_version'].iloc[-1]

        for i in range(self.config.max_prediction_length):
            future_known_data[i] = [last_block_height + i + 1, last_difficulty, last_block_version]

        time_feature = torch.arange(0, self.config.max_encoder_length, dtype=torch.float32).unsqueeze(1).to(self.device)
        x_hist = torch.tensor(hist_data, dtype=torch.float32).unsqueeze(0).to(self.device)
        x_future_known = torch.tensor(future_known_data, dtype=torch.float32).unsqueeze(0).to(self.device)

        with torch.no_grad():
            predictions = model(time_feature, x_hist, x_future_known).cpu().numpy().flatten()

        return predictions



    def calculate_metrics(self, y_true: np.ndarray, y_pred: np.ndarray) -> ModelMetrics:
        """Calculate evaluation metrics"""
        def mean_absolute_percentage_error(y_true, y_pred):
            return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

        def directional_accuracy(y_true, y_pred):
            return np.mean((np.diff(y_true) * np.diff(y_pred)) > 0) * 100

        def theil_u(y_true, y_pred):
            y_true_pct = (y_true[1:] - y_true[:-1]) / y_true[:-1]
            y_pred_pct = (y_pred[1:] - y_true[:-1]) / y_true[:-1]
            numerator = np.sqrt(np.mean((y_true_pct - y_pred_pct) ** 2))
            denominator = np.sqrt(np.mean(y_true_pct ** 2)) + np.sqrt(np.mean(y_pred_pct ** 2))
            return numerator / denominator

        return ModelMetrics(
            mae=mean_absolute_error(y_true, y_pred),
            rmse=np.sqrt(mean_squared_error(y_true, y_pred)),
            r2=r2_score(y_true, y_pred),
            mape=mean_absolute_percentage_error(y_true, y_pred),
            theil_u=theil_u(y_true, y_pred),
            directional_accuracy=directional_accuracy(y_true, y_pred)
        )
    
    def plot_predictions(self, y_true: np.ndarray, y_pred: np.ndarray,
                    title: str = "Actual vs Predicted Bitcoin Fee Rates") -> None:
        """Plot actual vs predicted values with metrics"""
        plt.figure(figsize=(15, 8))
    
        # Plot actual and predicted values
        x_axis = np.arange(len(y_true))
        plt.plot(x_axis, y_true, label='Actual', alpha=0.3, linewidth=2)
        plt.plot(x_axis, y_pred, label='Predicted',  alpha=0.3, linewidth=2)
    
        plt.title(title)
        plt.xlabel('Block Number')
        plt.ylabel('Fee Rate (sat/vB)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()

    def cross_validate(self, df: pd.DataFrame, n_splits: int = 5) -> Tuple[List[ModelMetrics], np.ndarray, np.ndarray]:
        """Perform time series cross-validation with combined plotting"""
        n_samples = len(df)
        metrics_list = []
        all_y_true = []
        all_y_pred = []
    
    # Create figure for combined plot
        plt.figure(figsize=(15, 8))
    
        for fold_idx in range(n_splits):
            train_end = n_samples - (n_splits - fold_idx) * self.config.max_prediction_length
            test_start = train_end
            test_end = test_start + self.config.max_prediction_length
        
        # Split and prepare data
            train_data = df.iloc[:train_end].copy()
            test_data = df.iloc[test_start:test_end].copy()
        
            train_data, scaler = self.prepare_data(train_data)
            test_data, _ = self.prepare_data(test_data, scaler)
        
        # Train model
            model = self.train_model(train_data)
        
        # Make predictions
            predictions = self.predict(model, train_data)
        
        # Get actual values
            y_true = test_data[self.target].values
        
        # Store results
            metrics = self.calculate_metrics(y_true, predictions)
            metrics_list.append(metrics)
        
        # Accumulate predictions for combined plot
            start_idx = fold_idx * len(predictions)
            all_y_true.extend(y_true)
            all_y_pred.extend(predictions)
    
    # Convert to numpy arrays for plotting
        all_y_true = np.array(all_y_true)
        all_y_pred = np.array(all_y_pred)
    
    # Create combined plot
        plt.figure(figsize=(15, 8))
        x_axis = np.arange(len(all_y_true))
    

        plt.plot(x_axis, all_y_true, label='Actual')
    
    # Plot predicted values in orange
        plt.plot(x_axis, all_y_pred, label='Predicted',  linestyle='--')
    
    # Calculate and format metrics for display
        mae_values = [m.mae for m in metrics_list]
        rmse_values = [m.rmse for m in metrics_list]
        theil_u_values = [m.theil_u for m in metrics_list]
        r2_values = [m.r2 for m in metrics_list]
        da_values = [m.directional_accuracy for m in metrics_list]
    
    # Customize plot
        plt.title('Actual vs Predicted Bitcoin Fee Rates (All Folds Combined)', pad=20)
        plt.xlabel('Block Number')
        plt.ylabel('Fee Rate')
        plt.legend(loc='upper right')
        plt.grid(True, alpha=0.3)
    
    # Add customized gridlines
        plt.gca().yaxis.grid(True, linestyle='--', alpha=0.3)
        plt.gca().xaxis.grid(True, linestyle='--', alpha=0.3)
    
    # Adjust layout to prevent text overlap
        plt.tight_layout()
    
    # Print metrics to console
        print("\nCross-Validation Results:")
        print(f"Mean Absolute Error (CV): {np.mean(mae_values):.4f} (±{np.std(mae_values):.4f})")
        print(f"Root Mean Squared Error (CV): {np.mean(rmse_values):.4f} (±{np.std(rmse_values):.4f})")
        print(f"Theil's U Statistic (CV): {np.mean(theil_u_values):.4f} (±{np.std(theil_u_values):.4f})")
        print(f"R² Score (CV): {np.mean(r2_values):.4f} (±{np.std(r2_values):.4f})")
        print(f"Directional Accuracy (CV): {np.mean(da_values):.2f}% (±{np.std(da_values):.2f}%)")
    
        return metrics_list, all_y_true, all_y_pred


class ModelTuner:
    def __init__(self, df, n_trials=50):
        self.df = df
        self.n_trials = n_trials
        self.best_params = None
        self.best_score = float('inf')

    def objective(self, trial):
        """Optuna objective function for hyperparameter optimization"""
        try:
            # Define hyperparameter search space
            config = ModelConfig(
                # Time2Vec parameters
                time2vec_dim=trial.suggest_int('time2vec_dim', 16, 32),

                # Model architecture
                hidden_dim=trial.suggest_int('hidden_dim', 32, 256, step=32),

                # Training parameters
                batch_size=trial.suggest_categorical('batch_size', [32, 64, 128, 256]),
                learning_rate=trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True),

                # Regularization
                dropout=trial.suggest_float('dropout', 0.1, 0.5),
                clip_grad_norm=trial.suggest_float('clip_grad_norm', 0.1, 5.0),

                # Training schedule
                warmup_epochs=trial.suggest_int('warmup_epochs', 1, 10),
                patience=trial.suggest_int('patience', 5, 15),

                # Keep other parameters fixed
                num_epochs=100,
                max_encoder_length=288,
                max_prediction_length=144,
                min_delta=1e-4
            )

            # Initialize predictor with trial config
            predictor = BitcoinFeePredictor(config)

            # Split data before scaling
            n_samples = len(self.df)
            train_end = n_samples - config.max_prediction_length
            train_data = self.df.iloc[:train_end].copy()
            test_data = self.df.iloc[train_end:].copy()

            # Fit scaler only on training data
            train_data, scaler = predictor.prepare_data(train_data)
            test_data, _ = predictor.prepare_data(test_data, scaler)  # Use same scaler

            # Train model
            model = predictor.train_model(train_data)

            # Make predictions
            predictions = predictor.predict(model, train_data)

            # Get actual values
            y_true = test_data[predictor.target].values

            # Calculate metrics
            metrics = predictor.calculate_metrics(y_true, predictions)

            # Use RMSE as the optimization metric
            return metrics.rmse

        except Exception as e:
            print(f"Trial failed with error: {str(e)}")
            return float('inf')

    def find_best_params(self):
        """Run hyperparameter optimization"""
        try:
            study = optuna.create_study(
                direction='minimize',
                pruner=optuna.pruners.MedianPruner(
                    n_startup_trials=5,
                    n_warmup_steps=5,
                    interval_steps=3
                )
            )

            study.sampler = optuna.samplers.TPESampler(
                n_startup_trials=10,
                multivariate=True,
                constant_liar=True
            )

            study.optimize(self.objective, n_trials=self.n_trials, show_progress_bar=True)

            print("\nOptimization Results:")
            print(f"Number of completed trials: {len(study.trials)}")
            print("\nBest trial:")
            trial = study.best_trial

            print(f"Value (RMSE): {trial.value:.4f}")
            print("\nBest hyperparameters:")
            for key, value in trial.params.items():
                print(f"    {key}: {value}")

            self.best_params = trial.params
            self.best_score = trial.value

            return study

        except Exception as e:
            print(f"Error in hyperparameter optimization: {str(e)}")
            raise


def main_with_tuning_and_cv():
    try:
        # Set seeds
        random.seed(42)
        np.random.seed(42)
        torch.manual_seed(42)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(42)
            torch.cuda.manual_seed_all(42)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False

        # Load data
        print("Loading data...")
        df = pd.read_csv('real_time_cleaned.csv')
        df['block_time'] = pd.to_datetime(df['block_time'])
        df = df.sort_values('block_time')
        
        # Set block_time as index
        df.set_index('block_time', inplace=True)

        # Step 1: Hyperparameter Optimization
        print("\nStarting hyperparameter optimization...")
        tuner = ModelTuner(df, n_trials=100)  # Increased trials
        study = tuner.find_best_params()

        # Create config with best parameters
        best_config = ModelConfig(**study.best_params)
        
        # Step 2: Cross Validation with Best Parameters
        print("\nPerforming cross-validation with best parameters...")
        predictor = BitcoinFeePredictor(best_config)
        metrics_list, all_y_true, all_y_pred = predictor.cross_validate(df, n_splits=5)
        
        # Print cross-validation results
        print("\nCross-validation Results:")
        mae_values = [m.mae for m in metrics_list]
        rmse_values = [m.rmse for m in metrics_list]
        r2_values = [m.r2 for m in metrics_list]
        
        print(f"MAE: {np.mean(mae_values):.4f} (±{np.std(mae_values):.4f})")
        print(f"RMSE: {np.mean(rmse_values):.4f} (±{np.std(rmse_values):.4f})")
        print(f"R2: {np.mean(r2_values):.4f} (±{np.std(r2_values):.4f})")

        # Step 3: Train Final Model on Full Dataset for Future Predictions
        print("\nTraining final model on full dataset...")
        df_prepared, scaler = predictor.prepare_data(df)
        model = predictor.train_model(df_prepared)
        
        # Generate predictions for next 144 blocks
        predictions = predictor.predict(model, df_prepared)

        # Create timestamps for predictions
        last_time = df.index[-1]  # Now this will be a timestamp
        prediction_times = pd.date_range(
            start=last_time,  # Use the last timestamp
            periods=145,      # Include the last timestamp
            freq='10T'
        )[1:]  # Exclude the first timestamp which is the last actual data point

        # Create results DataFrame with proper timestamps
        results_df = pd.DataFrame({
            'timestamp': prediction_times,
            'predicted_fee_rate': predictions[:144]
        })

        # Plot final results with proper time axis
        plt.figure(figsize=(15, 8))
        
        # Plot historical data
        historical_data = df['block_median_fee_rate'].iloc[-144:]
        plt.plot(historical_data.index, historical_data.values,
                 label='Historical', color='gray', alpha=0.5)
        
        # Plot predictions
        plt.plot(results_df['timestamp'], results_df['predicted_fee_rate'],
                 label='Predicted',  marker='o', markersize=4)
        
        plt.title('Bitcoin Fee Rate Predictions - Next 144 Blocks')
        plt.xlabel('Time')
        plt.ylabel('Fee Rate (sat/vB)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.gcf().autofmt_xdate()
        plt.tight_layout()
        plt.show()

        # Save results
        results_df.to_csv('time2vec_predictions.csv')
        best_params_df = pd.DataFrame([study.best_params])
        best_params_df.to_csv('time2vec_best_params.csv', index=False)

        # Save cross-validation results with more detailed metrics
        cv_results = pd.DataFrame({
            'fold': range(1, len(metrics_list) + 1),
            'mae': [m.mae for m in metrics_list],
            'rmse': [m.rmse for m in metrics_list],
            'r2': [m.r2 for m in metrics_list],
            'mape': [m.mape for m in metrics_list],
            'theil_u': [m.theil_u for m in metrics_list],
            'directional_accuracy': [m.directional_accuracy for m in metrics_list]
        })
        cv_results.to_csv('cross_validation_results.csv', index=False)

        print("\nResults saved:")
        print("- Predictions: 'time2vec_predictions.csv'")
        print("- Best parameters: 'time2vec_best_params.csv'")
        print("- Cross-validation results: 'cross_validation_results.csv'")

        return study, results_df, cv_results

    except Exception as e:
        print(f"Error in main process: {str(e)}")
        raise


# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Load and prepare data
print("Loading data...")
df = pd.read_csv('real_time_cleaned.csv')
df['block_time'] = pd.to_datetime(df['block_time'])
df = df.sort_values('block_time')
df.set_index('block_time', inplace=True)

# Run hyperparameter optimization
print("\nStarting hyperparameter optimization...")
tuner = ModelTuner(df, n_trials=50)  # Changed back to 50 trials as in original
study = tuner.find_best_params()

# Save best parameters
best_params_df = pd.DataFrame([study.best_params])
best_params_df.to_csv('time2vec_best_params.csv', index=False)

print("\nBest parameters saved to 'time2vec_best_params.csv'")

# Plot optimization history
plt.figure(figsize=(10, 6))
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.title('Hyperparameter Optimization History')
plt.tight_layout()
plt.show()

# Print the best parameters
print("\nBest hyperparameters found:")
for key, value in study.best_params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-11-25 00:52:36,226] A new study created in memory with name: no-name-bb414eb4-cb8f-4634-828b-ce5d55952a6e
# Loading data...
#
# Starting hyperparameter optimization...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 1/100, Train Loss: 5.0298, Val Loss: 10.6528, LR: 0.000008
# Epoch 2/100, Train Loss: 5.0096, Val Loss: 10.6079, LR: 0.000012
# Epoch 3/100, Train Loss: 4.9641, Val Loss: 10.5408, LR: 0.000017
# Epoch 4/100, Train Loss: 4.8812, Val Loss: 10.4459, LR: 0.000021
# Epoch 5/100, Train Loss: 4.7679, Val Loss: 10.3200, LR: 0.000025
# Epoch 6/100, Train Loss: 4.6226, Val Loss: 10.1624, LR: 0.000029
# Epoch 7/100, Train Loss: 4.4572, Val Loss: 9.9692, LR: 0.000033
# Epoch 8/100, Train Loss: 4.2293, Val Loss: 9.7342, LR: 0.000037
# Epoch 9/100, Train Loss: 3.9789, Val Loss: 9.4491, LR: 0.000041
# Epoch 10/100, Train Loss: 3.7183, Val Loss: 9.1085, LR: 0.000045
# Epoch 11/100, Train Loss: 3.4147, Val Loss: 8.6873, LR: 0.000044
# Epoch 12/100, Train Loss: 3.1178, Val Loss: 8.2144, LR: 0.000040
# Epoch 13/100, Train Loss: 2.9004, Val Loss: 7.7080, LR: 0.000036
# Epoch 14/100, Train Loss: 2.7805, Val Loss: 7.2052, LR: 0.000030
# Epoch 15/100, Train Loss: 2.7062, Val Loss: 6.7888, LR: 0.000023
# Epoch 16/100, Train Loss: 2.6850, Val Loss: 6.6921, LR: 0.000016
# Epoch 17/100, Train Loss: 2.6961, Val Loss: 6.7113, LR: 0.000010
# EarlyStopping counter: 1 out of 6
# Epoch 18/100, Train Loss: 2.6972, Val Loss: 6.7092, LR: 0.000005
# EarlyStopping counter: 2 out of 6
# Epoch 19/100, Train Loss: 2.7013, Val Loss: 6.7100, LR: 0.000002
# EarlyStopping counter: 3 out of 6
# Epoch 20/100, Train Loss: 2.7032, Val Loss: 6.7095, LR: 0.000045
# EarlyStopping counter: 4 out of 6
# Epoch 21/100, Train Loss: 2.6760, Val Loss: 6.6464, LR: 0.000044
# Epoch 22/100, Train Loss: 2.6567, Val Loss: 6.6260, LR: 0.000044
# Epoch 23/100, Train Loss: 2.6457, Val Loss: 6.5219, LR: 0.000042
# Epoch 24/100, Train Loss: 2.6479, Val Loss: 6.3819, LR: 0.000040
# Epoch 25/100, Train Loss: 2.6207, Val Loss: 6.3059, LR: 0.000038
# EarlyStopping counter: 4 out of 11
# Epoch 23/100, Train Loss: 1.5782, Val Loss: 3.5548, LR: 0.000081
# EarlyStopping counter: 5 out of 11
# Epoch 24/100, Train Loss: 1.5686, Val Loss: 3.6162, LR: 0.000076
# EarlyStopping counter: 6 out of 11
# Epoch 25/100, Train Loss: 1.5609, Val Loss: 3.5453, LR: 0.000069
# EarlyStopping counter: 7 out of 11
# Epoch 26/100, Train Loss: 1.5532, Val Loss: 3.5262, LR: 0.000063
# EarlyStopping counter: 8 out of 11
# Epoch 27/100, Train Loss: 1.5493, Val Loss: 3.6022, LR: 0.000055
# EarlyStopping counter: 9 out of 11
# Epoch 28/100, Train Loss: 1.5426, Val Loss: 3.6135, LR: 0.000048
# EarlyStopping counter: 10 out of 11
# Epoch 29/100, Train Loss: 1.5392, Val Loss: 3.5914, LR: 0.000041
# EarlyStopping counter: 11 out of 11
# Early stopping triggered
# [I 2024-11-25 03:13:10,137] Trial 8 finished with value: 3.6803545196456415 and parameters: {'time2vec_dim': 23, 'hidden_dim': 160, 'batch_size': 128, 'learning_rate': 9.5160919841683e-05, 'dropout': 0.3215647931463793, 'clip_grad_norm': 1.190707825980948, 'warmup_epochs': 8, 'patience': 11}. Best is trial 8 with value: 3.6803545196456415.
# Epoch 1/100, Train Loss: 4.4720, Val Loss: 9.0660, LR: 0.000208
# Epoch 2/100, Train Loss: 2.5913, Val Loss: 3.1803, LR: 0.000202
# Epoch 3/100, Train Loss: 1.8052, Val Loss: 3.9529, LR: 0.000188
# EarlyStopping counter: 1 out of 12
# Epoch 4/100, Train Loss: 1.6663, Val Loss: 3.8270, LR: 0.000165
# EarlyStopping counter: 2 out of 12
# Epoch 5/100, Train Loss: 1.5983, Val Loss: 3.8570, LR: 0.000136
# EarlyStopping counter: 3 out of 12
# Epoch 6/100, Train Loss: 1.5736, Val Loss: 3.8984, LR: 0.000104
# EarlyStopping counter: 4 out of 12
# Epoch 7/100, Train Loss: 1.5628, Val Loss: 3.8519, LR: 0.000072
# EarlyStopping counter: 5 out of 12
# Epoch 8/100, Train Loss: 1.5523, Val Loss: 3.7486, LR: 0.000044
# EarlyStopping counter: 6 out of 12
# Epoch 9/100, Train Loss: 1.5471, Val Loss: 3.6585, LR: 0.000021
# EarlyStopping counter: 7 out of 12
# Epoch 10/100, Train Loss: 1.5417, Val Loss: 3.6293, LR: 0.000006
# EarlyStopping counter: 8 out of 12
# Epoch 11/100, Train Loss: 1.5406, Val Loss: 3.6165, LR: 0.000208
# EarlyStopping counter: 9 out of 12
# Epoch 12/100, Train Loss: 1.5587, Val Loss: 3.8259, LR: 0.000206
# EarlyStopping counter: 10 out of 12
# Epoch 13/100, Train Loss: 1.5549, Val Loss: 3.8847, LR: 0.000202
# EarlyStopping counter: 11 out of 12
# Epoch 14/100, Train Loss: 1.5499, Val Loss: 3.8679, LR: 0.000196
# EarlyStopping counter: 12 out of 12
# Early stopping triggered
# Epoch 60/100, Train Loss: 1.5519, Val Loss: 4.0075, LR: 0.000026
# EarlyStopping counter: 3 out of 12
# Epoch 61/100, Train Loss: 1.5503, Val Loss: 3.9581, LR: 0.000024
# EarlyStopping counter: 4 out of 12
# Epoch 62/100, Train Loss: 1.5507, Val Loss: 3.9894, LR: 0.000021
# EarlyStopping counter: 5 out of 12
# Epoch 63/100, Train Loss: 1.5487, Val Loss: 3.9840, LR: 0.000019
# EarlyStopping counter: 6 out of 12
# Epoch 64/100, Train Loss: 1.5506, Val Loss: 3.9957, LR: 0.000016
# ...
# Epoch 6/100, Train Loss: 2.6261, Val Loss: 5.9502, LR: 0.000043
# Epoch 7/100, Train Loss: 2.5336, Val Loss: 5.3965, LR: 0.000049
# Epoch 8/100, Train Loss: 2.2971, Val Loss: 4.2728, LR: 0.000056
# Epoch 9/100, Train Loss: 2.0432, Val Loss: 3.4503, LR: 0.000054
# Epoch 10/100, Train Loss: 1.7590, Val Loss: 3.5977, LR: 0.000051
# EarlyStopping counter: 1 out of 5
# Epoch 11/100, Train Loss: 1.5975, Val Loss: 3.7888, LR: 0.000044
# EarlyStopping counter: 2 out of 5
# Epoch 12/100, Train Loss: 1.5780, Val Loss: 3.7767, LR: 0.000037
# EarlyStopping counter: 3 out of 5
# Epoch 13/100, Train Loss: 1.5686, Val Loss: 3.9054, LR: 0.000028
# EarlyStopping counter: 4 out of 5
# Epoch 14/100, Train Loss: 1.5571, Val Loss: 3.8840, LR: 0.000020
# EarlyStopping counter: 5 out of 5
# Early stopping triggered
# [I 2024-11-25 13:22:02,549] Trial 44 finished with value: 8.383443813270166 and parameters: {'time2vec_dim': 19, 'hidden_dim': 256, 'batch_size': 32, 'learning_rate': 5.576848344632736e-05, 'dropout': 0.4092395418490892, 'clip_grad_norm': 0.543914033238194, 'warmup_epochs': 8, 'patience': 5}. Best is trial 8 with value: 3.6803545196456415.
# Epoch 1/100, Train Loss: 5.2243, Val Loss: 10.5242, LR: 0.000003
# Epoch 2/100, Train Loss: 5.0793, Val Loss: 10.3386, LR: 0.000005
# Epoch 3/100, Train Loss: 4.8082, Val Loss: 10.0117, LR: 0.000007
# Epoch 4/100, Train Loss: 4.4475, Val Loss: 9.6401, LR: 0.000009
# Epoch 5/100, Train Loss: 3.8791, Val Loss: 8.8063, LR: 0.000011
# Epoch 6/100, Train Loss: 3.1542, Val Loss: 7.5797, LR: 0.000013
# Epoch 7/100, Train Loss: 2.7331, Val Loss: 6.3715, LR: 0.000013
# Epoch 8/100, Train Loss: 2.6620, Val Loss: 6.3023, LR: 0.000012
# Epoch 9/100, Train Loss: 2.6360, Val Loss: 6.2053, LR: 0.000010
# Epoch 10/100, Train Loss: 2.6183, Val Loss: 6.0397, LR: 0.000009
# Epoch 11/100, Train Loss: 2.5851, Val Loss: 5.8871, LR: 0.000007
# Epoch 12/100, Train Loss: 2.5517, Val Loss: 5.7726, LR: 0.000005
# Epoch 13/100, Train Loss: 2.5352, Val Loss: 5.7023, LR: 0.000003
# Epoch 14/100, Train Loss: 2.5188, Val Loss: 5.6682, LR: 0.000002
# Epoch 3/100, Train Loss: 2.6380, Val Loss: 5.5717, LR: 0.000119
# Epoch 4/100, Train Loss: 2.2946, Val Loss: 3.3084, LR: 0.000150
# Epoch 5/100, Train Loss: 1.8060, Val Loss: 3.6747, LR: 0.000180
# EarlyStopping counter: 1 out of 9
# Epoch 6/100, Train Loss: 1.6299, Val Loss: 3.7686, LR: 0.000211
# EarlyStopping counter: 2 out of 9
# Epoch 7/100, Train Loss: 1.6206, Val Loss: 3.8092, LR: 0.000241
# EarlyStopping counter: 3 out of 9
# Epoch 8/100, Train Loss: 1.5784, Val Loss: 3.9214, LR: 0.000272
# EarlyStopping counter: 4 out of 9
# Epoch 9/100, Train Loss: 1.5768, Val Loss: 3.7301, LR: 0.000265
# EarlyStopping counter: 5 out of 9
# Epoch 10/100, Train Loss: 1.5561, Val Loss: 4.2201, LR: 0.000246
# EarlyStopping counter: 6 out of 9
# Epoch 11/100, Train Loss: 1.5548, Val Loss: 3.7451, LR: 0.000216
# EarlyStopping counter: 7 out of 9
# Epoch 12/100, Train Loss: 1.5498, Val Loss: 3.9116, LR: 0.000178
# EarlyStopping counter: 8 out of 9
# Epoch 13/100, Train Loss: 1.5379, Val Loss: 4.0147, LR: 0.000136
# EarlyStopping counter: 9 out of 9
# Early stopping triggered
# [I 2024-11-25 14:45:08,303] Trial 49 finished with value: 8.966039629269018 and parameters: {'time2vec_dim': 21, 'hidden_dim': 224, 'batch_size': 32, 'learning_rate': 0.0002718780310198905, 'dropout': 0.4954136730156665, 'clip_grad_norm': 0.35646711900236006, 'warmup_epochs': 8, 'patience': 9}. Best is trial 8 with value: 3.6803545196456415.
#
# Optimization Results:
# Number of completed trials: 50
#
# Best trial:
# Value (RMSE): 3.6804
#
# Best hyperparameters:
#     time2vec_dim: 23
#     hidden_dim: 160
#     batch_size: 128
#     learning_rate: 9.5160919841683e-05
#     dropout: 0.3215647931463793
#     clip_grad_norm: 1.190707825980948
#     warmup_epochs: 8
#     patience: 11
#
# Best parameters saved to 'time2vec_best_params.csv'
# Best hyperparameters found:
#     time2vec_dim: 23
#     hidden_dim: 160
#     batch_size: 128
#     learning_rate: 9.5160919841683e-05
#     dropout: 0.3215647931463793
#     clip_grad_norm: 1.190707825980948
#     warmup_epochs: 8
#     patience: 11

# %%
best_params
# Out:
# {'time2vec_dim': 23,
#  'hidden_dim': 160,
#  'batch_size': 128,
#  'learning_rate': 9.5160919841683e-05,
#  'dropout': 0.3215647931463793,
#  'clip_grad_norm': 1.190707825980948,
#  'warmup_epochs': 8,
#  'patience': 11}

# %%
# Load and process best parameters
best_params = pd.read_csv('time2vec_best_params.csv').iloc[0].to_dict()

# Convert parameters to correct types
best_params['time2vec_dim'] = int(best_params['time2vec_dim'])
best_params['hidden_dim'] = int(best_params['hidden_dim'])
best_params['batch_size'] = int(best_params['batch_size'])
best_params['warmup_epochs'] = int(best_params['warmup_epochs'])
best_params['patience'] = int(best_params['patience'])

# Create config with corrected parameter types (other parameters will use defaults)
best_config = ModelConfig(**best_params)

# Initialize predictor with best parameters
print("\nPerforming cross-validation with best parameters...")
predictor = BitcoinFeePredictor(best_config)
metrics_list, all_y_true, all_y_pred = predictor.cross_validate(df, n_splits=5)

# Print detailed cross-validation results
print("\nCross-validation Results:")
mae_values = [m.mae for m in metrics_list]
rmse_values = [m.rmse for m in metrics_list]
r2_values = [m.r2 for m in metrics_list]
theil_u_values = [m.theil_u for m in metrics_list]
da_values = [m.directional_accuracy for m in metrics_list]

print(f"Mean Absolute Error (CV): {np.mean(mae_values):.4f} (±{np.std(mae_values):.4f})")
print(f"Root Mean Squared Error (CV): {np.mean(rmse_values):.4f} (±{np.std(rmse_values):.4f})")
print(f"R² Score (CV): {np.mean(r2_values):.4f} (±{np.std(r2_values):.4f})")
print(f"Theil's U Statistic (CV): {np.mean(theil_u_values):.4f} (±{np.std(theil_u_values):.4f})")
print(f"Directional Accuracy (CV): {np.mean(da_values):.2f}% (±{np.std(da_values):.2f}%)")

# Save cross-validation results
cv_results = pd.DataFrame({
    'fold': range(1, len(metrics_list) + 1),
    'mae': mae_values,
    'rmse': rmse_values,
    'r2': r2_values,
    'mape': [m.mape for m in metrics_list],
    'theil_u': theil_u_values,
    'directional_accuracy': da_values
})
cv_results.to_csv('cross_validation_results.csv', index=False)

print("\nCross-validation results saved to 'cross_validation_results.csv'")
# Out:
# Performing cross-validation with best parameters...
# Epoch 1/100, Train Loss: 4.0833, Val Loss: 11.3248, LR: 0.000020
# Epoch 2/100, Train Loss: 3.9403, Val Loss: 11.1474, LR: 0.000031
# Epoch 3/100, Train Loss: 3.7170, Val Loss: 10.8707, LR: 0.000042
# Epoch 4/100, Train Loss: 3.3922, Val Loss: 10.4811, LR: 0.000052
# Epoch 5/100, Train Loss: 2.9266, Val Loss: 9.9290, LR: 0.000063
# Epoch 6/100, Train Loss: 2.3727, Val Loss: 9.1317, LR: 0.000074
# Epoch 7/100, Train Loss: 1.8226, Val Loss: 7.7205, LR: 0.000084
# Epoch 8/100, Train Loss: 1.6569, Val Loss: 7.6306, LR: 0.000095
# Epoch 9/100, Train Loss: 1.6472, Val Loss: 7.3668, LR: 0.000093
# Epoch 10/100, Train Loss: 1.6363, Val Loss: 7.2882, LR: 0.000086
# Epoch 11/100, Train Loss: 1.6260, Val Loss: 7.1775, LR: 0.000076
# Epoch 12/100, Train Loss: 1.6164, Val Loss: 7.2476, LR: 0.000063
# EarlyStopping counter: 1 out of 11
# Epoch 13/100, Train Loss: 1.6081, Val Loss: 7.2637, LR: 0.000048
# EarlyStopping counter: 2 out of 11
# Epoch 14/100, Train Loss: 1.5981, Val Loss: 7.2168, LR: 0.000034
# EarlyStopping counter: 3 out of 11
# Epoch 15/100, Train Loss: 1.5974, Val Loss: 7.1775, LR: 0.000020
# EarlyStopping counter: 4 out of 11
# Epoch 16/100, Train Loss: 1.5908, Val Loss: 7.1699, LR: 0.000010
# Epoch 17/100, Train Loss: 1.5805, Val Loss: 7.1662, LR: 0.000003
# Epoch 18/100, Train Loss: 1.5807, Val Loss: 7.1649, LR: 0.000095
# Epoch 19/100, Train Loss: 1.5653, Val Loss: 7.0386, LR: 0.000095
# Epoch 20/100, Train Loss: 1.5446, Val Loss: 6.8665, LR: 0.000093
# Epoch 21/100, Train Loss: 1.5164, Val Loss: 6.6695, LR: 0.000090
# Epoch 22/100, Train Loss: 1.4897, Val Loss: 6.2797, LR: 0.000086
# Epoch 23/100, Train Loss: 1.4574, Val Loss: 6.3923, LR: 0.000081
# EarlyStopping counter: 1 out of 11
# Epoch 24/100, Train Loss: 1.4449, Val Loss: 6.1820, LR: 0.000076
# Epoch 25/100, Train Loss: 1.4374, Val Loss: 6.1167, LR: 0.000069
# Epoch 26/100, Train Loss: 1.4344, Val Loss: 6.1766, LR: 0.000063
# EarlyStopping counter: 1 out of 11
# Epoch 27/100, Train Loss: 1.4302, Val Loss: 6.1626, LR: 0.000055
# EarlyStopping counter: 2 out of 11
# Epoch 28/100, Train Loss: 1.4251, Val Loss: 6.1957, LR: 0.000048
# EarlyStopping counter: 3 out of 11
# Epoch 29/100, Train Loss: 1.4229, Val Loss: 6.1885, LR: 0.000041
# EarlyStopping counter: 4 out of 11
# Epoch 30/100, Train Loss: 1.4206, Val Loss: 6.1335, LR: 0.000034
# EarlyStopping counter: 5 out of 11
# Epoch 31/100, Train Loss: 1.4161, Val Loss: 6.0841, LR: 0.000027
# Epoch 32/100, Train Loss: 1.4151, Val Loss: 6.0917, LR: 0.000020
# EarlyStopping counter: 1 out of 11
# Epoch 33/100, Train Loss: 1.4140, Val Loss: 6.1039, LR: 0.000015
# EarlyStopping counter: 2 out of 11
# Epoch 34/100, Train Loss: 1.4149, Val Loss: 6.1040, LR: 0.000010
# EarlyStopping counter: 3 out of 11
# Epoch 35/100, Train Loss: 1.4114, Val Loss: 6.0961, LR: 0.000006
# EarlyStopping counter: 4 out of 11
# Epoch 36/100, Train Loss: 1.4120, Val Loss: 6.0867, LR: 0.000003
# EarlyStopping counter: 5 out of 11
# Epoch 37/100, Train Loss: 1.4086, Val Loss: 6.0786, LR: 0.000002
# Epoch 38/100, Train Loss: 1.4132, Val Loss: 6.0856, LR: 0.000095
# EarlyStopping counter: 1 out of 11
# Epoch 39/100, Train Loss: 1.4141, Val Loss: 6.0941, LR: 0.000095
# EarlyStopping counter: 2 out of 11
# Epoch 40/100, Train Loss: 1.4134, Val Loss: 6.1012, LR: 0.000095
# EarlyStopping counter: 3 out of 11
# Epoch 41/100, Train Loss: 1.4085, Val Loss: 6.1529, LR: 0.000094
# EarlyStopping counter: 4 out of 11
# Epoch 42/100, Train Loss: 1.4085, Val Loss: 6.1236, LR: 0.000093
# EarlyStopping counter: 5 out of 11
# Epoch 43/100, Train Loss: 1.4080, Val Loss: 6.1506, LR: 0.000092
# EarlyStopping counter: 6 out of 11
# Epoch 44/100, Train Loss: 1.4067, Val Loss: 6.1804, LR: 0.000090
# EarlyStopping counter: 7 out of 11
# Epoch 45/100, Train Loss: 1.4073, Val Loss: 6.1525, LR: 0.000088
# EarlyStopping counter: 8 out of 11
# EarlyStopping counter: 1 out of 11
# Epoch 32/100, Train Loss: 1.5417, Val Loss: 3.4694, LR: 0.000020
# EarlyStopping counter: 2 out of 11
# Epoch 33/100, Train Loss: 1.5398, Val Loss: 3.5320, LR: 0.000015
# EarlyStopping counter: 3 out of 11
# Epoch 34/100, Train Loss: 1.5414, Val Loss: 3.5221, LR: 0.000010
# EarlyStopping counter: 4 out of 11
# Epoch 35/100, Train Loss: 1.5387, Val Loss: 3.6592, LR: 0.000006
# EarlyStopping counter: 5 out of 11
# Epoch 36/100, Train Loss: 1.5382, Val Loss: 3.5216, LR: 0.000003
# EarlyStopping counter: 6 out of 11
# Epoch 37/100, Train Loss: 1.5382, Val Loss: 3.5268, LR: 0.000002
# EarlyStopping counter: 7 out of 11
# Epoch 38/100, Train Loss: 1.5375, Val Loss: 3.6492, LR: 0.000095
# EarlyStopping counter: 8 out of 11
# Epoch 39/100, Train Loss: 1.5394, Val Loss: 4.0445, LR: 0.000095
# EarlyStopping counter: 9 out of 11
# Epoch 40/100, Train Loss: 1.5360, Val Loss: 4.1202, LR: 0.000095
# EarlyStopping counter: 10 out of 11
# Epoch 41/100, Train Loss: 1.5390, Val Loss: 3.9976, LR: 0.000094
# EarlyStopping counter: 11 out of 11
# Early stopping triggered
#
# Cross-Validation Results:
# Mean Absolute Error (CV): 9.3943 (±2.9290)
# Root Mean Squared Error (CV): 11.2798 (±3.7616)
# Theil's U Statistic (CV): 0.7682 (±0.0268)
# R² Score (CV): -10.8513 (±7.5105)
# Directional Accuracy (CV): 36.36% (±9.36%)
#
# Cross-validation Results:
# Mean Absolute Error (CV): 9.3943 (±2.9290)
# Root Mean Squared Error (CV): 11.2798 (±3.7616)
# R² Score (CV): -10.8513 (±7.5105)
# Theil's U Statistic (CV): 0.7682 (±0.0268)
# Directional Accuracy (CV): 36.36% (±9.36%)
#
# Cross-validation results saved to 'cross_validation_results.csv'

# %%
# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Load data if not already loaded
if 'df' not in locals():
    print("Loading data...")
    df = pd.read_csv('real_time_cleaned.csv')
    df['block_time'] = pd.to_datetime(df['block_time'])
    df = df.sort_values('block_time')
    df.set_index('block_time', inplace=True)

# Train final model on full dataset
print("\nTraining final model on full dataset...")
predictor = BitcoinFeePredictor(best_config)
df_prepared, scaler = predictor.prepare_data(df)
model = predictor.train_model(df_prepared)

# Generate predictions for next 144 blocks
print("\nGenerating predictions...")
predictions = predictor.predict(model, df_prepared)

# Create timestamps for predictions
last_time = df.index[-1]
prediction_times = pd.date_range(
    start=last_time,
    periods=145,
    freq='10T'
)[1:]  # Exclude the first timestamp

# Create results DataFrame
results_df = pd.DataFrame({
    'timestamp': prediction_times,
    'predicted_fee_rate': predictions[:144]
})

# Plot future predictions
plt.figure(figsize=(15, 8))

# Plot historical data
historical_data = df['block_median_fee_rate'].iloc[-144:]
plt.plot(historical_data.index, historical_data.values,
         label='Historical', color='gray', alpha=0.3)

# Plot predictions
plt.plot(results_df['timestamp'], results_df['predicted_fee_rate'],
         label='Predicted', marker='o', markersize=4)

plt.title('Bitcoin Fee Rate Predictions - Next 144 Blocks')
plt.xlabel('Time')
plt.ylabel('Fee Rate (sat/vB)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# Save predictions
results_df.to_csv('time2vec_predictions.csv')
print("\nPredictions saved to 'time2vec_predictions.csv'")

# Print prediction statistics
print("\nPrediction Statistics:")
print(results_df['predicted_fee_rate'].describe())

# Evaluate on test set if available
try:
    print("\nEvaluating on test set...")
    test_data = pd.read_csv('test.csv')
    actual_values = test_data['block_median_fee_rate']
    
    # Make sure we have the same number of predictions as actual values
    predicted_values = predictions[:len(actual_values)]
    
    # Calculate metrics
    metrics = predictor.calculate_metrics(actual_values.values, predicted_values)
    
    # Print metrics
    print("\nTest Set Performance Metrics:")
    print(f"Mean Absolute Error (MAE): {metrics.mae:.4f}")
    print(f"Root Mean Squared Error (RMSE): {metrics.rmse:.4f}")
    print(f"R² Score: {metrics.r2:.4f}")
    print(f"Theil's U Statistic: {metrics.theil_u:.4f}")
    print(f"Directional Accuracy: {metrics.directional_accuracy:.2f}%")
    
    # Plot comparison
    plt.figure(figsize=(15, 8))
    
    # Plot actual values
    plt.plot(range(len(actual_values)), actual_values, 
             label='Actual Fee Rate', linewidth=2)
    
    # Plot predicted values
    plt.plot(range(len(actual_values)), predicted_values, 
             label='Predicted Fee Rate', linestyle='--', linewidth=2)
    


    plt.title('Actual vs Predicted Bitcoin Fee Rate', fontsize=16)
    plt.xlabel('Time', fontsize=14)
    plt.ylabel('Fee Rate (sat/vB)', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(alpha=0.3)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

except FileNotFoundError:
    print("\nNo test set found. Skipping evaluation.")
except Exception as e:
    print(f"\nError during evaluation: {str(e)}")
# Out:
# Training final model on full dataset...
# Epoch 1/100, Train Loss: 5.3595, Val Loss: 9.0252, LR: 0.000020
# Epoch 2/100, Train Loss: 5.1888, Val Loss: 8.7947, LR: 0.000031
# Epoch 3/100, Train Loss: 4.9006, Val Loss: 8.4516, LR: 0.000042
# Epoch 4/100, Train Loss: 4.4467, Val Loss: 7.8754, LR: 0.000052
# Epoch 5/100, Train Loss: 3.7851, Val Loss: 6.9422, LR: 0.000063
# Epoch 6/100, Train Loss: 3.0795, Val Loss: 5.4062, LR: 0.000074
# Epoch 7/100, Train Loss: 2.8004, Val Loss: 4.7911, LR: 0.000084
# Epoch 8/100, Train Loss: 2.7292, Val Loss: 4.5428, LR: 0.000095
# Epoch 9/100, Train Loss: 2.6127, Val Loss: 4.1583, LR: 0.000093
# Epoch 10/100, Train Loss: 2.4426, Val Loss: 3.3945, LR: 0.000086
# Epoch 11/100, Train Loss: 2.1642, Val Loss: 2.7261, LR: 0.000076
# Epoch 12/100, Train Loss: 1.9543, Val Loss: 2.6649, LR: 0.000063
# Epoch 13/100, Train Loss: 1.8653, Val Loss: 2.6741, LR: 0.000048
# EarlyStopping counter: 1 out of 11
# Epoch 14/100, Train Loss: 1.7982, Val Loss: 2.6618, LR: 0.000034
# Epoch 15/100, Train Loss: 1.7639, Val Loss: 2.6484, LR: 0.000020
# Epoch 16/100, Train Loss: 1.7432, Val Loss: 2.6685, LR: 0.000010
# EarlyStopping counter: 1 out of 11
# Epoch 17/100, Train Loss: 1.7311, Val Loss: 2.6735, LR: 0.000003
# EarlyStopping counter: 2 out of 11
# Epoch 18/100, Train Loss: 1.7285, Val Loss: 2.6774, LR: 0.000095
# EarlyStopping counter: 3 out of 11
# Epoch 19/100, Train Loss: 1.7156, Val Loss: 2.6965, LR: 0.000095
# EarlyStopping counter: 4 out of 11
# Epoch 20/100, Train Loss: 1.6749, Val Loss: 2.6172, LR: 0.000093
# Epoch 21/100, Train Loss: 1.6457, Val Loss: 2.5997, LR: 0.000090
# Epoch 22/100, Train Loss: 1.6337, Val Loss: 2.6083, LR: 0.000086
# EarlyStopping counter: 1 out of 11
# Epoch 23/100, Train Loss: 1.6211, Val Loss: 2.6394, LR: 0.000081
# EarlyStopping counter: 2 out of 11
# Epoch 24/100, Train Loss: 1.6144, Val Loss: 2.6125, LR: 0.000076
# EarlyStopping counter: 3 out of 11
# Epoch 25/100, Train Loss: 1.6102, Val Loss: 2.6013, LR: 0.000069
# EarlyStopping counter: 4 out of 11
# Epoch 26/100, Train Loss: 1.6070, Val Loss: 2.5765, LR: 0.000063
# Epoch 27/100, Train Loss: 1.6023, Val Loss: 2.5921, LR: 0.000055
# EarlyStopping counter: 1 out of 11
# Epoch 28/100, Train Loss: 1.6020, Val Loss: 2.5968, LR: 0.000048
# EarlyStopping counter: 2 out of 11
# Epoch 29/100, Train Loss: 1.6009, Val Loss: 2.5863, LR: 0.000041
# EarlyStopping counter: 3 out of 11
# Epoch 30/100, Train Loss: 1.5989, Val Loss: 2.5863, LR: 0.000034
# EarlyStopping counter: 4 out of 11
# Epoch 31/100, Train Loss: 1.5962, Val Loss: 2.5916, LR: 0.000027
# EarlyStopping counter: 5 out of 11
# Epoch 32/100, Train Loss: 1.5960, Val Loss: 2.5950, LR: 0.000020
# EarlyStopping counter: 6 out of 11
# Epoch 33/100, Train Loss: 1.5941, Val Loss: 2.5975, LR: 0.000015
# EarlyStopping counter: 7 out of 11
# Epoch 34/100, Train Loss: 1.5944, Val Loss: 2.5955, LR: 0.000010
# EarlyStopping counter: 8 out of 11
# Epoch 35/100, Train Loss: 1.5923, Val Loss: 2.5866, LR: 0.000006
# EarlyStopping counter: 9 out of 11
# Epoch 36/100, Train Loss: 1.5923, Val Loss: 2.5878, LR: 0.000003
# EarlyStopping counter: 10 out of 11
# Epoch 37/100, Train Loss: 1.5915, Val Loss: 2.5890, LR: 0.000002
# EarlyStopping counter: 11 out of 11
# Early stopping triggered
#
# Generating predictions...
# Predictions saved to 'time2vec_predictions.csv'
#
# Prediction Statistics:
# count    144.000000
# mean      12.042718
# std        4.047398
# min        5.105147
# 25%        8.573932
# 50%       12.042717
# 75%       15.511502
# max       18.980286
# Name: predicted_fee_rate, dtype: float64
#
# Evaluating on test set...
#
# Test Set Performance Metrics:
# Mean Absolute Error (MAE): 5.6106
# Root Mean Squared Error (RMSE): 6.1604
# R² Score: -1.2656
# Theil's U Statistic: 0.7519
# Directional Accuracy: 40.56%
